# %%
# %pip install webdriver-manager
# %pip install selenium-firefox
# Out:
# Collecting webdriver-manager
#   Obtaining dependency information for webdriver-manager from https://files.pythonhosted.org/packages/b1/51/b5c11cf739ac4eecde611794a0ec9df420d0239d51e73bc19eb44f02b48b/webdriver_manager-4.0.1-py2.py3-none-any.whl.metadata
#   Downloading webdriver_manager-4.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from webdriver-manager) (2.31.0)
# Collecting python-dotenv (from webdriver-manager)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: packaging in /Users/javierdealcazar/Library/Python/3.11/lib/python/site-packages (from webdriver-manager) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->webdriver-manager) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->webdriver-manager) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->webdriver-manager) (2023.7.22)
# Downloading webdriver_manager-4.0.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: python-dotenv, webdriver-manager
# Successfully installed python-dotenv-1.0.0 webdriver-manager-4.0.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting selenium-firefox
#   Obtaining dependency information for selenium-firefox from https://files.pythonhosted.org/packages/13/19/a13176802c130d1eb8734af4deff66181a7fab7cb030c4019d94066b0087/selenium_firefox-2.0.8-py3-none-any.whl.metadata
#   Downloading selenium_firefox-2.0.8-py3-none-any.whl.metadata (2.7 kB)
# Collecting geckodriver-autoinstaller>=0.1.0 (from selenium-firefox)
#   Downloading geckodriver_autoinstaller-0.1.0-py3-none-any.whl (5.6 kB)
# Collecting kproxy>=0.0.1 (from selenium-firefox)
#   Downloading kproxy-0.0.1-py3-none-any.whl (3.3 kB)
# Collecting noraise>=0.0.16 (from selenium-firefox)
#   Downloading noraise-0.0.16-py3-none-any.whl (4.2 kB)
# Requirement already satisfied: selenium>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-firefox) (4.14.0)
# Collecting selenium-browser>=0.0.12 (from selenium-firefox)
#   Downloading selenium_browser-0.0.15-py3-none-any.whl (14 kB)
# Collecting setuptools>=67.8.0 (from selenium-firefox)
#   Obtaining dependency information for setuptools>=67.8.0 from https://files.pythonhosted.org/packages/bb/26/7945080113158354380a12ce26873dd6c1ebd88d47f5bc24e2c5bb38c16a/setuptools-68.2.2-py3-none-any.whl.metadata
#   Downloading setuptools-68.2.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jsoncodable>=0.1.7 (from kproxy>=0.0.1->selenium-firefox)
#   Downloading jsoncodable-0.1.7-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium>=4.0.0->selenium-firefox) (2.0.6)
# Requirement already satisfied: trio~=0.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium>=4.0.0->selenium-firefox) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium>=4.0.0->selenium-firefox) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium>=4.0.0->selenium-firefox) (2023.7.22)
# Collecting k-selenium-cookies>=0.0.4 (from selenium-browser>=0.0.12->selenium-firefox)
#   Downloading k_selenium_cookies-0.0.4-py3-none-any.whl (4.9 kB)
# Collecting xpath-utils>=0.0.3 (from selenium-browser>=0.0.12->selenium-firefox)
#   Downloading xpath_utils-0.0.3-py3-none-any.whl (8.8 kB)
# Collecting jsonpickle>=2.0.0 (from jsoncodable>=0.1.7->kproxy>=0.0.1->selenium-firefox)
#   Obtaining dependency information for jsonpickle>=2.0.0 from https://files.pythonhosted.org/packages/d3/25/6e0a450430b7aa194b0f515f64820fc619314faa289458b7dfca4a026114/jsonpickle-3.0.2-py3-none-any.whl.metadata
#   Downloading jsonpickle-3.0.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting tldextract>=3.1.0 (from k-selenium-cookies>=0.0.4->selenium-browser>=0.0.12->selenium-firefox)
#   Obtaining dependency information for tldextract>=3.1.0 from https://files.pythonhosted.org/packages/3d/c3/e743f2a39cd38b0ea5af0d7833ba18bd73f79ea5348826d2a08d8b3ba5e4/tldextract-5.0.0-py3-none-any.whl.metadata
#   Downloading tldextract-5.0.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: attrs>=20.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-firefox) (23.1.0)
# Requirement already satisfied: sortedcontainers in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-firefox) (2.4.0)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-firefox) (3.4)
# Requirement already satisfied: outcome in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-firefox) (1.2.0)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-firefox) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium>=4.0.0->selenium-firefox) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium>=4.0.0->selenium-firefox) (1.7.1)
# Requirement already satisfied: requests>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tldextract>=3.1.0->k-selenium-cookies>=0.0.4->selenium-browser>=0.0.12->selenium-firefox) (2.31.0)
# Collecting requests-file>=1.4 (from tldextract>=3.1.0->k-selenium-cookies>=0.0.4->selenium-browser>=0.0.12->selenium-firefox)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Collecting filelock>=3.0.8 (from tldextract>=3.1.0->k-selenium-cookies>=0.0.4->selenium-browser>=0.0.12->selenium-firefox)
#   Obtaining dependency information for filelock>=3.0.8 from https://files.pythonhosted.org/packages/5e/5d/97afbafd9d584ff1b45fcb354a479a3609bd97f912f8f1f6c563cb1fae21/filelock-3.12.4-py3-none-any.whl.metadata
#   Downloading filelock-3.12.4-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: h11<1,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium>=4.0.0->selenium-firefox) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.1.0->tldextract>=3.1.0->k-selenium-cookies>=0.0.4->selenium-browser>=0.0.12->selenium-firefox) (3.3.0)
# Requirement already satisfied: six in /Users/javierdealcazar/Library/Python/3.11/lib/python/site-packages (from requests-file>=1.4->tldextract>=3.1.0->k-selenium-cookies>=0.0.4->selenium-browser>=0.0.12->selenium-firefox) (1.16.0)
# Downloading selenium_firefox-2.0.8-py3-none-any.whl (13.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 9.2 MB/s eta 0:00:00:00:0100:01
# Downloading setuptools-68.2.2-py3-none-any.whl (807 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 9.3 MB/s eta 0:00:00:00:0100:01
# Downloading jsonpickle-3.0.2-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 2.1 MB/s eta 0:00:00
# Downloading tldextract-5.0.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.0/97.0 kB 5.9 MB/s eta 0:00:00
# Downloading filelock-3.12.4-py3-none-any.whl (11 kB)
# Installing collected packages: xpath-utils, setuptools, noraise, jsonpickle, geckodriver-autoinstaller, filelock, requests-file, jsoncodable, tldextract, kproxy, k-selenium-cookies, selenium-browser, selenium-firefox
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.5.0
#     Uninstalling setuptools-65.5.0:
#       Successfully uninstalled setuptools-65.5.0
# Successfully installed filelock-3.12.4 geckodriver-autoinstaller-0.1.0 jsoncodable-0.1.7 jsonpickle-3.0.2 k-selenium-cookies-0.0.4 kproxy-0.0.1 noraise-0.0.16 requests-file-1.5.1 selenium-browser-0.0.15 selenium-firefox-2.0.8 setuptools-68.2.2 tldextract-5.0.0 xpath-utils-0.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install selenium-wire
# Out:
# Collecting selenium-wire
#   Downloading selenium_wire-5.1.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 874.6 kB/s eta 0:00:0000:0100:01
# Collecting blinker>=1.4 (from selenium-wire)
#   Obtaining dependency information for blinker>=1.4 from https://files.pythonhosted.org/packages/bf/2b/11bcedb7dee4923253a4a21bae3be854bcc4f06295bd827756352016d97c/blinker-1.6.3-py3-none-any.whl.metadata
#   Downloading blinker-1.6.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting brotli>=1.0.9 (from selenium-wire)
#   Obtaining dependency information for brotli>=1.0.9 from https://files.pythonhosted.org/packages/95/4e/5afab7b2b4b61a84e9c75b17814198ce515343a44e2ed4488fac314cd0a9/Brotli-1.1.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading Brotli-1.1.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: certifi>=2019.9.11 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire) (2023.7.22)
# Collecting kaitaistruct>=0.7 (from selenium-wire)
#   Downloading kaitaistruct-0.10-py2.py3-none-any.whl (7.0 kB)
# Collecting pyasn1>=0.3.1 (from selenium-wire)
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 643.1 kB/s eta 0:00:00a 0:00:01
# Collecting pyOpenSSL>=22.0.0 (from selenium-wire)
#   Obtaining dependency information for pyOpenSSL>=22.0.0 from https://files.pythonhosted.org/packages/f0/e2/f8b4f1c67933a4907e52228241f4bd52169f3196b70af04403b29c63238a/pyOpenSSL-23.2.0-py3-none-any.whl.metadata
#   Downloading pyOpenSSL-23.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyparsing>=2.4.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire) (3.1.1)
# Requirement already satisfied: pysocks>=1.7.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire) (1.7.1)
# Requirement already satisfied: selenium>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire) (4.14.0)
# Requirement already satisfied: wsproto>=0.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire) (1.2.0)
# Collecting zstandard>=0.14.1 (from selenium-wire)
#   Downloading zstandard-0.21.0-cp311-cp311-macosx_10_9_x86_64.whl (473 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.8/473.8 kB 591.8 kB/s eta 0:00:00a 0:00:01
# Collecting h2>=4.0 (from selenium-wire)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 895.7 kB/s eta 0:00:00:--:--
# Collecting hyperframe>=6.0 (from selenium-wire)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2>=4.0->selenium-wire)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Collecting cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0 (from pyOpenSSL>=22.0.0->selenium-wire)
#   Obtaining dependency information for cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0 from https://files.pythonhosted.org/packages/bb/c1/e8ca19a3e9ac5c867efa6f23ce0b119ad00a16b6019e49a298b8c1fe6866/cryptography-41.0.4-cp37-abi3-macosx_10_12_x86_64.whl.metadata
#   Downloading cryptography-41.0.4-cp37-abi3-macosx_10_12_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium>=4.0.0->selenium-wire) (2.0.6)
# Requirement already satisfied: trio~=0.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium>=4.0.0->selenium-wire) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium>=4.0.0->selenium-wire) (0.11.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wsproto>=0.14->selenium-wire) (0.14.0)
# Collecting cffi>=1.12 (from cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0->pyOpenSSL>=22.0.0->selenium-wire)
#   Obtaining dependency information for cffi>=1.12 from https://files.pythonhosted.org/packages/95/c8/ce05a6cba2bec12d4b28285e66c53cc88dd7385b102dea7231da3b74cfef/cffi-1.16.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading cffi-1.16.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: attrs>=20.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-wire) (23.1.0)
# Requirement already satisfied: sortedcontainers in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-wire) (2.4.0)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-wire) (3.4)
# Requirement already satisfied: outcome in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-wire) (1.2.0)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-wire) (1.3.0)
# Collecting pycparser (from cffi>=1.12->cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0->pyOpenSSL>=22.0.0->selenium-wire)
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Downloading blinker-1.6.3-py3-none-any.whl (13 kB)
# Downloading Brotli-1.1.0-cp311-cp311-macosx_10_9_x86_64.whl (446 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.2/446.2 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Downloading pyOpenSSL-23.2.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 2.7 MB/s eta 0:00:00
# Downloading cryptography-41.0.4-cp37-abi3-macosx_10_12_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 3.5 MB/s eta 0:00:0000:0100:01
# Downloading cffi-1.16.0-cp311-cp311-macosx_10_9_x86_64.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 kB 2.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: brotli, zstandard, pycparser, pyasn1, kaitaistruct, hyperframe, hpack, blinker, h2, cffi, cryptography, pyOpenSSL, selenium-wire
# Successfully installed blinker-1.6.3 brotli-1.1.0 cffi-1.16.0 cryptography-41.0.4 h2-4.1.0 hpack-4.0.0 hyperframe-6.0.1 kaitaistruct-0.10 pyOpenSSL-23.2.0 pyasn1-0.5.0 pycparser-2.21 selenium-wire-5.1.0 zstandard-0.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from seleniumwire import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.proxy import Proxy, ProxyType
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from selenium_stealth import stealth
from selenium.webdriver.firefox.options import Options as FirefoxOptions


from bs4 import BeautifulSoup as bs
import time
import pandas as pd
import random

# %%
driver = webdriver.Firefox()
driver.get("https://dev.to")
# Out:
# There was an error managing firefox (error sending request for url (https://github.com/mozilla/geckodriver/releases/latest): error trying to connect: Se ha forzado la interrupción de una conexión existente por el host remoto. (os error 10054)); using driver found in the cache

# %%
driver.quit()

# %% [markdown]
# proxies = pd.read_csv("./Free_Proxy_List.csv")
# print(proxies)
# list_ip = [x for x in proxies["ip"]]
# list_port = [x for x in proxies["port"]]
# list_proxies = []
# for x in range(0, len(list_ip)-1):
#     list_proxies.append(str(list_ip[x]) + ":" + str(list_port[x]))
# #list_proxies

# %% [markdown]
# df_1 = pd.DataFrame()
# # the list of proxy to rotate on
# PROXIES = list_proxies
# # randomly extract a proxy
# random_proxy = random.choice(PROXIES)
#
# random_ip, random_port = random_proxy.split(":")

# %%
#myProxy = random_proxy

df_1 = pd.DataFrame()
driver = webdriver.Firefox()

# %%
def get_rent_info(soup):
    rent_info = {
        "Direction": [],
        "Price": [],
        "m2": [],
        "Floor": [],
        "Room": [],
        "Description": []
    }
    item_info = soup.find_all('div', class_="item-info-container")
    rent_info["Direction"] = [x.find('a',class_="item-link").get_text() for x in item_info]
    rent_info["Price"] = [x.find('span',class_="item-price h2-simulated").get_text() for x in item_info]
    rent_info["Description"] = [x.find('div',class_="item-description description").get_text() for x in item_info]

    apart_detail = [x.find('div',class_="item-detail-char").get_text() for x in item_info]

    detail_list = [x.split('\n') for x in apart_detail]
    time.sleep(12)

    for elem in detail_list:
        print(elem)
        rent_info["Room"].append(elem[1])
        rent_info["m2"].append(elem[2])
        rent_info["Floor"].append(elem[3])

    df = pd.DataFrame(rent_info)
    return df

# %%
df = pd.DataFrame()

soup = []
df_info = pd.DataFrame()
URL = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/"
URL_2 ="https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-2.htm"
URL_3 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-3.htm"
URL_4 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-4.htm"
URL_5 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-5.htm"
URL_5 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-6.htm"
URL_6 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-7.htm"
URL_7 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-8.htm"

urls = [URL,URL_2]

# scraping logic...
for url in urls:
    time.sleep(5)
    driver.get(url)
    time.sleep(15)
    soup.append((driver.page_source, "html.parser"))


driver.quit()

for s in soup:
    s = bs(s[0],"html.parser")
    df = pd.concat([df,get_rent_info(s)],ignore_index=True)
df_1.to_csv("rents.csv", index=False)
# Out:
# ['', '2 hab.', '71 m²', 'Planta 5ª exterior con ascensor', '9 minutos', '']
# ['', '2 hab.', '134 m²', 'Planta 4ª exterior con ascensor', '18\xa0oct ', '']
# ['', '1 hab.', '35 m²', 'Planta 2ª interior con ascensor', '13 minutos', '']
# ['', '1 hab.', '38 m²', 'Planta 1ª exterior con ascensor', '']
# ['', '2 hab.', '135 m²', 'Bajo exterior sin ascensor', '56 minutos', '']
# ['', '4 hab.', '180 m²', ' exterior con ascensor', '']
# ['', '1 hab.', '70 m²', 'Planta 4ª exterior con ascensor', '1 hora', '']
# ['', '4 hab.', '151 m²', 'Planta 1ª exterior con ascensor', '']
# ['', '2 hab.', '45 m²', 'Planta 3ª exterior con ascensor', '1 hora', '']
# ['', '5 hab.', '448 m²', '']
# ['', '4 hab.', '176 m²', 'Planta 2ª exterior con ascensor', '1 hora', '']
# ['', '3 hab.', '100 m²', 'Planta 4ª exterior con ascensor', '']
# ['', '3 hab.', '87 m²', 'Planta 3ª exterior con ascensor', '2 horas', '']
# ['', '4 hab.', '247 m²', 'Planta 4ª exterior con ascensor', '']
# ['', '1 hab.', '55 m²', 'Planta 1ª interior con ascensor', '2 horas', '']
# ['', '3 hab.', '157 m²', 'Planta 5ª exterior con ascensor', '']
# ['', '2 hab.', '62 m²', 'Planta 3ª exterior con ascensor', '4 horas', '']
# ['', '3 hab.', '120 m²', 'Planta 1ª exterior con ascensor', '']
# ['', '1 hab.', '59 m²', 'Planta 4ª exterior con ascensor', '6 horas', '']
# ['', '2 hab.', '174 m²', 'Planta 2ª exterior con ascensor', '']
# ['', '2 hab.', '85 m²', 'Planta 2ª exterior con ascensor', '13 horas', '']
# ['', '1 hab.', '43 m²', 'Planta 1ª exterior con ascensor', '']
# ['', '2 hab.', '70 m²', 'Bajo exterior sin ascensor', '13 horas', '']
# ['', '30 m²', 'Bajo interior sin ascensor', '']
# ['', '1 hab.', '70 m²', 'Planta 5ª exterior con ascensor', '14 horas', '']
# ['', '2 hab.', '85 m²', 'Planta 2ª exterior con ascensor', '36 minutos', '']
# ['', '3 hab.', '130 m²', 'Planta 4ª exterior con ascensor', '15 horas', '']
# ['', '2 hab.', '67 m²', 'Planta 1ª exterior sin ascensor', '']
# ['', '1 hab.', '82 m²', 'Planta 2ª exterior con ascensor', '14 horas', '']
# ['', '2 hab.', '100 m²', 'Planta 5ª interior con ascensor', '20\xa0oct ', '']

# %%
s= bs(soup[0][0],"html.parser")

# %%
s
# Out:
# <html class="" data-userauth="false" env="es" lang="es" username=""><head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Casas y pisos en alquiler en Madrid — idealista</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Alquiler casas y pisos en Madrid, a partir de 550 euros de particulares e inmobiliarias. Alquiler casas y pisos en Madrid: anuncios de particular a particular y de agencias inmobiliarias." name="description"/>
# <meta content="idealista.com" name="author"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="no-cache" name="pragma"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Fri, 01 Jan 1990 00:00:00 GMT" http-equiv="Expires"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <script async="" src="https://js.datadome.co/tags.js"></script><script async="" charset="utf-8" id="utag_239" src="https://tag.aticdn.net/piano-analytics.js" type="text/javascript"></script><script defer="" src="//dp.idealista.com/es-portal/prod/utag.js" type="text/javascript"></script><script async="" charset="utf-8" id="spcloader" src="https://sdk.privacy-center.org/645b65e6-0665-4634-b4e4-98e7024b6598/loader.js?target=www.idealista.com" type="text/javascript"></script><script defer="" src="https://st3.idealista.com/static/common/js/lib/jquery/jquery-1.10.2.js"></script>
# <script src="https://st3.idealista.com/static/common/release/mavericks/legacy/js/didomi/didomi-consent-lang.js"></script>
# <script src="https://st3.idealista.com/static/common/release/mavericks/legacy/js/didomi/didomi-iab-integration.js"></script>
# <script src="https://st3.idealista.com/static/common/release/mavericks/legacy/js/didomi/didomi-embed.js"></script>
# <script src="https://st3.idealista.com/static/common/release/mavericks/legacy/js/tealium/tealium-wrapper.js?20231020095014"></script>
# <link href="https://st3.idealista.com/static/common/icons/favicon.ico?20231020095014" rel="shortcut icon"/>
# <link href="https://st3.idealista.com/static/common/icons/32x32.png?20231020095014" rel="apple-touch-icon" sizes="32x32"/>
# <link href="https://st3.idealista.com/static/common/icons/32x32.png?20231020095014" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/57x57.png?20231020095014" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://st3.idealista.com/static/common/icons/57x57.png?20231020095014" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/60x60.png?20231020095014" rel="apple-touch-icon"/>
# <link href="https://st3.idealista.com/static/common/icons/60x60.png?20231020095014" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/76x76.png?20231020095014" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://st3.idealista.com/static/common/icons/76x76.png?20231020095014" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="https://st3.idealista.com/static/common/icons/96x96.png?20231020095014" rel="apple-touch-icon" sizes="96x96"/>
# <link href="https://st3.idealista.com/static/common/icons/96x96.png?20231020095014" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/120x120.png?20231020095014" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://st3.idealista.com/static/common/icons/120x120.png?20231020095014" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="https://st3.idealista.com/static/common/icons/128x128.png?20231020095014" rel="apple-touch-icon" sizes="128x128"/>
# <link href="https://st3.idealista.com/static/common/icons/128x128.png?20231020095014" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/144x144.png?20231020095014" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://st3.idealista.com/static/common/icons/144x144.png?20231020095014" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/152x152.png?20231020095014" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://st3.idealista.com/static/common/icons/152x152.png?20231020095014" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="https://st3.idealista.com/static/common/icons/167x167.png?20231020095014" rel="apple-touch-icon" sizes="167x167"/>
# <link href="https://st3.idealista.com/static/common/icons/167x167.png?20231020095014" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/180x180.png?20231020095014" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://st3.idealista.com/static/common/icons/180x180.png?20231020095014" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/192x192.png?20231020095014" rel="apple-touch-icon" sizes="192x192"/>
# <link href="https://st3.idealista.com/static/common/icons/192x192.png?20231020095014" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/195x195.png?20231020095014" rel="apple-touch-icon" sizes="195x195"/>
# <link href="https://st3.idealista.com/static/common/icons/195x195.png?20231020095014" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/196x196.png?20231020095014" rel="apple-touch-icon" sizes="196x196"/>
# <link href="https://st3.idealista.com/static/common/icons/196x196.png?20231020095014" rel="apple-touch-icon-precomposed"/>
# <link as="style" href="https://st3.idealista.com/static/common/release/listing/listing.css?20231020095014" rel="preload"/>
# <link href="https://st3.idealista.com/static/common/release/listing/listing.css?20231020095014" rel="stylesheet" type="text/css"/>
# <link as="style" href="https://st3.idealista.com/static/common/release/modules/breadcrumb-geo-new.css?20231020095014" rel="preload"/>
# <link href="https://st3.idealista.com/static/common/release/modules/breadcrumb-geo-new.css?20231020095014" rel="stylesheet" type="text/css"/>
# <link as="style" href="https://st3.idealista.com/static/common/release/contact/contact-manager.css?20231020095014" rel="preload"/>
# <link href="https://st3.idealista.com/static/common/release/contact/contact-manager.css?20231020095014" rel="stylesheet" type="text/css"/>
# <link as="style" href="https://st3.idealista.com/static/common/release/modules/gallery-widget.css?20231020095014" rel="preload"/>
# <link href="https://st3.idealista.com/static/common/release/modules/gallery-widget.css?20231020095014" rel="stylesheet" type="text/css"/>
# <link href="https://www.idealista.com/alquiler-viviendas/madrid-madrid/" rel="canonical"/>
# <meta content="INDEX, FOLLOW" name="ROBOTS"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1.0" name="viewport"/>
# <script async="" data-vendor="iab:45" src="//ced.sascdn.com/tag/687/smart.js" type="text/javascript"></script><script async="" data-processed="true" data-vendor="iab:45" src="//ced.sascdn.com/tag/687/smart.js" type="didomi/javascript"></script>
# <script data-vendor="iab:45" type="text/javascript">
#                         var sas = sas || {};
#                         sas.cmd = sas.cmd || [];
#                         sas.cmd.push(function() {
#                             if(sas.setup) {
#                                 sas.setup({networkid: 687, domain: '//www8.smartadserver.com', async: true, renderMode: 2});
#                             }
#                         });
#                     </script><script data-processed="true" data-vendor="iab:45" type="didomi/javascript">
#                         var sas = sas || {};
#                         sas.cmd = sas.cmd || [];
#                         sas.cmd.push(function() {
#                             if(sas.setup) {
#                                 sas.setup({networkid: 687, domain: '//www8.smartadserver.com', async: true, renderMode: 2});
#                             }
#                         });
#                     </script>
# <script data-vendor="iab:45" id="advertisementScript" type="text/javascript">
#                         var sas = sas || {};
#                         sas.cmd = sas.cmd || [];
#                         sas.cmd.push(function() {
#                             if(sas.call) {
#                                 sas.call('onecall', {
#                                     siteId:	33114,
#                                     pageId:	253245,
#                                     formatId: '16022,16025',
#                                     formats: [{"id":16022},{"id":16025}],
#                                     target: 'geo=0-EU-ES-28-07-001-079-XX-XX-XX-XX;typ=hs;auth=f;geop=0-EU-ES-28;ope=r;geoc=0-EU-ES-28-07'
#                                 }, {
#                                     onNoad: function(data){
#                                         if (data.formatId) {
#                                             var bannerDiv = document.getElementById('banners_' + data.formatId);
#                                             if (bannerDiv != null) {
#                                                 bannerDiv.style.display = 'none';
#                                             }
#                                         }
#                                     }
#                                 });
#                             }
#                         });
#                     </script><script data-processed="true" data-vendor="iab:45" id="advertisementScript" type="didomi/javascript">
#                         var sas = sas || {};
#                         sas.cmd = sas.cmd || [];
#                         sas.cmd.push(function() {
#                             if(sas.call) {
#                                 sas.call('onecall', {
#                                     siteId:	33114,
#                                     pageId:	253245,
#                                     formatId: '16022,16025',
#                                     formats: [{"id":16022},{"id":16025}],
#                                     target: 'geo=0-EU-ES-28-07-001-079-XX-XX-XX-XX;typ=hs;auth=f;geop=0-EU-ES-28;ope=r;geoc=0-EU-ES-28-07'
#                                 }, {
#                                     onNoad: function(data){
#                                         if (data.formatId) {
#                                             var bannerDiv = document.getElementById('banners_' + data.formatId);
#                                             if (bannerDiv != null) {
#                                                 bannerDiv.style.display = 'none';
#                                             }
#                                         }
#                                     }
#                                 });
#                             }
#                         });
#                     </script>
# <link href="https://www.idealista.com/ca/alquiler-viviendas/madrid-madrid/" hreflang="ca" rel="alternate"/><link href="https://www.idealista.com/en/alquiler-viviendas/madrid-madrid/" hreflang="en" rel="alternate"/><link href="https://www.idealista.com/fr/alquiler-viviendas/madrid-madrid/" hreflang="fr" rel="alternate"/><link href="https://www.idealista.com/de/alquiler-viviendas/madrid-madrid/" hreflang="de" rel="alternate"/><link href="https://www.idealista.com/it/alquiler-viviendas/madrid-madrid/" hreflang="it" rel="alternate"/><link href="https://www.idealista.com/pt/alquiler-viviendas/madrid-madrid/" hreflang="pt" rel="alternate"/><link href="https://www.idealista.com/da/alquiler-viviendas/madrid-madrid/" hreflang="da" rel="alternate"/><link href="https://www.idealista.com/fi/alquiler-viviendas/madrid-madrid/" hreflang="fi" rel="alternate"/><link href="https://www.idealista.com/no/alquiler-viviendas/madrid-madrid/" hreflang="no" rel="alternate"/><link href="https://www.idealista.com/nl/alquiler-viviendas/madrid-madrid/" hreflang="nl" rel="alternate"/><link href="https://www.idealista.com/pl/alquiler-viviendas/madrid-madrid/" hreflang="pl" rel="alternate"/><link href="https://www.idealista.com/ro/alquiler-viviendas/madrid-madrid/" hreflang="ro" rel="alternate"/><link href="https://www.idealista.com/ru/alquiler-viviendas/madrid-madrid/" hreflang="ru" rel="alternate"/><link href="https://www.idealista.com/sv/alquiler-viviendas/madrid-madrid/" hreflang="sv" rel="alternate"/><link href="https://www.idealista.com/el/alquiler-viviendas/madrid-madrid/" hreflang="el" rel="alternate"/><link href="https://www.idealista.com/zh/alquiler-viviendas/madrid-madrid/" hreflang="zh" rel="alternate"/><link href="https://www.idealista.com/uk/alquiler-viviendas/madrid-madrid/" hreflang="uk" rel="alternate"/>
# <link as="font" crossorigin="" href="https://st3.idealista.com/static/common/release/modules/resources/fonts/bernino-regular.woff?v1" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://st3.idealista.com/static/common/release/modules/resources/fonts/bernino-bold.woff?v1" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://st3.idealista.com/static/common/release/modules/resources/fonts/bernino-semibold.woff?v1" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://st3.idealista.com/static/common/release/modules/resources/fonts/idealista-regular.woff?v83" rel="preload" type="font/woff"/>
# <link as="image" href="https://img3.idealista.com/blur/WEB_LISTING-M/0/id.pro.es.image.master/12/fb/cb/84494024.jpg" rel="preload" type="image/jpeg"/>
# <link href="//img3.idealista.com" rel="dns-prefetch"/><script async="" charset="utf-8" id="tiqapp" src="https://tags.tiqcdn.com/utag/tiqapp/utag.v.js?a=idealista/es-portal/202310190615&amp;cb=1697972905667" type="text/javascript"></script><link as="script" href="https://sdk.privacy-center.org/sdk/b98b368950f3d0e0d1b02b3d7d52ad2caa5bec37/modern/sdk.b98b368950f3d0e0d1b02b3d7d52ad2caa5bec37.js" rel="preload"/><script async="" charset="utf-8" src="https://sdk.privacy-center.org/sdk/b98b368950f3d0e0d1b02b3d7d52ad2caa5bec37/modern/sdk.b98b368950f3d0e0d1b02b3d7d52ad2caa5bec37.js" type="text/javascript"></script><link href="https://st3.idealista.com/static/react/projects/listings/dist/309.6cb3b1cc4ceed26bcab6.css" media="all" rel="stylesheet" type="text/css"/><script async="" charset="utf-8" id="utag_idealista.es-portal_239" src="//dp.idealista.com/es-portal/prod/utag.239.js?utv=ut4.51.202310051817" type="text/javascript"></script><script async="" charset="utf-8" id="utag_idealista.es-portal_174" src="//dp.idealista.com/es-portal/prod/utag.174.js?utv=ut4.51.202308090552" type="text/javascript"></script><script async="" charset="utf-8" id="utag_idealista.es-portal_190" src="//dp.idealista.com/es-portal/prod/utag.190.js?utv=ut4.51.202309210604" type="text/javascript"></script><script charset="utf-8" src="https://st3.idealista.com/static/react/projects/listings/dist/245.2e54bd598f2005a86e70.js"></script><script charset="utf-8" src="https://st3.idealista.com/static/react/projects/listings/dist/307.de35c421f8d444f58afd.js"></script><link href="https://st3.idealista.com/static/react/projects/listings/dist/312.793fd2b99fc98f150891.css" rel="stylesheet" type="text/css"/><script charset="utf-8" src="https://st3.idealista.com/static/react/projects/listings/dist/312.89e7af8054a4df99334b.js"></script><script charset="utf-8" src="https://st3.idealista.com/static/react/projects/listings/dist/306.2ff99c0ef009477d5f7b.js"></script><link href="https://st3.idealista.com/static/react/projects/listings/dist/311.7f11a06e79fbbeb690fc.css" rel="stylesheet" type="text/css"/><script charset="utf-8" src="https://st3.idealista.com/static/react/projects/listings/dist/311.8a58ab0416003b959367.js"></script><script charset="utf-8" src="https://st3.idealista.com/static/react/projects/listings/dist/async-es.a10f0d0c54d125a1cf49.js"></script><script charset="utf-8" src="https://st3.idealista.com/static/react/projects/listings/dist/async-profileQualification_en-properties.a0fcef24eb1b7dc9310d.js"></script><script charset="utf-8" src="https://st3.idealista.com/static/react/projects/listings/dist/async-profileQualification_es-properties.d43280cc62cfd49b0dd3.js"></script><script charset="utf-8" src="https://st3.idealista.com/static/react/projects/listings/dist/async-galleryListing_en-properties.95376ebb8e1811936de6.js"></script><script charset="utf-8" src="https://st3.idealista.com/static/react/projects/listings/dist/async-galleryListing_es-properties.53f3c2bc78868f87e29f.js"></script><script async="true" id="script-119379-1" src="https://ced-ns.sascdn.com/diff/templates/ts/dist/banner/sas-banner-1.3.js" type="text/javascript"></script></head>
# <body class="" id=""><iframe name="__tcfapiLocator" style="display: none;" title="__tcfapiLocator"></iframe><iframe name="__uspapiLocator" style="display: none;" title="__uspapiLocator"></iframe><style scoped="true" type="text/css">#didomi-host .didomi-components-button{cursor:pointer;display:block;height:38px;padding:0 20px;font-size:16px;line-height:18px;font-weight:bold;text-align:center;color:#555;background-color:#eee;border:solid 1px rgba(34,34,34,.2)}#didomi-host .didomi-components-button:disabled{opacity:.4;cursor:initial}#didomi-host .didomi-components-button span{background:rgba(0,0,0,0)}#didomi-host .didomi-mobile .didomi-components-button{font-size:14px}#didomi-host .didomi-screen-xsmall .didomi-components-button{padding:0 10px}#didomi-host .didomi-components-radio{display:-webkit-flexbox;display:flex;-moz-flex-direction:row;flex-direction:row;-webkit-flex-pack:justify;-moz-justify-content:space-between;justify-content:space-between;-moz-align-items:center;align-items:center}#didomi-host .didomi-components-radio__option{margin-right:5px;cursor:pointer;height:25px;box-shadow:1px 1px 0 0 rgba(0,0,0,.1);background-color:#fff;border:solid 1px #eee;padding:0 20px;line-height:12px;font-size:12px;color:#757575;font-weight:bold;transition:background-color 200ms,border-color 200ms;transition-timing-function:ease}#didomi-host .didomi-components-radio__option:hover{color:#757575;border-color:#757575}#didomi-host .didomi-components-radio__option:last-child{margin-right:0}[dir=rtl] #didomi-host .didomi-components-radio__option:last-child{margin-right:5px}#didomi-host .didomi-components-radio__option:first-child{margin-right:5px}[dir=rtl] #didomi-host .didomi-components-radio__option:first-child{margin-right:0}#didomi-host .didomi-components-radio__option>svg{margin-right:5px}#didomi-host .didomi-components-radio__option span{background:rgba(0,0,0,0)}#didomi-host .didomi-components-radio__option.didomi-components-radio__option--agree{background-color:#3d8548;color:#fff;border:solid 1px rgba(0,0,0,.3);padding:0 11.5px}#didomi-host .didomi-components-radio__option.didomi-components-radio__option--agree>svg{vertical-align:middle}#didomi-host .didomi-components-radio__option.didomi-components-radio__option--disagree{background-color:#e60000;color:#fff;border:solid 1px rgba(0,0,0,.3);padding:0 13.5px}#didomi-host .didomi-components-radio__option__reporting{box-sizing:border-box}#didomi-host .didomi-components-radio__option__reporting#didomi-radio-option-disagree-to-all{font-size:12px !important}#didomi-host .didomi-components-radio__option__reporting#didomi-radio-option-agree-to-all{font-size:12px !important}#didomi-host .didomi-components-radio__option__accepter{box-sizing:border-box}#didomi-host .didomi-components-accordion{flex:5}#didomi-host .didomi-components-accordion .label-click{cursor:pointer}#didomi-host .didomi-components-accordion .trigger-icon{width:15px;font-size:16px;display:inline-block;text-align:center}#didomi-host .didomi-components-accordion .didomi-content{display:none;overflow:hidden;max-height:0;opacity:0;visibility:hidden;font-weight:300;text-align:justify;transition:all .1s ease-in-out;transition-property:opacity,max-height,transform,visibility,padding-bottom}#didomi-host .didomi-components-accordion .didomi-content.active{display:block;max-height:3000px;opacity:1;visibility:visible;padding-bottom:10px;transition-property:opacity,max-height,transform,visibility;overflow:visible}#didomi-host .didomi-components-accordion .didomi-components-accordion-label-container{display:-webkit-flexbox;display:flex;-moz-flex-direction:row;flex-direction:row;-webkit-flex-pack:justify;-moz-justify-content:space-between;justify-content:space-between;-moz-align-items:center;align-items:center}#didomi-host .didomi-components-accordion .didomi-components-accordion-label-container .label-click{flex:2}#didomi-host .didomi-mobile .didomi-components-accordion{width:100%;flex:1 auto}#didomi-host .didomi-mobile .didomi-components-accord ...
#     #didomi-host {
#       font-family: 'bernino-regular', Arial, sans-serif;
#     }
#     #didomi-host a:not(.didomi-no-link-style) {
#       text-decoration: underline;
#       color: #666664 !important;
#     }
#
#
#
# #didomi-host :focus {
#     outline: none!important;
#
# }
#
# #didomi-host {
#     z-index: 9999!important;
#
# }
#
# #didomi-host .didomi-notice-banner {
# 	border-top: solid .25rem #b1d004!important;
# }
#
# #didomi-host .didomi-regular-notice
# .multiple .didomi-button-highlight,
# #didomi-host .didomi-popup-footer .didomi-popup-actions .highlight-button {
# 	-webkit-appearance: none!important;
# 	appearance: none!important;
# 	background-color: #B62682!important;
# 	border-radius: .125rem!important;
# 	border: .0625rem solid #B62682!important;
# 	box-shadow: inset 0 -1px 1px 0 #8c1d64,inset 0 1px 1px 0 rgba(255,255,255,0.5)!important;
# 	box-sizing: border-box!important;
# 	color: #fff!important;
# 	cursor: pointer!important;
# 	display: inline-block!important;
# 	font-size: 0.9rem!important;
# 	font-weight: 700!important;
# 	min-height: 2.625rem!important;
# 	padding: .375rem 1rem!important;
# 	text-align: center!important;
# 	text-decoration: none!important;
# 	word-wrap: break-word!important;
#
# }
#
# #didomi-host .didomi-regular-notice p:last-child {
#     margin-bottom: 0;
# }
#
# #didomi-host #didomi-notice.didomi-regular-notice a {
#     color: #145bc7;
#     text-decoration: none;
# }
#
# #didomi-host .didomi-regular-notice
# .multiple .didomi-button-standard {
#     background-color: transparent!important;
# 	border-width: 0!important;
# 	color: #145BC7!important;
#     font-size: 0.9rem!important;
# 	font-weight: 700!important;
# 	padding-bottom: .5rem!important;
# 	padding-top: .5rem!important;
#
# }
#
# #didomi-host .didomi-notice-text {
#     color: #141414!important;
#     font-size: .875rem!important;
#     line-height: 1.25rem!important;
#     max-height: calc(40vh - 2.75rem)!important;
#     width: 100%!important;
#
# }
#
# #didomi-host .didomi-notice-text .didomi-notice-data-processing-title, #didomi-host .didomi-notice-text .didomi-notice-data-processing-list {
#     font-size: .875rem!important;
#     line-height: 1.5rem!important;
# }
#
# #didomi-host .didomi-consent-popup-body .didomi-consent-popup-body__title {
#     font-size: 1.125rem!important;
#     color: #141414!important;
#     text-transform: lowercase!important;
# }
#
# #didomi-host .didomi-consent-popup-body .didomi-consent-popup-body__explanation a {
#     color: #145bc7!important;
#     text-decoration: none!important;
#     font-weight: 400!important;
# }
#
# #didomi-host .didomi-consent-popup-preferences .didomi-consent-popup-data-processing {
#     margin-bottom: 1rem!important;
# }
#
# #didomi-host .didomi-components-radio__option,
# #didomi-host .didomi-popup-footer .didomi-popup-actions .standard-button {
#     background-color: #e5e6e1!important;
#     border-radius: .125rem !important;
#     border: solid .0625rem #a3a3a0!important;
#     box-shadow: inset 0 .125rem .0625rem 0 #ffffff, inset 0 -.125rem .0625rem 0 #a3a3a0!important;
#     color: #141414!important;
#     font-size: 0.9rem!important;
#     height: 35px!important;
#     margin-right: .5rem!important;
#     padding: .375rem 1rem .313rem!important;
# }
#
# #didomi-host .didomi-components-radio__option:last-child {
#     margin-right: 0!important;
# }
#
# #didomi-host .didomi-popup-footer .didomi-popup-actions .standard-button {
#     min-height: 2.625rem!important;
# }
#
# #didomi-host .didomi-components-radio__option:hover {
#     background-color: #CBCCC7!important;
# }
#
# #didomi-host .didomi-components-radio__option.didomi-components-radio__option--disagree,
# #didomi-host .didomi-components-radio__option.didomi-components-radio__option--agree {
#     border-radius: .125rem!important;
#     font-weight: 400!important;
#     align-items: center!important;
#     display: flex!important;
#     box-shadow: none!important;
#     padding-left: .5rem!important;
#     padding-right: .5rem!important;
#     border-width: .125rem!important;
#     border-style: solid!important;
#
# }
#
# #didomi-host .didomi-components-radio__option.didomi-components-radio__option--disagree {
#     border-color: #d62f2f!important;
#     background-color: #fff0f0!important;
#     color: #d62f2f!important;
# }
#
# #didomi-host .didomi-components-radio__option.didomi-components-radio__option--agree {
#     border-color: #0c990c!important;
#     background-color: #ebfaeb!important;
#     color: #0c990c!important;
#     font-weight: 400!important;
# }
#
# #didomi-host .didomi-components-radio__option>svg {
#     border-radius: 50%!important;
#     height: 1rem!important;
#     width: 1rem!important;
#     padding: .0625rem!important;
#     font-size: .5rem!important;
#     border-color:#d62f2f!important;
#     background-color:#d62f2f!important;
# }
#
# #didomi-host .didomi-components-radio__option.didomi-components-radio__option--agree>svg {
#     border-color: #0c990c!important;
#     background-color: #0c990c!important;
# }
#
# #didomi-host .didomi-components-accordion .label-click {
#     color: #145bc7!important;
#     font-weight: 400!important;
#     display: flex!important;
#     flex-direction: row-reverse!important;
#     margin-bottom: .5rem!important;
# }
#
# #didomi-host .didomi-consent-popup-preferences-purposes .didomi-consent-popup-view-vendors-list .didomi-consent-popup-view-vendors-list-link {
#       color: #145bc7!important;
#       background-color: transparent!important;
#       box-shadow: none!important;
#       border: none!important;
#       font-size: 1rem!important;
# }
#
# #didomi-host .didomi-consent-popup-preferences-purposes .didomi-consent-popup-view-vendors-list .didomi-consent-popup-body__title {
#     color: #121212;
#     font-size: 1rem!important;
#     text-transform: lowercase!important;
#     margin-bottom: 1rem!important;
# }
#
# #didomi-host .didomi-popup-header {
#     padding: 1rem .5rem!important;
#     border-bottom: .0725rem solid #e5e6e1!important;
# }
#
# #didomi-host .didomi-popup-header span {
#     font-size: 1.25rem!important;
#     line-height: 1.5rem!important;
# }
#
# #didomi-host a.didomi-no-link-style {
#     font-size: 1.5rem!important;
#     line-height: 1.5rem!important;
#     color: #141414!important;
#     text-shadow: m¡none!important;
#     font-weight: 700!important;
#     padding: 0!important;
# }
#
# #didomi-host .didomi-consent-popup-body {
#     padding: 1rem .5rem 0!important;
# }
#
# #didomi-host .didomi-consent-popup-preferences-purposes-features {
#     margin-top: 2rem!important;
# }
#
# #didomi-host .didomi-popup-footer {
#     padding: 1rem .5rem 1rem!important;
#     flex-direction: column-reverse!important;
# }
#
# #didomi-host .didomi-consent-popup-body__explanation {
#     margin-bottom: 1.5rem!important;
# }
#
# #didomi-host .didomi-consent-popup-preferences-purposes .didomi-consent-popup-view-vendors-list {
#     flex-direction: column!important;
#     align-items: flex-start!important;
#     margin-bottom: 0!important;
# }
#
# #didomi-host .didomi-consent-popup-preferences-purposes .didomi-consent-popup-view-vendors-list .didomi-consent-popup-view-vendors-list-link {
#         padding: 0!important;
# }
#
# #didomi-host .didomi-components-skip-link {
#     display: none!important;
# }
# #didomi-host .didomi-mobile .didomi-consent-popup-preferences-purposes .didomi-consent-popup-footer .didomi-consent-popup-actions {
#     flex-direction: column-reverse!important;
#     width: 100%!important;
# }
#
# #didomi-host .didomi-popup-footer .didomi-popup-actions .highlight-button,
# #didomi-host .didomi-popup-footer .didomi-popup-actions .standard-button {
#     margin-bottom: .5rem!important;
#     margin-right: 0!important;
#     width: calc(100vw - 1rem);
# }
#
# #didomi-host .didomi-consent-popup-body__title::first-letter {
#     text-transform: uppercase!important;
# }
#
# .didomi-components-accordion .didomi-user-information-trigger span {
#     font-size: 1rem!important;
# }
#
# #didomi-host .didomi-exterior-border,
# #didomi-host .didomi-popup-container {
#     border-radius: 0!important;
#     border-width: 0!important;
#     padding: 0!important;
# }
#
# #didomi-host .didomi-popup-container {
#     max-width: 46.5rem;
# }
#
# #didomi-host .didomi-popup-backdrop {
#     background-color: rgba(20, 20, 20, 0.8)!important;
# }
#
# #didomi-host .didomi-consent-popup-preferences-purposes .didomi-consent-popup-view-vendors-list {
#     text-align: left!important;
# }
#
# #didomi-host .didomi-mobile .didomi-consent-popup-preferences-purposes .didomi-consent-popup-footer {
#     background-color: #f4f5f2;
#     bottom: 0;
#     position: sticky;
# }
#
# #didomi-host .didomi-mobile #didomi-notice.didomi-regular-notice .didomi-notice__interior-border {
#     border-top-width: 0!important;
#     padding: .5rem;
# }
#
# #didomi-host #didomi-notice.didomi-regular-notice .didomi-notice-view-partners-link {
#     display: none!important;
#     }
#
# @media screen and (min-width: 20rem) {
#     .didomi-notice__interior-border .didomi-notice-text {
#         border-top-width: 0!important;
#         margin-right: 0!important;
#         max-height: calc(40vh - 2.75rem);
#         overflow-y: scroll;
#         width: auto!important;
#     }
# }
#
#
# #didomi-host {
#     background-color: rgba(20, 20, 20, 0.8);
#     height: 100vh;
#     position: fixed;
#     width: 100vw;
#     z-index: 8;
#
#     @media screen and (min-width: 48rem) {
#         position: absolute;
#         background-color: transparent;
#
#     }
# }
#
# #didomi-host[aria-hidden="true"] {
#     height: auto;
#     width: auto;
#
# }
#
# #didomi-host .didomi-screen-xsmall #didomi-notice.didomi-regular-notice #buttons.multiple {
#     flex-direction: column-reverse!important;
#     display: -webkit-flex!important;
#     -webkit-flex-direction: column-reverse!important;
#     margin-top: 0;
#     padding-top: 1rem!important;
#     padding-bottom: 1rem!important;
#
# }
#
# @media screen and (max-width: 20rem) {
#
#     #didomi-host .didomi-screen-xsmall #didomi-notice.didomi-regular-notice #buttons.multiple {
#         padding-bottom: 1rem!important;
#
#     }
#
# }
#
# #didomi-host .didomi-screen-xsmall #didomi-notice.didomi-regular-notice #buttons.multiple button {
#     margin-bottom: 0;
# }
#
# #didomi-host .didomi-consent-popup-preferences-purposes-features > div {
#     text-transform: lowercase;
#
# }
#
# @media screen and (min-width: 48rem) {
#
#     #didomi-host #didomi-notice.didomi-regular-notice {
#         width: 100%!important;
#
#     }
#
#     .didomi-vendors-details-purposes-consent ul {
#         list-style: inside;
#         margin-top: 1rem;
#     }
#
#     #didomi-host .didomi-consent-popup-preferences-vendors .didomi-consent-popup-container-click-all {
#         padding-left: 1rem;
#         padding-right: 1.5rem;
#     }
#
#     #didomi-host .didomi-consent-popup-preferences-vendors .didomi-consent-popup-container-click-all .didomi-consent-popup-vendor__name {
#         font-size: 1.125rem;
#     }
#
#     #didomi-host .didomi-consent-popup-preferences-vendors .didomi-consent-popup-body_vendors-list {
#         padding-right: .5625rem!important;
#     }
#
#     #didomi-host .didomi-consent-popup-preferences-purposes .didomi-consent-popup-data-processing__purpose_actions {
#         background-color: transparent!important;
#         padding: 1rem 0 1rem 1rem!important;
#     }
#
#     #didomi-host {
#         background-color: transparent;
#         height: auto;
#         width: auto;
#     }
#
#     .didomi-notice__interior-border .didomi-notice-text {
#         max-height: unset;
#         overflow-y: auto;
#     }
#
#     #didomi-host .didomi-popup-footer .didomi-popup-actions .highlight-button,
#     #didomi-host .didomi-popup-footer .didomi-popup-actions .standard-button {
#         width: auto;
#     }
#
#     #didomi-host .didomi-consent-popup-preferences .didomi-consent-popup-data-processing {
#         flex-direction: row !important;
#     }
#
#     #didomi-host .didomi-popup-header {
#         border-bottom-width: 0!important;
#         padding: 1.5rem!important;
#     }
#
#     #didomi-host .didomi-consent-popup-body {
#         padding: 0 1.5rem 1rem!important;
#     }
#
#     #didomi-host .didomi-consent-popup-preferences-purposes-features {
#         margin-top: 2.5rem!important;
#     }
#
#     #didomi-host a:not(.didomi-no-link-style) {
#         display: inline!important;
#     }
#
#     #didomi-host .didomi-consent-popup-preferences-purposes .didomi-consent-popup-view-vendors-list {
#         flex-direction: row!important;
#     }
#
#     #didomi-host .didomi-consent-popup-preferences-purposes .didomi-consent-popup-view-vendors-list .didomi-consent-popup-body__title {
#         margin-bottom: 0!important;
#     }
#
#     #didomi-host .didomi-popup-footer {
#         padding: 1rem 1.5rem!important;
#         flex-direction: row!important;
#     }
#
#     #didomi-host .didomi-popup-footer .didomi-logo-icon {
# 	    margin-left: 0!important;
#     }
#
#     #didomi-host .didomi-components-radio__option, #didomi-host .didomi-popup-footer .didomi-popup-actions button {
#         width: auto!important;
#     }
#
#     #didomi-host .didomi-mobile .didomi-consent-popup-preferences-purposes .didomi-consent-popup-footer .didomi-consent-popup-actions {
#         flex-direction: row!important;
#         width: auto!important;
#     }
#
#     #didomi-host .didomi-popup-footer .didomi-popup-actions button.standard-button,
#     #didomi-host .didomi-popup-footer .didomi-popup-actions .highlight-button,
#     #didomi-host .didomi-popup-footer .didomi-popup-actions .highlight-button  {
#         margin-bottom: 0!important;
#     }
#
#     #didomi-host .didomi-popup-footer .didomi-popup-actions button.standard-button {
#         margin-right: .5rem!important;
#     }
#
#     #didomi-host .didomi-mobile .didomi-consent-popup-preferences-purposes .didomi-consent-popup-footer .didomi-consent-popup-actions {
#         padding: 0;
#     }
#
# }
#
#
# @media screen and (min-width: 62rem) {
#
#     #didomi-host .didomi-notice-banner {
#         margin: auto!important;
#         bottom: 3rem!important;
#         border-radius: 0.125rem!important;
#         box-shadow: 0 .5rem 2rem .125rem rgba(102, 102, 100, 0.4)!important;
#         border-top: none!important;
#
#     }
#
#     .didomi-notice-banner.shape-banner {
#         background-color: #fff0f9!important;
#         padding:0!important;
#
#     }
#
#     .didomi-regular-notice.shape-banner .didomi-notice__interior-border {
#         flex-direction: column!important;
#         align-items: flex-start!important;
#         padding: 1.5rem!important;
#
#     }
#
#     .didomi-notice-text span br {
#         display: none!important;
#
#     }
#
#     .didomi-notice-text a {
#         font-weight: 700!important;
#
#     }
#
#     #didomi-notice.didomi-regular-notice.shape-banner #buttons.multiple {
#         padding-left: 0!important;
#
#     }
#
#     .didomi-regular-notice .multiple .didomi-button-standard {
#         padding-left: 0!important;
#
#     }
#
# }
#
# @media screen and (min-width: 62rem) and (max-width: 87.4rem) {
#
#     #didomi-host #didomi-notice.didomi-regular-notice {
#         width: auto!important;
#         margin-left: calc((100vw - 62rem)/2) !important;
#         margin-right: calc((100vw - 62rem)/2) !important;
#
#
#     }
#
# }
#
# @media screen and (min-width: 87.5rem) {
#
#     #didomi-host #didomi-notice.didomi-regular-notice {
#         width: 80rem!important;
#
#     }
#
# }
#   </style><div aria-hidden="true" data-nosnippet="true" id="didomi-host"><div class="notranslate didomi-screen-medium didomi-consent-popup__645b65e6-0665-4634-b4e4-98e7024b6598"></div></div>
# <script>
#     var utag_data = {"page":{"section":"portal","subSection":"listing","name":"viewResults","language":"es","category":"","subCategory":"","subSubCategory":"","template":"resultList","position":""},"user":{"status":"2"},"response":{"statusCode":"200","loadBalancer":"web"},"list":{"ads":[{"adId":"25189292","isFavourite":"0","owner":{"type":"1"}},{"adId":"102887291","isFavourite":"0","owner":{"type":"2"}},{"adId":"37241445","isFavourite":"0","owner":{"type":"1"}},{"adId":"102745459","isFavourite":"0","owner":{"type":"2"}},{"adId":"95648643","isFavourite":"0","owner":{"type":"1"}},{"adId":"102680628","isFavourite":"0","owner":{"type":"2"}},{"adId":"102934061","isFavourite":"0","owner":{"type":"1"}},{"adId":"102686078","isFavourite":"0","owner":{"type":"2"}},{"adId":"102933932","isFavourite":"0","owner":{"type":"1"}},{"adId":"102329049","isFavourite":"0","owner":{"type":"2"}},{"adId":"102933836","isFavourite":"0","owner":{"type":"1"}},{"adId":"102332311","isFavourite":"0","owner":{"type":"2"}},{"adId":"86671755","isFavourite":"0","owner":{"type":"1"}},{"adId":"102402081","isFavourite":"0","owner":{"type":"2"}},{"adId":"102933771","isFavourite":"0","owner":{"type":"2"}},{"adId":"102220975","isFavourite":"0","owner":{"type":"2"}},{"adId":"95318127","isFavourite":"0","owner":{"type":"2"}},{"adId":"92566453","isFavourite":"0","owner":{"type":"2"}},{"adId":"102933418","isFavourite":"0","owner":{"type":"2"}},{"adId":"92113151","isFavourite":"0","owner":{"type":"2"}},{"adId":"95195763","isFavourite":"0","owner":{"type":"1"}},{"adId":"99821717","isFavourite":"0","owner":{"type":"2"}},{"adId":"102933094","isFavourite":"0","owner":{"type":"1"}},{"adId":"89786986","isFavourite":"0","owner":{"type":"2"}},{"adId":"84405363","isFavourite":"0","owner":{"type":"1"}},{"adId":"102934161","isFavourite":"0","owner":{"type":"2"}},{"adId":"27223232","isFavourite":"0","owner":{"type":"1"}},{"adId":"91679748","isFavourite":"0","owner":{"type":"1"}},{"adId":"102932945","isFavourite":"0","owner":{"type":"2"}},{"adId":"36040348","isFavourite":"0","owner":{"type":"1"}}],"agencies":[],"totalResult":"6165","currentPageNumber":"1","totalPageNumber":"206","type":"officialZone","orderBy":"relevance"},"search":{"operation":"2","typology":"1","geo":{"type":"OFFICIAL_ZONE","locationId":"0-EU-ES-28-07-001-079","locationLevel":"6"},"orderBy":"relevance-desc"},"markup":{"xtPage":""},"correlation":{"id":"bb315fe4-9360-4ddc-928b-4e8f792004fb","session":"84c35763-1aaf-4269-889c-ff8416a8bae1"},"event":{"id":"","type":"","name":"","action":"","role":"","user_role":"","channel":"","origin":"","outcome":"","hash":"","markup":{"xtPage":"","name":"","category":"","subCategory":"","subSubCategory":""},"productType":"","agencyNames":[],"transactionId":""},"didomiVendorsConsent":"","post":{"id":"90be6ddf-847c-4081-bf84-537fee8f5c27","time":"1697972909427"},"alert":{"savedSearch":{"id":"","isGeneric":"0"}}};
# 	var dataLayerContext = utag_data;
#
#
#         window.utag_cfg_ovrd = { noview: true };
#
#     window.utag_data = utag_data;
# </script>
# <script>
#     (function(a,b,c,d){
#         a='//dp.idealista.com/es-portal/prod/utag.js';
#         b=document;c='script';d=b.createElement(c);d.onload=function () { window.idealistaUtag && window.idealistaUtag.init() };d.src=a;d.type='text/java'+c;d.defer=true;
#         a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);
#     })();
# </script>
# <script>
#     function onInitIdealistaUtag() {
#         window.utag.view(window.utag_data);
#     }
#
#     if (window.idealistaUtag) {
#         window.idealistaUtag.onInit(onInitIdealistaUtag);
#     }
# </script>
# <header class="help-center ide-header" id="main-header">
# <div class="col-ide-lg-12 col-ide-xl-12 content extended-grid">
# <figure class="logo-container starter">
# <a class="id-logo" href="/"> <img alt="idealista" src="https://st3.idealista.com/static/common/img/idealista.svg" title="idealista"/></a>
# </figure>
# <nav>
# <div class="lang-selector lang-responsive">
# <span class="lang-selector--lang-selected icon-arrow-dropdown">
# <span class="flag lang-es"></span>
# <span class="lang-text">Español</span>
# </span>
# <ul class="lang-selector--lang-options" data-url-attribute="/user/update-user-language" data-user-authenticated="false">
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::ca" href="/ca/alquiler-viviendas/madrid-madrid/" id="idioma-ca" rel="nofollow" value="ca">
# <span>
# <span class="flag lang-ca"></span>Català
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::en" href="/en/alquiler-viviendas/madrid-madrid/" id="idioma-en" rel="nofollow" value="en">
# <span>
# <span class="flag lang-en"></span>English
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::fr" href="/fr/alquiler-viviendas/madrid-madrid/" id="idioma-fr" rel="nofollow" value="fr">
# <span>
# <span class="flag lang-fr"></span>Français
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::de" href="/de/alquiler-viviendas/madrid-madrid/" id="idioma-de" rel="nofollow" value="de">
# <span>
# <span class="flag lang-de"></span>Deutsch
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::it" href="/it/alquiler-viviendas/madrid-madrid/" id="idioma-it" rel="nofollow" value="it">
# <span>
# <span class="flag lang-it"></span>Italiano
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::pt" href="/pt/alquiler-viviendas/madrid-madrid/" id="idioma-pt" rel="nofollow" value="pt">
# <span>
# <span class="flag lang-pt"></span>Português
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::da" href="/da/alquiler-viviendas/madrid-madrid/" id="idioma-da" rel="nofollow" value="da">
# <span>
# <span class="flag lang-da"></span>Dansk
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::fi" href="/fi/alquiler-viviendas/madrid-madrid/" id="idioma-fi" rel="nofollow" value="fi">
# <span>
# <span class="flag lang-fi"></span>Suomi
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::no" href="/no/alquiler-viviendas/madrid-madrid/" id="idioma-no" rel="nofollow" value="no">
# <span>
# <span class="flag lang-no"></span>Norsk
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::nl" href="/nl/alquiler-viviendas/madrid-madrid/" id="idioma-nl" rel="nofollow" value="nl">
# <span>
# <span class="flag lang-nl"></span>Nederlands
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::pl" href="/pl/alquiler-viviendas/madrid-madrid/" id="idioma-pl" rel="nofollow" value="pl">
# <span>
# <span class="flag lang-pl"></span>Polski
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::ro" href="/ro/alquiler-viviendas/madrid-madrid/" id="idioma-ro" rel="nofollow" value="ro">
# <span>
# <span class="flag lang-ro"></span>Română
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::ru" href="/ru/alquiler-viviendas/madrid-madrid/" id="idioma-ru" rel="nofollow" value="ru">
# <span>
# <span class="flag lang-ru"></span>Русский
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::sv" href="/sv/alquiler-viviendas/madrid-madrid/" id="idioma-sv" rel="nofollow" value="sv">
# <span>
# <span class="flag lang-sv"></span>Svenska
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::el" href="/el/alquiler-viviendas/madrid-madrid/" id="idioma-el" rel="nofollow" value="el">
# <span>
# <span class="flag lang-el"></span>Ελληνικά
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::zh" href="/zh/alquiler-viviendas/madrid-madrid/" id="idioma-zh" rel="nofollow" value="zh">
# <span>
# <span class="flag lang-zh"></span>中文
# </span>
# </a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::idioma::cabecera::uk" href="/uk/alquiler-viviendas/madrid-madrid/" id="idioma-uk" rel="nofollow" value="uk">
# <span>
# <span class="flag lang-uk"></span>Українська
# </span>
# </a>
# </li>
# <li class="separator">
# <a data-click="1" data-markup="cambio::pais::cabecera::it" href="https://www.idealista.it/es/" title="">idealista.it</a>
# </li>
# <li>
# <a data-click="1" data-markup="cambio::pais::cabecera::pt" href="https://www.idealista.pt/es/" title="">idealista.pt</a>
# </li>
# </ul>
# </div>
# <ul class="no-logged-user-menu ide-main-menu" id="no-login-user-bar">
# <li class="ide-main-menu__adv-free" id="put-adv-free">
# <a data-click="1" data-markup="header-new-advert" href="/flow/publicar-anuncio">
# <span class="icon-pin">
# Pon tu anuncio gratis
# </span>
# </a>
# </li>
# <li id="your-account">
# <a class="icon-user-no-logged" data-click="1" data-markup="header-login" href="/login" rel="nofollow">
# <span class="icon-user-no-logged-text">Iniciar sesión</span>
# <span class="icon-user-no-logged-text-extrasmall-devices">Acceso</span>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# </header>
# <div id="wrapper">
# <div data-islogged="false" id="main">
# <div class="container extended-grid">
# <div class="listing-top">
# <ul class="breadcrumb-navigation" itemscope="" itemtype="http://schema.org/BreadcrumbList">
# <li class="breadcrumb-navigation-element" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a href="/" itemprop="item">
# <span itemprop="name">idealista</span>
# </a>
# <meta content="1" itemprop="position"/>
# </li>
# <li class="breadcrumb-navigation-element" data-location-id="0-EU-ES-28" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a href="/alquiler-viviendas/madrid-provincia/" itemprop="item">
# <span itemprop="name">Madrid provincia</span>
# </a>
# <span class="breadcrumb-navigation-element-info">8.145</span>
# <meta content="2" itemprop="position"/>
# </li>
# <li class="breadcrumb-navigation-element inactive" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <span class="breadcrumb-navigation-current-level arrow-down" itemprop="name" role="button">Madrid</span>
# <span class="breadcrumb-navigation-close-button"></span>
# <div class="breadcrumb-dropdown breadcrumb-subitems">
# <ul class="breadcrumb-dropdown-list">
# <li class="breadcrumb-dropdown-upper-level">
# <a href="/">idealista</a>
# </li>
# <li class="breadcrumb-dropdown-upper-level">
# <a href="/alquiler-viviendas/madrid-provincia/">Madrid provincia</a>
# </li>
# <li class="breadcrumb-dropdown-element highlighted" data-location-id="0-EU-ES-28-07-001-079">
# <span class="breadcrumb-navigation-current-level">Madrid</span>
# <span class="breadcrumb-navigation-sidenote">6.165</span>
# <ul class="breadcrumb-dropdown-subitem-list">
# <li class="breadcrumb-dropdown-subitem-element-list" data-location-id="0-EU-ES-28-07-001-079-02">
# <a href="/alquiler-viviendas/madrid/arganzuela/">Arganzuela</a>
# <span class="breadcrumb-navigation-sidenote">219</span>
# </li>
# <li class="breadcrumb-dropdown-subitem-element-list" data-location-id="0-EU-ES-28-07-001-079-21">
# <a href="/alquiler-viviendas/madrid/barajas/">Barajas</a>
# <span class="breadcrumb-navigation-sidenote">32</span>
# </li>
# <li class="breadcrumb-dropdown-subitem-element-list" data-location-id="0-EU-ES-28-07-001-079-04">
# <a href="/alquiler-viviendas/madrid/barrio-de-salamanca/">Barrio de Salamanca</a>
# <span class="breadcrumb-navigation-sidenote">1.032</span>
# </li>
# <li class="breadcrumb-dropdown-subitem-element-list" data-location-id="0-EU-ES-28-07-001-079-11">
# <a href="/alquiler-viviendas/madrid/carabanchel/">Carabanchel</a>
# <span class="breadcrumb-navigation-sidenote">138</span>
# </li>
# <li class="breadcrumb-dropdown-subitem-element-list" data-location-id="0-EU-ES-28-07-001-079-01">
# <a href="/alquiler-viviendas/madrid/centro/">Centro</a>
# <span class="breadcrumb-navigation-sidenote">1.139</span>
# </li>
# <li class="breadcrumb-dropdown-subitem-element-list" data-location-id="0-EU-ES-28-07-001-079-05">
# <a href="/alquiler-viviendas/madrid/chamartin/">Chamartín</a>
# <span class="breadcrumb-navigation-sidenote">567</span>
# </li>
# <li class="breadcrumb-dropdown-subitem-element-list" data-location-id="0-EU-ES-28-07-001-079-07">
# <a href="/alquiler-viviendas/madrid/chamberi/">Chamberí</a>
# <span class="breadcrumb-navigation-sidenote">598</span>
# </li>
# <li class="breadcrumb-dropdown-subitem-element-list" data-location-id="0-EU-ES-28-07-001-079-15">
# <a href="/alquiler-viviendas/madrid/ciudad-lineal/">Ciudad Lineal</a>
# <span class="breadcrumb-navigation-sidenote">189</span>
# </li>
# <li class="breadcrumb-dropdown-subitem-element-list" data-location-id="0-EU-ES-28-07-001-079-08">
# ...
# 				<input class="btn action" value='Enviar' type="submit" id="share-friend-send" disabled/>
# 			</fieldset>
#
# 			<input type="hidden" id="adId" name="share-to-friend-adId" value="{{=adId}}" />
# 			<input type="hidden" id="cookieEnabled" name="cookieEnabled" value="true" />
#
#
# 			<div class="d-none">
# 				<input type="text" value="" name="contact-mail">
# 			</div>
# 			{{:showForm}}
# 				<fieldset class="modal-share-feedback-buttons">
# 					{{picture.id}}
# 					<a href="" data-xiti-shared-n2="true" data-xiti-page="detalle::conversiones::form_compartir_foto" title="Compartir con más gente" class="anotherTime btn regular modal-share-with-others-button">Compartir con más gente</a>
# 					{{:picture.id}}
# 					<a href="" data-xiti-shared-n2="true" data-xiti-page="detalle::conversiones::form_compartir" title="Compartir con más gente" class="anotherTime btn regular modal-share-with-others-button">Compartir con más gente</a>
# 					{{/picture.id}}
# 					<a href="#" class="modal-share-close-button cancel">Cerrar</a>
# 					{{/showForm}}
# 				</fieldset>
# 		</form>
# 	</section>
#
# </script>
# <script id="listing-loading-tmpl" type="text/microtemplate">
#
# 	<div class="listing-loading">
# 	<div class="listing-loading-content">
# 		<div class="listing-loading-image">
# 			<img src="https://st3.idealista.com/static/common/release/modules/resources/img/id-spinner2.gif?20231020095014">
# 		</div>
# 		<div class="listing-loading-text">
# 			<p>Buscando...</p>
# 		</div>
# 	</div>
# </div>
#
#
# </script>
# <script id="carrousel-contact-slide" type="text/microtemplate">
# 	<div class="contact-slide" role="article">
# 		<img class="contact-slide__background-img" alt="" src="" />
# 		<div class="contact-slide__content"">
# 			<p class="contact-slide__title">¿Te interesa?</p>
# 			<button type="button" class="contact-slide__contact-btn">Contactar</button>
# 			<button type="button" class="fake-anchor action-discard contact-slide__discard-btn" data-role='add'>Descartar inmueble</button>
# 		</div>
# 	</div>
#
# </script>
# <script id="save-live-search-error" type="text/microtemplate">
#
# 	<div id="content">
# 		<div class="feedback warning">
# 			{{@errorMessages}}<span>{{=_val}}<span></br>{{/@errorMessages}}
# 		</div>
# 	</div>
# 	<div id="buttons">
# 		<a href="#" class="btn action cancel">Cerrar</a>
# 	<div>
#
# </script>
# <script id="expert-card-tpl" type="text/microtemplate">
#     <div class="expert-card card-{{=idx}}" data-commercialdataid="{{=commercialDataId}}">
#         <div class="head">
#             <div class="expert-multimedia">
#                 <div class="image-holder">
#                     {{hasImage}}
#                         <img src="{{=headImageUrl}}" alt="{{=agencyName}}" crossorigin="anonymous" />
#                     {{/hasImage}}
#                 </div>
#             </div>
#         </div>
#         <div class="info-container">
#             <div class="centrable">
#                 <div class="agency-logo" role="img">
#                     <img src="{{=logoUrl}}"/>
#                 </div>
#                 <h4 class="agency-link">
#                     <a class="item-link" href="{{=agencyUrl}}" title="">{{=agencyName}}</a>
#                 </h4>
#             </div>
#
#             <div class="expert-detail-top">
#                 {{showTotal}}
#                     <p class="expert-detail" title="{{=total}} inmuebles en esta zona">
#                         {{=total}} inmuebles en esta zona
#                     </p>
#                 {{/showTotal}}
#             </div>
#             <div class="expert-detail-bottom">
#                 {{showYears}}
#                     <p class="expert-detail" title="{{=years}} años en idealista">
#                         {{=years}} años en idealista
#                     </p>
#                 {{/showYears}}
#                 <p class="expert-detail karma karma-{{=karma}}">
#                     <span class="blob score-1"></span><span class="blob score-2"></span><span class="blob score-3"></span><span class="blob score-4"></span><span class="blob score-5"></span>
#                 </p>
#             </div>
#         </div>
#
#         <div class="contact-container">
#             <a class="js-contact">Valorar gratis tu inmueble</a>
#         </div>
#     </div>
# </script>
# <script id="expert-card-compact-tpl" type="text/microtemplate">
#     <div class="expert-card compact card-{{=idx}}" data-commercialdataid="{{=commercialDataId}}">
#         <a class="link-wrap" href="{{=agencyUrl}}" title="{{=agencyName}}">
#         <div class="head">
#             <div class="expert-multimedia">
#                 <div class="image-holder">
#                 </div>
#             </div>
#         </div><div class="info-container">
#             <div class="centrable">
#                 <div class="agency-logo">
#                     <img src="{{=logoUrl}}" crossorigin="anonymous" alt="{{=agencyName}}"/>
#                 </div>
#                 <h4 class="agency-link">
#                     <a class="item-link" href="{{=agencyUrl}}" title="{{=agencyName}}">{{=agencyName}}</a>
#                 </h4>
#             </div>
#             <div class="details">
#
#             {{showTotal}}
#                 <p class="expert-detail centrable">{{=total}} inmuebles en esta zona</p>
#             {{/showTotal}}
#
#             {{showYears}}
#                 <p class="expert-detail centrable">{{=years}} años en idealista</p>
#             {{/showYears}}
#             </div>
#         </div>
#         </a>
#     </div>
# </script>
# <script id="advertiser-info-header-content" type="text/microtemplate">
#
#     {{avatarUrl}}
#         <img src="{{=avatarUrl}}"/>
#     {{/avatarUrl}}
#
#     {{isAdProfessionalAndAgencyIsNotABank}}
#         <div class="advertiser-container">
#             <p class="advertiser-name">
#                 {{showAdvertiserName}}
#                     {{firstName}}
#                         {{=firstName}} {{=lastName}}
#                     {{/firstName}}
#                 {{/showAdvertiserName}}
#             </p>
#         {{:isAdProfessionalAndAgencyIsNotABank}}
#           <div class="advertiser-container">
#             <p class="advertiser-name__costumer">
#                 {{firstName}}
#                     {{isInvoiceAd}}
#                         {{=firstName}}
#                     {{:isInvoiceAd}}
#                         <strong>{{=firstName}}</strong>
#                     {{/isInvoiceAd}}
#                 {{/firstName}}
#             </p>
#         {{/isAdProfessionalAndAgencyIsNotABank}}
#
#         <div class="shortAdDescription">
#             <p class="ellipsis">{{=shortDescription}}</p>
#         </div>
#       </div>
#     </div>
# </script>
# <script id="advertiser-info-footer-content" type="text/microtemplate">
#     {{showPhoneContactMethod}}
#
#     {{:showPhoneContactMethod}}
#         <div class="contact-phones">
#             <div class="phone hide-phone">
#                 Puedes contactar con el anunciante por chat (no ha facilitado teléfono).
#             </div>
#         </div>
#     {{/showPhoneContactMethod}}
#
#
#     <div class="advertiser-data">
#
#
#         {{newDevelopmentDirectory}}
#             <div class="new-dev-directory-message">
#                 <div class="new-dev-directory-message">Ten a mano el código {0} al llamar</div>
#             </div>
#         {{/newDevelopmentDirectory}}
#     </div>
#
#     <div class="module-contact-gray contact-data-container">
#
#         {{agencyIsABank}}
#             <strong>{{=adTypologyName}} de banco</strong>
#             <input type="hidden" name="user-name" value="" />
#             <input type="hidden" name="agency"/>
#         {{:agencyIsABank}}
#             {{isAdProfessional}}
#                 <p class="professional-name">
#                     <span class="professional-name_type">
#                         {{isAdRealEstateDeveloper}}
#                             Promotora
#                         {{:isAdRealEstateDeveloper}}
#                             Profesional
#                         {{/isAdRealEstateDeveloper}}
#                     </span>
#
#                     <span class="professional-name_name">
#                         {{showProfessionalName}}
#                             {{firstName}}
#                                 {{=firstName}} {{=lastName}}
#                                 <input type="hidden" name="user-name" value="{{=firstName}} {{=lastName}}" />
#                             {{:firstName}}
#                                 {{=commercialName}}
#                                 <input type="hidden" name="user-name" value="{{=commercialName}}" />
#                             {{/firstName}}
#                         {{:showProfessionalName}}
#                             {{=commercialName}}
#                             <input type="hidden" name="user-name" value="{{=commercialName}}" />
#                         {{/showProfessionalName}}
#                     </span>
#                 </p>
#                 <input type="hidden" name="professional"/>
#                 {{:isAdProfessional}}
#
#                     <span class="icon-block"></span>
#
#                 <p class="txt-ref">
#                     {{firstName}}
#                         {{isInvoiceAd}}
#
#                         {{:isInvoiceAd}}
#                             Particular -
#                         {{/isInvoiceAd}}
#                         {{=firstName}}
#                         <input type="hidden" name="user-name" value="{{=firstName}} {{=lastName}}" />
#                     {{/firstName}}
#                 </p>
#             {{/isAdProfessional}}
#         {{/agencyIsABank}}
#
#         <p class="ad-reference">
#             <span class="name">Referencia del anuncio</span>
#             <span class="ref-txt">{{=referenceMessage}}</span>
#         </p>
#     </div>
#     <div class="module-contact-gray about-container">
#
#         {{showAboutAdvertiser}}
#         <div class="advertiser-name-container">
#             {{isVirtualMicrosite}}
#             <p class="about-advertiser-name" >
#                 {{=commercialNamePhraseBlock}}
#             </p>
#             {{:isVirtualMicrosite}}
#             <a class="about-advertiser-name" href="{{=advertiserNameLink}}" title="{{=commercialNamePhraseBlock}}">
#                 {{=commercialNamePhraseBlock}}
#             </a>
#             {{/isVirtualMicrosite}}
#
#             <p class="advertiser-name-location">{{=micrositeCityName}}</p>
#         </div>
#
#
#         <div class="about-advertiser">
#             {{mustShowLogo}}
#             <div class="advertiser-logo">
#                 <a href="{{=advertiserNameLink}}">
#                     <img src="{{=advertiserLogoUrl}}"
#                          data-ondemand-img="{{=advertiserLogoUrl}}"
#                          width="125"
#                          height="60"
#                          alt="{{=commercialNamePhraseBlock}}" />
#                 </a>
#             </div>
#             {{/mustShowLogo}}
#         </div>
#         {{/showAboutAdvertiser}}
#     </div>
# </script>
# <script id="typology_1" type="text/microtemplate">Hola, me interesa este piso y me gustaría hacer una visita.
# Un saludo</script>
# <script id="vv_typology_1" type="text/microtemplate">Hola, me interesa este piso y me gustaría hacer una visita guiada virtual.
# Un saludo</script>
# <script id="typology_2" type="text/microtemplate">Hola, me interesa este inmueble y me gustaría hacer una visita.
# Un saludo</script>
# <script id="vv_typology_2" type="text/microtemplate">Hola, me interesa este inmueble y me gustaría hacer una visita guiada virtual.
# Un saludo</script>
# <script id="typology_3" type="text/microtemplate">Hola, me interesa este inmueble y me gustaría hacer una visita.
# Un saludo</script>
# <script id="vv_typology_3" type="text/microtemplate">Hola, me interesa este inmueble y me gustaría hacer una visita guiada virtual.
# Un saludo</script>
# <script id="formatted-phone" type="text/microtemplate">
#     <a role="button"
#        aria-label="contact phone"
#        class="icon-phone hidden-contact-phones_formatted-phone _mobilePhone"
#        href="tel:{{=phoneNumber}}">
#         <span class="hidden-contact-phones_text">{{=formattedPhoneNumber}}</span>
#         <span tabindex="0" class="phone-type-info phone-type-info--hidden"></span>
#     </a>
# </script>
# <script src="https://st3.idealista.com/static/react/projects/listings/dist/245.2e54bd598f2005a86e70.js"></script><script src="https://st3.idealista.com/static/react/projects/listings/dist/246.d3de425c515c62493c02.js"></script><script src="https://st3.idealista.com/static/react/projects/listings/dist/listings.ca20564916c18c7ba18a.js"></script><script src="https://st3.idealista.com/static/react/projects/listings/dist/vendors.3abab745c08efc2058fb.js"></script><script src="https://st3.idealista.com/static/react/projects/listings/dist/306.2ff99c0ef009477d5f7b.js"></script><script src="https://st3.idealista.com/static/react/projects/listings/dist/307.de35c421f8d444f58afd.js"></script><script src="https://st3.idealista.com/static/react/projects/listings/dist/308.939757a0092e45bb775d.js"></script><script src="https://st3.idealista.com/static/react/projects/listings/dist/309.bdaf3a4e5db085e6af6f.js"></script><script src="https://st3.idealista.com/static/react/projects/listings/dist/310.11a858160463049ad78a.js"></script><script src="https://st3.idealista.com/static/react/projects/listings/dist/311.8a58ab0416003b959367.js"></script><script src="https://st3.idealista.com/static/react/projects/listings/dist/312.89e7af8054a4df99334b.js"></script><script src="https://st3.idealista.com/static/react/projects/listings/dist/313.8d47f000b66745fa54d9.js"></script><script src="https://st3.idealista.com/static/react/projects/listings/dist/314.ac013e77c3df97b953ac.js"></script><script src="https://st3.idealista.com/static/react/projects/listings/dist/315.bb162b62a870ef4eb569.js"></script><div><div class="rs-modal" data-testid="modal" id="Modal-basic-profile"><div class="rs-modal-dialog rs-modal-dialog-large rs-create-profile step-one"><div class="rs-modal-dialog-header" data-testid="modal-header"><h2 data-testid="subtitleH2">Preséntate para dar más confianza y recibir respuesta antes</h2><span class="svg-close"></span></div><div class="rs-modal-dialog-content" data-testid="modal-content"><div class="input"><label class="input_label" for="input-name">Nombre</label><input autocomplete="name" class="rs-input" data-testid="input" maxlength="40" type="text" value=""/></div><div class="avatar-uploader" data-testid="avatar-uploader"><span aria-level="2" role="heading">Foto de perfil (opcional)</span><p class="avatar-uploader-description"></p><div class="avatar-uploader-svg-container"><span class="icon-no-avatar"></span><figure class="rs-file-preview"><img/></figure><div class="avatar-uploader-svg-action"><div class="rs-input-file"><span class="file-name"></span><button class="rs-button rs-button_link rs-file-upload link-type-file" data-testid="button" type="button">Añadir foto</button><input accept="image/*" class="file-upload" style="display: none;" type="file"/></div><p class="avatar-uploader-text">Una buena foto transmite más confianza</p></div></div></div><div class="phone-input" id="phone-input"><div class="phone-code" role="region"><span class="phone-code-title">Teléfono</span><div class="phone-code-wrapper"><div class="phone-code-select-input"><div class="phone-code-fields"><button aria-haspopup="listbox" aria-labelledby="country-select-phone-code" class="phone-code-trigger"><span class="phone-code-prefix-text" id="country-select-phone-code">+34</span><i class="icon-arrow-dropdown"></i></button><input aria-label="Teléfono" autocomplete="tel" class="phone-code_input" data-message-pattern="" data-message-required="" data-pattern="$" data-pattern-international="" data-pattern-national="" data-validation="pattern " placeholder="" type="tel" value=""/></div></div><div class="phone-code-list"><div aria-labelledby="country-code" class="phone-code-popup" hidden="" id="phone-code-popup" role="listbox" tabindex="-1"><div class="phone-code-searcher" role="search"><i class="icon-search"></i><input class="search-prefix-input" placeholder="" type="search" value=""/></div><div class="phone-result-list"><ul class="phone-code-highlight-list show-highlights"><li class ...

# %%
df_1 = pd.DataFrame()

# %%
df_1 = get_rent_info(s)
df_1
# Out:
# ['', '2 hab.', '71 m²', 'Planta 5ª exterior con ascensor', '9 minutos', '']
# ['', '2 hab.', '134 m²', 'Planta 4ª exterior con ascensor', '18\xa0oct ', '']
# ['', '1 hab.', '35 m²', 'Planta 2ª interior con ascensor', '13 minutos', '']
# ['', '1 hab.', '38 m²', 'Planta 1ª exterior con ascensor', '']
# ['', '2 hab.', '135 m²', 'Bajo exterior sin ascensor', '56 minutos', '']
# ['', '4 hab.', '180 m²', ' exterior con ascensor', '']
# ['', '1 hab.', '70 m²', 'Planta 4ª exterior con ascensor', '1 hora', '']
# ['', '4 hab.', '151 m²', 'Planta 1ª exterior con ascensor', '']
# ['', '2 hab.', '45 m²', 'Planta 3ª exterior con ascensor', '1 hora', '']
# ['', '5 hab.', '448 m²', '']
# ['', '4 hab.', '176 m²', 'Planta 2ª exterior con ascensor', '1 hora', '']
# ['', '3 hab.', '100 m²', 'Planta 4ª exterior con ascensor', '']
# ['', '3 hab.', '87 m²', 'Planta 3ª exterior con ascensor', '2 horas', '']
# ['', '4 hab.', '247 m²', 'Planta 4ª exterior con ascensor', '']
# ['', '1 hab.', '55 m²', 'Planta 1ª interior con ascensor', '2 horas', '']
# ['', '3 hab.', '157 m²', 'Planta 5ª exterior con ascensor', '']
# ['', '2 hab.', '62 m²', 'Planta 3ª exterior con ascensor', '4 horas', '']
# ['', '3 hab.', '120 m²', 'Planta 1ª exterior con ascensor', '']
# ['', '1 hab.', '59 m²', 'Planta 4ª exterior con ascensor', '6 horas', '']
# ['', '2 hab.', '174 m²', 'Planta 2ª exterior con ascensor', '']
# ['', '2 hab.', '85 m²', 'Planta 2ª exterior con ascensor', '13 horas', '']
# ['', '1 hab.', '43 m²', 'Planta 1ª exterior con ascensor', '']
# ['', '2 hab.', '70 m²', 'Bajo exterior sin ascensor', '13 horas', '']
# ['', '30 m²', 'Bajo interior sin ascensor', '']
# ['', '1 hab.', '70 m²', 'Planta 5ª exterior con ascensor', '14 horas', '']
# ['', '2 hab.', '85 m²', 'Planta 2ª exterior con ascensor', '36 minutos', '']
# ['', '3 hab.', '130 m²', 'Planta 4ª exterior con ascensor', '15 horas', '']
# ['', '2 hab.', '67 m²', 'Planta 1ª exterior sin ascensor', '']
# ['', '1 hab.', '82 m²', 'Planta 2ª exterior con ascensor', '14 horas', '']
# ['', '2 hab.', '100 m²', 'Planta 5ª interior con ascensor', '20\xa0oct ', '']
#                                             Direction       Price  \
# 0            \nPiso en Lavapiés-Embajadores, Madrid\n  1.400€/mes
# 1                  \nPiso en Pavia, Palacio, Madrid\n  2.800€/mes
# 2   \nPiso en calle de Manuela Malasaña, 28, Malas...    850€/mes
# 3   \nPiso en calle Corral de Almaguer, 12, Ensanc...    799€/mes
# 4   \nDúplex en calle de Agustín Durán, 29, Guinda...  1.800€/mes
# 5   \nPiso en avenida de Valdemarín, Valdemarín, M...  2.750€/mes
# 6        \nPiso en albadalejo, 46, Simancas, Madrid\n    850€/mes
# 7                       \nPiso en Argüelles, Madrid\n  2.400€/mes
# 8                         \nPiso en Chopera, Madrid\n  1.070€/mes
# 9   \nChalet pareado en Conde Orgaz-Piovera, Madrid\n  4.800€/mes
# 10  \nPiso en carril del Conde, 81, Canillas, Madr...  3.700€/mes
# 11            \nPiso en Conde Orgaz-Piovera, Madrid\n  2.500€/mes
# 12  \nPiso en calle del Alcalde Sáinz de Baranda, ...  1.700€/mes
# 13            \nDúplex en San Juan Bautista, Madrid\n  4.100€/mes
# 14  \nPiso en calle de la Ruda, Lavapiés-Embajador...    900€/mes
# 15  \nPiso en Nuevos Ministerios-Ríos Rosas, Madrid\n  2.800€/mes
# 16  \nPiso en calle de la Hierbabuena, Berruguete,...  1.300€/mes
# 17         \nPiso en calle Alcalá, 84, Goya, Madrid\n  5.800€/mes
# 18  \nPiso en calle de Villanueva, Recoletos, Madr...  2.450€/mes
# 19  \nPiso en calle de Víctor Hugo, Chueca-Justici...  3.345€/mes
# 20  \nPiso en calle de San Nazario, 1, Prosperidad...  1.100€/mes
# 21  \nPiso en calle de Martínez, Berruguete, Madrid\n  1.550€/mes
# 22  \nPiso en calle de Bremen, 3, Guindalera, Madr...  2.150€/mes
# 23                     \nEstudio en Acacias, Madrid\n    790€/mes
# 24  \nPiso en calle de Francos Rodríguez, 33, Bell...  1.350€/mes
# 25  \nPiso en calle Alejandro Casona, Peñagrande, ...  1.400€/mes
# 26  \nPiso en calle la Rábida, 22, Bellas Vistas, ...  1.700€/mes
# 27  \nPiso en calle de Alejandro Morán, 8, Puerta ...    997€/mes
# 28  \nPiso en Av. de Menéndez Pelayo, 67, Niño Jes...  1.850€/mes
# 29                            \nPiso en Sol, Madrid\n  2.100€/mes
#
#                             m2                            Floor    Room  \
# 0                        71 m²  Planta 5ª exterior con ascensor  2 hab.
# 1                       134 m²  Planta 4ª exterior con ascensor  2 hab.
# 2                        35 m²  Planta 2ª interior con ascensor  1 hab.
# 3                        38 m²  Planta 1ª exterior con ascensor  1 hab.
# 4                       135 m²       Bajo exterior sin ascensor  2 hab.
# 5                       180 m²            exterior con ascensor  4 hab.
# 6                        70 m²  Planta 4ª exterior con ascensor  1 hab.
# 7                       151 m²  Planta 1ª exterior con ascensor  4 hab.
# 8                        45 m²  Planta 3ª exterior con ascensor  2 hab.
# 9                       448 m²                                   5 hab.
# 10                      176 m²  Planta 2ª exterior con ascensor  4 hab.
# 11                      100 m²  Planta 4ª exterior con ascensor  3 hab.
# 12                       87 m²  Planta 3ª exterior con ascensor  3 hab.
# 13                      247 m²  Planta 4ª exterior con ascensor  4 hab.
# 14                       55 m²  Planta 1ª interior con ascensor  1 hab.
# 15                      157 m²  Planta 5ª exterior con ascensor  3 hab.
# 16                       62 m²  Planta 3ª exterior con ascensor  2 hab.
# 17                      120 m²  Planta 1ª exterior con ascensor  3 hab.
# 18                       59 m²  Planta 4ª exterior con ascensor  1 hab.
# 19                      174 m²  Planta 2ª exterior con ascensor  2 hab.
# 20                       85 m²  Planta 2ª exterior con ascensor  2 hab.
# 21                       43 m²  Planta 1ª exterior con ascensor  1 hab.
# 22                       70 m²       Bajo exterior sin ascensor  2 hab.
# 23  Bajo interior sin ascensor                                    30 m²
# 24                       70 m²  Planta 5ª exterior con ascensor  1 hab.
# 25                       85 m²  Planta 2ª exterior con ascensor  2 hab.
# 26                      130 m²  Planta 4ª exterior con ascensor  3 hab.
# 27                       67 m²  Planta 1ª exterior sin ascensor  2 hab.
# 28                       82 m²  Planta 2ª exterior con ascensor  1 hab.
# 29                      100 m²  Planta 5ª interior con ascensor  2 hab.
#
#                                           Description
# 0   \nPiso exterior muy luminoso y tranquilo en ca...
# 1   \nEn alquiler y/o a la venta una propiedad esp...
# 2   \nBonito apartamento amueblado en el corazón d...
# 3   \n¡Sin comisiones de agencia!\n\n\nY AHORA ALQ...
# 4   \nAlquilamos, como particulares (no lo gestion...
# 5   \nFantástico bajo con terraza en Valdemarin\nE...
# 6   \nFantástico apartamento de 40 metros, un dorm...
# 7   \nLuminoso y amplio piso en Argüelles en alqui...
# 8   \nPropietario particular ofrece excelente inmu...
# 9   \nColomba Boutique Inmobiliaria alquila, Chale...
# 10  \nDISTRIBUCIÓN:\nVivienda con 4 dormitorios y ...
# 11  \nColomba Boutique Inmobiliaria, alquila EN EX...
# 12  \n¡ABSTENERSE AGENCIAS! Preciosa vivienda con ...
# 13  \nEXCELENTE PISO REFORMADO ALTAS CALIDADES\n\n...
# 14  \nPENDIENTE REPORTAJE FOTOGRAFICO\nDISPONIBLE ...
# 15  \nPiso de 3 dormitorios y 2 baños\nEngel & Völ...
# 16  \nMagnifica vivienda en alquiler de 2 dormitor...
# 17  \n"Alquiler por meses" "No se cobra comisión d...
# 18  \nALQUILER POR MESES (MINIMO 1 MES)\nPRECIO IN...
# 19  \nEspectacular apartamento exterior de 2 dormi...
# 20  \nAlquilo piso luminoso a un minuto del metro ...
# 21  \nServicheck Alquila Piso por Temporada en Mad...
# 22  \nPiso recién reformado, con dos espaciosas ha...
# 23  \nPara más información preguntar por Pablo Mar...
# 24  \nPiso amplio y muy luminoso, todo exterior, a...
# 25  \nVIVIENDA exterior 75 metros útiles, distribu...
# 26  \nParticular, directamente sin comisiones. Pis...
# 27  \nPARTICULAR-OPORTO. Sin comisión-REFORMA Inte...
# 28  \nPara más viviendas como está, visita nuestra...
# 29  \nPiso en calle mayor a 100 de Sol. Dos habita...

# %%
df_1
df_1.to_csv("src/data/rentaMadrid2023_8.csv")

# %%
options = webdriver.ChromeOptions()
options.add_argument("start-maximized")

# options.add_argument("--headless")
proxy_username = 'fgrlkbxt'
proxy_password = 'cs01nzezlfen'
seleniumwire_options = {
    'proxy': {
        'http': f'http://{proxy_username}:{proxy_password}@185.199.229.156:7492',
        'verify_ssl': False,
    },
}
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
service = Service(executable_path='./src/utils/chromedriver.exe')
driver = webdriver.Chrome(options=options, service=service)
soup = []


stealth(driver,
        languages=["en-US", "en"],
        vendor="Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Inc.",
        renderer="Intel Iris OpenGL Engine",
        fix_hairline=True,
        )
for i in range(3,51):
        url = f"https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-{i}.htm"
        driver.get(url)
        soup.append(bs(driver.page_source))
        time.sleep(21)
        
driver.quit()

soup
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb Cell 14 line 1
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=13'>14</a> options.add_experimental_option('useAutomationExtension', False)
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=14'>15</a> service = Service(executable_path='./src/utils/chromedriver.exe')
# ---> <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=15'>16</a> driver = webdriver.Chrome(options=options, service=service)
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=16'>17</a> soup = []
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=19'>20</a> stealth(driver,
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=20'>21</a>         languages=["en-US", "en"],
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=21'>22</a>         vendor="Google Inc.",
#    (...)
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=25'>26</a>         fix_hairline=True,
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=26'>27</a>         )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/chrome/webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     DesiredCapabilities.CHROME["browserName"],
#      47     "goog",
#      48     options,
#      49     service,
#      50     keep_alive,
#      51 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/chromium/webdriver.py:53, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      49 self.service = service
#      51 self.service.path = DriverFinder.get_path(self.service, options)
# ---> 53 self.service.start()
#      55 try:
#      56     super().__init__(
#      57         command_executor=ChromiumRemoteConnection(
#      58             remote_server_addr=self.service.service_url,
#    (...)
#      64         options=options,
#      65     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/common/service.py:98, in Service.start(self)
#      91 def start(self) -> None:
#      92     """Starts the Service.
#      93
#      94     :Exceptions:
#      95      - WebDriverException : Raised either when it can't start the service
#      96        or when it can't connect to the service
#      97     """
# ---> 98     self._start_process(self._path)
#     100     count = 0
#     101     while True:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/common/service.py:204, in Service._start_process(self, path)
#     201         start_info.dwFlags = subprocess.CREATE_NEW_CONSOLE | subprocess.STARTF_USESHOWWINDOW
#     202         start_info.wShowWindow = subprocess.SW_HIDE
# --> 204     self.process = subprocess.Popen(
#     205         cmd,
#     206         env=self.env,
#     207         close_fds=close_file_descriptors,
#     208         stdout=self.log_output,
#     209         stderr=self.log_output,
#     210         stdin=PIPE,
#     211         creationflags=self.creation_flags,
#     212         startupinfo=start_info,
#     213         **self.popen_kw,
#     214     )
#     215     logger.debug("Started executable: `%s` in a child process with pid: %s", self._path, self.process.pid)
#     216 except TypeError:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:1950, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1948     if errno_num != 0:
#    1949         err_msg = os.strerror(errno_num)
# -> 1950     raise child_exception_type(errno_num, err_msg, err_filename)
#    1951 raise child_exception_type(err_msg)
#
# OSError: [Errno 8] Exec format error: './src/utils/chromedriver.exe'

# %%
def clean_csv(df_info):
    df_info["Direction"] = df_info["Direction"].str.replace("\n", " ")
    df_info["Description"] = df_info["Description"].str.replace("\n", " ")
    df_info["Room"] = df_info["Room"].str.replace("hab.", "")
    df_info["Price"] = df_info["Price"].str.replace("€/mes", "")
    df_info["m2"] = df_info["m2"].str.replace("m²", "")

    return df_info

# %%
df_1 = clean_csv(df_1)

# %%
df_1
# Out:
#                                             Direction  Price  \
# 0    Piso en calle de Hinojosa del Duque, 11, Hell...  1.200
# 1    Piso en calle de Alonso Cano, Nuevos Minister...  1.600
# 2     Piso en calle Alora, Palomeras sureste, Madrid     750
# 3     Piso en calle de Fúcar, Huertas-Cortes, Madrid   2.700
# 4    Piso en paseo de la Ermita del Santo, Puerta ...  1.200
# 5    Piso en calle Válgame Dios, Chueca-Justicia, ...  1.650
# 6    Piso en calle de los Estudios, Lavapiés-Embaj...  1.490
# 7    Piso en calle de Gravina, Chueca-Justicia, Ma...  1.290
# 8    Piso en paseo de la Ermita del Santo, 5, Puer...    850
# 9                  Chalet adosado en Palomas, Madrid   4.900
# 10   Piso en calle de Verdaguer y García, San Pasc...    950
# 11   Piso en calle de las Viñas del Rio, 16, Butar...    999
# 12   Piso en calle de Oña, Virgen del Cortijo - Ma...  1.100
# 13   Piso en calle Arroyo del Cañaveral, 66, El Ca...  1.750
# 14   Piso en calle Vargas, Nuevos Ministerios-Ríos...  1.450
# 15                           Piso en Aravaca, Madrid   1.650
# 16   Piso en calle Gran Via del sureste, Ensanche ...    850
# 17   Piso en avenida Cerro de Valdecahonde, 18, Ar...  1.370
# 18   Piso en avenida de Miguel Delibes, 19, El Cañ...    875
# 19    Piso en calle de José Abascal, Almagro, Madrid   8.800
# 20   Piso en plaza de Almuñecar, Casa de Campo, Ma...  1.200
# 21   Piso en calle Prieto Ureña, Nueva España, Mad...  5.500
# 22   Piso en C. Parador del Sol, 12, Comillas, Mad...  1.100
# 23   Chalet pareado en calle Olimpo, s/n, Conde Or...  8.500
# 24                           Piso en Almagro, Madrid   4.500
# 25     Piso en calle del Olvido, Almendrales, Madrid   1.100
# 26                 Piso en Juan Bravo, Lista, Madrid   1.650
# 27   Estudio en calle de San Romualdo, Simancas, M...  1.000
# 28   Estudio en calle de Ardemans, Guindalera, Mad...    750
# 29                           Piso en El Viso, Madrid   1.650
#
#                                  m2                              Floor  \
# 0                              117     Planta 6ª exterior con ascensor
# 1                               73     Planta 2ª interior con ascensor
# 2                               60     Planta 3ª exterior sin ascensor
# 3                              162               exterior con ascensor
# 4                               90     Planta 3ª exterior con ascensor
# 5                               70     Planta 3ª exterior con ascensor
# 6                               80     Planta 3ª exterior sin ascensor
# 7                               60          Bajo exterior con ascensor
# 8                               65   Entreplanta exterior con ascensor
# 9                              307
# 10                              45          Bajo exterior con ascensor
# 11                              61     Planta 1ª exterior con ascensor
# 12                             120     Planta 1ª exterior con ascensor
# 13                              90     Planta 5ª exterior con ascensor
# 14                              73     Planta 2ª exterior sin ascensor
# 15                             109     Planta 1ª exterior con ascensor
# 16                              57     Planta 3ª exterior con ascensor
# 17                              86     Planta 5ª exterior con ascensor
# 18                              55     Planta 6ª exterior con ascensor
# 19                             366     Planta 5ª exterior con ascensor
# 20                              75     Planta 2ª exterior con ascensor
# 21                             297     Planta 1ª exterior con ascensor
# 22                              49     Planta 4ª interior con ascensor
# 23                             650
# 24                             160     Planta 5ª exterior con ascensor
# 25                              52          Bajo exterior sin ascensor
# 26                              75     Planta 8ª exterior con ascensor
# 27  Planta 6ª exterior con ascensor
# 28  Planta 1ª interior con ascensor                           12 horas
# 29                              70     Planta 2ª exterior con ascensor
#
#       Room                                        Description
# 0       3    Piso de tres habitaciones amplias y cuarto de...
# 1       1    Se alquila en Chamberí, piso reformado para p...
# 2       2    Magnífico piso de 60m2. Consta de 2 dormitori...
# 3       3    Amplio y luminoso piso en Cortes en alquiler ...
# 4       3    Piso de 90m2 útiles, 104m2 construidos. Const...
# 5       3    Bonito piso exterior, con una suite, una habi...
# 6       1    Piso de 80m2 con una decoración unica de ladr...
# 7       1    Disponible para entrar en Septiembre. PATIO P...
# 8       2    Se alquila piso zona primcipe pio madrid rio ...
# 9       4    Colomba Boutique Inmobiliaria presenta en alq...
# 10      2    Por favor, NO CONTACTAR POR TELÉFONO, solo a ...
# 11      2    ¡Sin comisiones de agencia!   Y AHORA ALQUILA...
# 12      3    TECNOCASA ESTUDIO PINAR DE CHAMARTIN VENDE vi...
# 13      2    *** ALQUILER POR MESES*** Disponible a partir...
# 14      3    VIDEO DISPONIBLE! Piso exterior completamente...
# 15      3    ¡SERVICHECK ALQUILA HERMOSO PISO EN AVENIDA E...
# 16      1    VIDEO PUBLICIDAD! Piso exterior y parcialment...
# 17      2    ¡No te lo pienses! ¡Ven a visitarnos!   En el...
# 18      1    Vivienda nueva a estrena; Zonas comunes verde...
# 19      5    Piso de lujo reformado con magníficas calidad...
# 20      2    REDPISO PASEO DE LA FLORIDA alquila ésta fant...
# 21      5    INMOBILIARIA EMMANUEL PARA ENTRAR 1 de DICIEM...
# 22      1    Alquilar un piso con la reparación de diseño....
# 23      5    QUALITÉ Agence Immobilière Française présente...
# 24      2    Piso a estrenar en obra nueva en el barrio de...
# 25      1    Alquiler por temporadas "VIVIENDA A ESTRENAR"...
# 26      1    IMPRESIONANTE ÁTICO AMUEBLADO CON PISCINA EN ...
# 27  100 m²   SERVICHECK ALQUILA! PRECIOSO LOFT EN MADRID P...
# 28   35 m²   ¡FANTÁSTICO ESTUDIO AMUEBLADO EN BARRIO SALAM...
# 29      2    Piso reformado y luminoso vacío en alquiler E...
