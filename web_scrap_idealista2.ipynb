# %%
# %pip install webdriver-manager
# %pip install selenium-firefox
# Out:
# Collecting webdriver-manager
#   Obtaining dependency information for webdriver-manager from https://files.pythonhosted.org/packages/b1/51/b5c11cf739ac4eecde611794a0ec9df420d0239d51e73bc19eb44f02b48b/webdriver_manager-4.0.1-py2.py3-none-any.whl.metadata
#   Downloading webdriver_manager-4.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from webdriver-manager) (2.31.0)
# Collecting python-dotenv (from webdriver-manager)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: packaging in /Users/javierdealcazar/Library/Python/3.11/lib/python/site-packages (from webdriver-manager) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->webdriver-manager) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->webdriver-manager) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->webdriver-manager) (2023.7.22)
# Downloading webdriver_manager-4.0.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: python-dotenv, webdriver-manager
# Successfully installed python-dotenv-1.0.0 webdriver-manager-4.0.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting selenium-firefox
#   Obtaining dependency information for selenium-firefox from https://files.pythonhosted.org/packages/13/19/a13176802c130d1eb8734af4deff66181a7fab7cb030c4019d94066b0087/selenium_firefox-2.0.8-py3-none-any.whl.metadata
#   Downloading selenium_firefox-2.0.8-py3-none-any.whl.metadata (2.7 kB)
# Collecting geckodriver-autoinstaller>=0.1.0 (from selenium-firefox)
#   Downloading geckodriver_autoinstaller-0.1.0-py3-none-any.whl (5.6 kB)
# Collecting kproxy>=0.0.1 (from selenium-firefox)
#   Downloading kproxy-0.0.1-py3-none-any.whl (3.3 kB)
# Collecting noraise>=0.0.16 (from selenium-firefox)
#   Downloading noraise-0.0.16-py3-none-any.whl (4.2 kB)
# Requirement already satisfied: selenium>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-firefox) (4.14.0)
# Collecting selenium-browser>=0.0.12 (from selenium-firefox)
#   Downloading selenium_browser-0.0.15-py3-none-any.whl (14 kB)
# Collecting setuptools>=67.8.0 (from selenium-firefox)
#   Obtaining dependency information for setuptools>=67.8.0 from https://files.pythonhosted.org/packages/bb/26/7945080113158354380a12ce26873dd6c1ebd88d47f5bc24e2c5bb38c16a/setuptools-68.2.2-py3-none-any.whl.metadata
#   Downloading setuptools-68.2.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jsoncodable>=0.1.7 (from kproxy>=0.0.1->selenium-firefox)
#   Downloading jsoncodable-0.1.7-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium>=4.0.0->selenium-firefox) (2.0.6)
# Requirement already satisfied: trio~=0.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium>=4.0.0->selenium-firefox) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium>=4.0.0->selenium-firefox) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium>=4.0.0->selenium-firefox) (2023.7.22)
# Collecting k-selenium-cookies>=0.0.4 (from selenium-browser>=0.0.12->selenium-firefox)
#   Downloading k_selenium_cookies-0.0.4-py3-none-any.whl (4.9 kB)
# Collecting xpath-utils>=0.0.3 (from selenium-browser>=0.0.12->selenium-firefox)
#   Downloading xpath_utils-0.0.3-py3-none-any.whl (8.8 kB)
# Collecting jsonpickle>=2.0.0 (from jsoncodable>=0.1.7->kproxy>=0.0.1->selenium-firefox)
#   Obtaining dependency information for jsonpickle>=2.0.0 from https://files.pythonhosted.org/packages/d3/25/6e0a450430b7aa194b0f515f64820fc619314faa289458b7dfca4a026114/jsonpickle-3.0.2-py3-none-any.whl.metadata
#   Downloading jsonpickle-3.0.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting tldextract>=3.1.0 (from k-selenium-cookies>=0.0.4->selenium-browser>=0.0.12->selenium-firefox)
#   Obtaining dependency information for tldextract>=3.1.0 from https://files.pythonhosted.org/packages/3d/c3/e743f2a39cd38b0ea5af0d7833ba18bd73f79ea5348826d2a08d8b3ba5e4/tldextract-5.0.0-py3-none-any.whl.metadata
#   Downloading tldextract-5.0.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: attrs>=20.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-firefox) (23.1.0)
# Requirement already satisfied: sortedcontainers in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-firefox) (2.4.0)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-firefox) (3.4)
# Requirement already satisfied: outcome in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-firefox) (1.2.0)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-firefox) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium>=4.0.0->selenium-firefox) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium>=4.0.0->selenium-firefox) (1.7.1)
# Requirement already satisfied: requests>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tldextract>=3.1.0->k-selenium-cookies>=0.0.4->selenium-browser>=0.0.12->selenium-firefox) (2.31.0)
# Collecting requests-file>=1.4 (from tldextract>=3.1.0->k-selenium-cookies>=0.0.4->selenium-browser>=0.0.12->selenium-firefox)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Collecting filelock>=3.0.8 (from tldextract>=3.1.0->k-selenium-cookies>=0.0.4->selenium-browser>=0.0.12->selenium-firefox)
#   Obtaining dependency information for filelock>=3.0.8 from https://files.pythonhosted.org/packages/5e/5d/97afbafd9d584ff1b45fcb354a479a3609bd97f912f8f1f6c563cb1fae21/filelock-3.12.4-py3-none-any.whl.metadata
#   Downloading filelock-3.12.4-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: h11<1,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium>=4.0.0->selenium-firefox) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.1.0->tldextract>=3.1.0->k-selenium-cookies>=0.0.4->selenium-browser>=0.0.12->selenium-firefox) (3.3.0)
# Requirement already satisfied: six in /Users/javierdealcazar/Library/Python/3.11/lib/python/site-packages (from requests-file>=1.4->tldextract>=3.1.0->k-selenium-cookies>=0.0.4->selenium-browser>=0.0.12->selenium-firefox) (1.16.0)
# Downloading selenium_firefox-2.0.8-py3-none-any.whl (13.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 9.2 MB/s eta 0:00:00:00:0100:01
# Downloading setuptools-68.2.2-py3-none-any.whl (807 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 9.3 MB/s eta 0:00:00:00:0100:01
# Downloading jsonpickle-3.0.2-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 2.1 MB/s eta 0:00:00
# Downloading tldextract-5.0.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.0/97.0 kB 5.9 MB/s eta 0:00:00
# Downloading filelock-3.12.4-py3-none-any.whl (11 kB)
# Installing collected packages: xpath-utils, setuptools, noraise, jsonpickle, geckodriver-autoinstaller, filelock, requests-file, jsoncodable, tldextract, kproxy, k-selenium-cookies, selenium-browser, selenium-firefox
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.5.0
#     Uninstalling setuptools-65.5.0:
#       Successfully uninstalled setuptools-65.5.0
# Successfully installed filelock-3.12.4 geckodriver-autoinstaller-0.1.0 jsoncodable-0.1.7 jsonpickle-3.0.2 k-selenium-cookies-0.0.4 kproxy-0.0.1 noraise-0.0.16 requests-file-1.5.1 selenium-browser-0.0.15 selenium-firefox-2.0.8 setuptools-68.2.2 tldextract-5.0.0 xpath-utils-0.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install selenium-wire
# Out:
# Collecting selenium-wire
#   Downloading selenium_wire-5.1.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 874.6 kB/s eta 0:00:0000:0100:01
# Collecting blinker>=1.4 (from selenium-wire)
#   Obtaining dependency information for blinker>=1.4 from https://files.pythonhosted.org/packages/bf/2b/11bcedb7dee4923253a4a21bae3be854bcc4f06295bd827756352016d97c/blinker-1.6.3-py3-none-any.whl.metadata
#   Downloading blinker-1.6.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting brotli>=1.0.9 (from selenium-wire)
#   Obtaining dependency information for brotli>=1.0.9 from https://files.pythonhosted.org/packages/95/4e/5afab7b2b4b61a84e9c75b17814198ce515343a44e2ed4488fac314cd0a9/Brotli-1.1.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading Brotli-1.1.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: certifi>=2019.9.11 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire) (2023.7.22)
# Collecting kaitaistruct>=0.7 (from selenium-wire)
#   Downloading kaitaistruct-0.10-py2.py3-none-any.whl (7.0 kB)
# Collecting pyasn1>=0.3.1 (from selenium-wire)
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 643.1 kB/s eta 0:00:00a 0:00:01
# Collecting pyOpenSSL>=22.0.0 (from selenium-wire)
#   Obtaining dependency information for pyOpenSSL>=22.0.0 from https://files.pythonhosted.org/packages/f0/e2/f8b4f1c67933a4907e52228241f4bd52169f3196b70af04403b29c63238a/pyOpenSSL-23.2.0-py3-none-any.whl.metadata
#   Downloading pyOpenSSL-23.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyparsing>=2.4.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire) (3.1.1)
# Requirement already satisfied: pysocks>=1.7.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire) (1.7.1)
# Requirement already satisfied: selenium>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire) (4.14.0)
# Requirement already satisfied: wsproto>=0.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire) (1.2.0)
# Collecting zstandard>=0.14.1 (from selenium-wire)
#   Downloading zstandard-0.21.0-cp311-cp311-macosx_10_9_x86_64.whl (473 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.8/473.8 kB 591.8 kB/s eta 0:00:00a 0:00:01
# Collecting h2>=4.0 (from selenium-wire)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 895.7 kB/s eta 0:00:00:--:--
# Collecting hyperframe>=6.0 (from selenium-wire)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2>=4.0->selenium-wire)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Collecting cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0 (from pyOpenSSL>=22.0.0->selenium-wire)
#   Obtaining dependency information for cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0 from https://files.pythonhosted.org/packages/bb/c1/e8ca19a3e9ac5c867efa6f23ce0b119ad00a16b6019e49a298b8c1fe6866/cryptography-41.0.4-cp37-abi3-macosx_10_12_x86_64.whl.metadata
#   Downloading cryptography-41.0.4-cp37-abi3-macosx_10_12_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium>=4.0.0->selenium-wire) (2.0.6)
# Requirement already satisfied: trio~=0.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium>=4.0.0->selenium-wire) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium>=4.0.0->selenium-wire) (0.11.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wsproto>=0.14->selenium-wire) (0.14.0)
# Collecting cffi>=1.12 (from cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0->pyOpenSSL>=22.0.0->selenium-wire)
#   Obtaining dependency information for cffi>=1.12 from https://files.pythonhosted.org/packages/95/c8/ce05a6cba2bec12d4b28285e66c53cc88dd7385b102dea7231da3b74cfef/cffi-1.16.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading cffi-1.16.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: attrs>=20.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-wire) (23.1.0)
# Requirement already satisfied: sortedcontainers in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-wire) (2.4.0)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-wire) (3.4)
# Requirement already satisfied: outcome in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-wire) (1.2.0)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.0.0->selenium-wire) (1.3.0)
# Collecting pycparser (from cffi>=1.12->cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0->pyOpenSSL>=22.0.0->selenium-wire)
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Downloading blinker-1.6.3-py3-none-any.whl (13 kB)
# Downloading Brotli-1.1.0-cp311-cp311-macosx_10_9_x86_64.whl (446 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.2/446.2 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Downloading pyOpenSSL-23.2.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 2.7 MB/s eta 0:00:00
# Downloading cryptography-41.0.4-cp37-abi3-macosx_10_12_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 3.5 MB/s eta 0:00:0000:0100:01
# Downloading cffi-1.16.0-cp311-cp311-macosx_10_9_x86_64.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 kB 2.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: brotli, zstandard, pycparser, pyasn1, kaitaistruct, hyperframe, hpack, blinker, h2, cffi, cryptography, pyOpenSSL, selenium-wire
# Successfully installed blinker-1.6.3 brotli-1.1.0 cffi-1.16.0 cryptography-41.0.4 h2-4.1.0 hpack-4.0.0 hyperframe-6.0.1 kaitaistruct-0.10 pyOpenSSL-23.2.0 pyasn1-0.5.0 pycparser-2.21 selenium-wire-5.1.0 zstandard-0.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from seleniumwire import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.proxy import Proxy, ProxyType
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from selenium_stealth import stealth
from selenium.webdriver.firefox.options import Options as FirefoxOptions


from bs4 import BeautifulSoup as bs
import time
import pandas as pd
import random

# %%
driver = webdriver.Firefox()
driver.get("https://dev.to")

# %%
driver.quit()

# %% [markdown]
# proxies = pd.read_csv("./Free_Proxy_List.csv")
# print(proxies)
# list_ip = [x for x in proxies["ip"]]
# list_port = [x for x in proxies["port"]]
# list_proxies = []
# for x in range(0, len(list_ip)-1):
#     list_proxies.append(str(list_ip[x]) + ":" + str(list_port[x]))
# #list_proxies

# %% [markdown]
# df_1 = pd.DataFrame()
# # the list of proxy to rotate on
# PROXIES = list_proxies
# # randomly extract a proxy
# random_proxy = random.choice(PROXIES)
#
# random_ip, random_port = random_proxy.split(":")

# %%
#myProxy = random_proxy

df_1 = pd.DataFrame()
driver = webdriver.Firefox()

# %%
def get_rent_info(soup):
    rent_info = {
        "Direction": [],
        "Price": [],
        "m2": [],
        "Floor": [],
        "Room": [],
        "Description": []
    }
    item_info = soup.find_all('div', class_="item-info-container")
    rent_info["Direction"] = [x.find('a',class_="item-link").get_text() for x in item_info]
    rent_info["Price"] = [x.find('span',class_="item-price h2-simulated").get_text() for x in item_info]
    rent_info["Description"] = [x.find('div',class_="item-description description").get_text() for x in item_info]

    apart_detail = [x.find('div',class_="item-detail-char").get_text() for x in item_info]

    detail_list = [x.split('\n') for x in apart_detail]
    time.sleep(12)

    for elem in detail_list:
        print(elem)
        rent_info["Room"].append(elem[1])
        rent_info["m2"].append(elem[2])
        rent_info["Floor"].append(elem[3])

    df = pd.DataFrame(rent_info)
    return df

# %%
df = pd.DataFrame()

soup = []
df_info = pd.DataFrame()
URL = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/"
URL_2 ="https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-2.htm"
URL_3 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-3.htm"
URL_4 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-4.htm"
URL_5 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-5.htm"
URL_5 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-6.htm"
URL_6 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-7.htm"
URL_7 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-8.htm"

urls = [URL,URL_2,URL_3,URL_4,URL_5,URL_6,URL_7]

# scraping logic...
for url in urls:
    time.sleep(5)
    driver.get(url)
    time.sleep(15)
    soup.append((driver.page_source, "html.parser"))


driver.quit()

for s in soup:
    s = bs(s[0],"html.parser")
    df = pd.concat([df,get_rent_info(s)],ignore_index=True)
df_1.to_csv("rents.csv", index=False)
# Out:
# ['', '2 hab.', '65 m²', 'Planta 3ª interior con ascensor', '5 minutos', '']
# ['', '4 hab.', '200 m²', 'Planta 2ª exterior con ascensor', '']
# ['', '1 hab.', '30 m²', 'Entreplanta exterior con ascensor', '14 minutos', '']
# ['', '3 hab.', '120 m²', 'Bajo exterior con ascensor', '17\xa0oct ', '']
# ['', '2 hab.', '50 m²', 'Planta -1 interior sin ascensor', '1 hora', '']
# ['', '40 m²', 'Planta 2ª interior con ascensor', '']
# ['', '2 hab.', '77 m²', 'Planta 2ª exterior con ascensor', '1 hora', '']
# ['', '1 hab.', '73 m²', 'Planta 2ª interior con ascensor', '']
# ['', '3 hab.', '65 m²', 'Planta 4ª exterior sin ascensor', '1 hora', '']
# ['', '4 hab.', '270 m²', '']
# ['', '74 m²', 'Planta 3ª exterior con ascensor', '2 horas', '']
# ['', '3 hab.', '162 m²', ' exterior con ascensor', '']
# ['', '4 hab.', '250 m²', '3 horas', '']
# ['', '3 hab.', '70 m²', 'Planta 3ª exterior con ascensor', '']
# ['', '2 hab.', '105 m²', 'Entreplanta exterior con ascensor', '3 horas', '']
# ['', '1 hab.', '60 m²', 'Bajo exterior con ascensor', '']
# ['', '1 hab.', '35 m²', 'Bajo sin ascensor', '7 horas', '']
# ['', '5 hab.', '245 m²', 'Planta 1ª exterior con ascensor', '']
# ['', '30 m²', 'Planta 5ª exterior con ascensor', '7 horas', '']
# ['', '4 hab.', '307 m²', '']
# ['', '1 hab.', '45 m²', 'Planta 1ª exterior sin ascensor', '10 horas', '']
# ['', '2 hab.', '178 m²', 'Planta 3ª exterior con ascensor', '']
# ['', '2 hab.', '50 m²', 'Planta 2ª exterior sin ascensor', '10 horas', '']
# ['', '3 hab.', '109 m²', 'Planta 1ª exterior con ascensor', '']
# ['', '35 m²', 'Planta 11ª exterior con ascensor', '10 horas', '']
# ['', '2 hab.', '86 m²', 'Planta 5ª exterior con ascensor', '']
# ['', '1 hab.', '82 m²', 'Planta 1ª interior con ascensor', '10 horas', '']
# ['', '6 hab.', '482 m²', '19\xa0oct ', '']
# ['', '2 hab.', '60 m²', 'Planta 2ª exterior con ascensor', '10 horas', '']
# ['', '1 hab.', '85 m²', 'Planta 5ª exterior con ascensor', '']

# %%
s= bs(soup[0][0],"html.parser")

# %%
df_1 = pd.DataFrame()

# %%
df_1 = get_rent_info(s)
df_1
# Out:
# ['', '2 hab.', '65 m²', 'Planta 3ª interior con ascensor', '5 minutos', '']
# ['', '4 hab.', '200 m²', 'Planta 2ª exterior con ascensor', '']
# ['', '1 hab.', '30 m²', 'Entreplanta exterior con ascensor', '14 minutos', '']
# ['', '3 hab.', '120 m²', 'Bajo exterior con ascensor', '17\xa0oct ', '']
# ['', '2 hab.', '50 m²', 'Planta -1 interior sin ascensor', '1 hora', '']
# ['', '40 m²', 'Planta 2ª interior con ascensor', '']
# ['', '2 hab.', '77 m²', 'Planta 2ª exterior con ascensor', '1 hora', '']
# ['', '1 hab.', '73 m²', 'Planta 2ª interior con ascensor', '']
# ['', '3 hab.', '65 m²', 'Planta 4ª exterior sin ascensor', '1 hora', '']
# ['', '4 hab.', '270 m²', '']
# ['', '74 m²', 'Planta 3ª exterior con ascensor', '2 horas', '']
# ['', '3 hab.', '162 m²', ' exterior con ascensor', '']
# ['', '4 hab.', '250 m²', '3 horas', '']
# ['', '3 hab.', '70 m²', 'Planta 3ª exterior con ascensor', '']
# ['', '2 hab.', '105 m²', 'Entreplanta exterior con ascensor', '3 horas', '']
# ['', '1 hab.', '60 m²', 'Bajo exterior con ascensor', '']
# ['', '1 hab.', '35 m²', 'Bajo sin ascensor', '7 horas', '']
# ['', '5 hab.', '245 m²', 'Planta 1ª exterior con ascensor', '']
# ['', '30 m²', 'Planta 5ª exterior con ascensor', '7 horas', '']
# ['', '4 hab.', '307 m²', '']
# ['', '1 hab.', '45 m²', 'Planta 1ª exterior sin ascensor', '10 horas', '']
# ['', '2 hab.', '178 m²', 'Planta 3ª exterior con ascensor', '']
# ['', '2 hab.', '50 m²', 'Planta 2ª exterior sin ascensor', '10 horas', '']
# ['', '3 hab.', '109 m²', 'Planta 1ª exterior con ascensor', '']
# ['', '35 m²', 'Planta 11ª exterior con ascensor', '10 horas', '']
# ['', '2 hab.', '86 m²', 'Planta 5ª exterior con ascensor', '']
# ['', '1 hab.', '82 m²', 'Planta 1ª interior con ascensor', '10 horas', '']
# ['', '6 hab.', '482 m²', '19\xa0oct ', '']
# ['', '2 hab.', '60 m²', 'Planta 2ª exterior con ascensor', '10 horas', '']
# ['', '1 hab.', '85 m²', 'Planta 5ª exterior con ascensor', '']
#                                             Direction       Price  \
# 0   \nPiso en calle de los Fundadores, 23, Fuente ...  1.200€/mes
# 1   \nPiso en paseo de San Francisco de Sales, Val...  3.500€/mes
# 2           \nPiso en Canillas, Prosperidad, Madrid\n  1.545€/mes
# 3       \nPiso en calle de Serrano, El Viso, Madrid\n  2.600€/mes
# 4   \nPiso en calle del Cardenal Cisneros, 82, Tra...  1.300€/mes
# 5   \nEstudio en calle de Meléndez Valdés, Gaztamb...    900€/mes
# 6                 \nDúplex en Butron, Rosas, Madrid\n  1.150€/mes
# 7   \nPiso en calle de Alonso Cano, Nuevos Ministe...  1.600€/mes
# 8   \nPiso en carabanchel, 2, Puerta Bonita, Madrid\n    790€/mes
# 9   \nChalet adosado en calle de Rafael Villa, El ...  2.950€/mes
# 10  \nEstudio en calle miguel servet, 11, Lavapiés...  1.300€/mes
# 11  \nPiso en calle de Fúcar, Huertas-Cortes, Madr...  2.700€/mes
# 12  \nCasa o chalet independiente en avenida del C...  2.000€/mes
# 13  \nPiso en calle Válgame Dios, Chueca-Justicia,...  1.650€/mes
# 14  \nPiso en calle de Apodaca, Chueca-Justicia, M...  2.900€/mes
# 15  \nPiso en calle de Gravina, Chueca-Justicia, M...  1.290€/mes
# 16                  \nPiso en Ciudad Jardín, Madrid\n    930€/mes
# 17              \nPiso en Ventilla-Almenara, Madrid\n  4.500€/mes
# 18     \nEstudio en calle de Narváez, Ibiza, Madrid\n  1.000€/mes
# 19              \nChalet adosado en Palomas, Madrid\n  4.900€/mes
# 20  \nPiso en calle Topete, 5, Bellas Vistas, Madr...  1.000€/mes
# 21                        \nPiso en Palacio, Madrid\n  4.450€/mes
# 22  \nPiso en calle de la Coruña, 12, Cuatro Camin...  1.400€/mes
# 23                        \nPiso en Aravaca, Madrid\n  1.650€/mes
# 24  \nEstudio en calle de Cebreros, 88, Lucero, Ma...    910€/mes
# 25  \nPiso en avenida Cerro de Valdecahonde, 18, A...  1.370€/mes
# 26  \nDúplex en calle Cerro del Murmullo, 13, Ensa...  1.100€/mes
# 27  \nCasa o chalet independiente en calle de Ánge...  7.000€/mes
# 28  \nPiso en calle de Ponferrada, 35, Pilar, Madr...    950€/mes
# 29  \nPiso en calle Henri Dunant, 23, Nueva España...  2.250€/mes
#
#                                   m2                              Floor  \
# 0                              65 m²    Planta 3ª interior con ascensor
# 1                             200 m²    Planta 2ª exterior con ascensor
# 2                              30 m²  Entreplanta exterior con ascensor
# 3                             120 m²         Bajo exterior con ascensor
# 4                              50 m²    Planta -1 interior sin ascensor
# 5    Planta 2ª interior con ascensor
# 6                              77 m²    Planta 2ª exterior con ascensor
# 7                              73 m²    Planta 2ª interior con ascensor
# 8                              65 m²    Planta 4ª exterior sin ascensor
# 9                             270 m²
# 10   Planta 3ª exterior con ascensor                            2 horas
# 11                            162 m²              exterior con ascensor
# 12                            250 m²                            3 horas
# 13                             70 m²    Planta 3ª exterior con ascensor
# 14                            105 m²  Entreplanta exterior con ascensor
# 15                             60 m²         Bajo exterior con ascensor
# 16                             35 m²                  Bajo sin ascensor
# 17                            245 m²    Planta 1ª exterior con ascensor
# 18   Planta 5ª exterior con ascensor                            7 horas
# 19                            307 m²
# 20                             45 m²    Planta 1ª exterior sin ascensor
# 21                            178 m²    Planta 3ª exterior con ascensor
# 22                             50 m²    Planta 2ª exterior sin ascensor
# 23                            109 m²    Planta 1ª exterior con ascensor
# 24  Planta 11ª exterior con ascensor                           10 horas
# 25                             86 m²    Planta 5ª exterior con ascensor
# 26                             82 m²    Planta 1ª interior con ascensor
# 27                            482 m²                            19 oct
# 28                             60 m²    Planta 2ª exterior con ascensor
# 29                             85 m²    Planta 5ª exterior con ascensor
#
#       Room                                        Description
# 0   2 hab.  \nCALEFACCIÓN CENTRAL Y PLAZA DE GARAJE INCLUI...
# 1   4 hab.  \nCONTRATO DE TEMPORADA: MÁXIMO 11 MESES. WIFI...
# 2   1 hab.  \nESPECTACULAR APARTAMENTO EN PROSPERIDAD!\nAl...
# 3   3 hab.  \nAlquiler de magnifico piso con amplio jardín...
# 4   2 hab.  \nPrecioso apartamento de dos habitaciones, si...
# 5    40 m²  \nALQUILOFACIL MONCLOA alquila espectacular es...
# 6   2 hab.  \nSe alquila vivienda con casi 5 metros de alt...
# 7   1 hab.  \nSe alquila en Chamberí, piso reformado para ...
# 8   3 hab.  \nVivienda 58 m, totalmente reformada, Calefac...
# 9   4 hab.  \nChalet reformado adosado con anexo para serv...
# 10   74 m²  \nParticular alquila magnifico piso en la mejo...
# 11  3 hab.  \nAmplio y luminoso piso en Cortes en alquiler...
# 12  4 hab.  \nEspectacular chalet de obra seminueva con un...
# 13  3 hab.  \nBonito piso exterior, con una suite, una hab...
# 14  2 hab.  \n¡PISO EXTERIOR EN ALQUILER!\nHousinGo presen...
# 15  1 hab.  \nDisponible para entrar en Septiembre.\nPATIO...
# 16  1 hab.  \nDonpiso Retiro alquila precioso estudio de u...
# 17  5 hab.  \nAlquiler de maravilloso piso de 245 m2, exte...
# 18   30 m²  \nRENTAKASA ALQUILA, moderno estudio, exterior...
# 19  4 hab.  \nColomba Boutique Inmobiliaria presenta en al...
# 20  1 hab.  \nSe alquila completamente amueblado. Por favo...
# 21  2 hab.  \nMagnífico piso reformado de 178 m2 en la mej...
# 22  2 hab.  \nABSTENERSE AGENCIAS\n¿Estáis buscando vivir ...
# 23  3 hab.  \n¡SERVICHECK ALQUILA HERMOSO PISO EN AVENIDA ...
# 24   35 m²  \nTemporal: solo desde el 24 de octubre de 202...
# 25  2 hab.  \n¡No te lo pienses! ¡Ven a visitarnos!\n\n\nE...
# 26  1 hab.  \nLoft rental, one of the\nbest areas of the e...
# 27  6 hab.  \nEn la zona de Arturo Soria, al lado del Cond...
# 28  2 hab.  \nESPECTACULAR, piso de 2 dormitorios en 2ª pl...
# 29  1 hab.  \nApartamento de 85 m2 con terraza incluida. C...

# %%
df_1
df_1.to_csv("src/data/rentaMadrid2023_7.csv")

# %%
options = webdriver.ChromeOptions()
options.add_argument("start-maximized")

# options.add_argument("--headless")
proxy_username = 'fgrlkbxt'
proxy_password = 'cs01nzezlfen'
seleniumwire_options = {
    'proxy': {
        'http': f'http://{proxy_username}:{proxy_password}@185.199.229.156:7492',
        'verify_ssl': False,
    },
}
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
service = Service(executable_path='./src/utils/chromedriver.exe')
driver = webdriver.Chrome(options=options, service=service)
soup = []


stealth(driver,
        languages=["en-US", "en"],
        vendor="Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Inc.",
        renderer="Intel Iris OpenGL Engine",
        fix_hairline=True,
        )
for i in range(3,51):
        url = f"https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-{i}.htm"
        driver.get(url)
        soup.append(bs(driver.page_source))
        time.sleep(21)
        
driver.quit()

soup
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb Cell 14 line 1
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=13'>14</a> options.add_experimental_option('useAutomationExtension', False)
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=14'>15</a> service = Service(executable_path='./src/utils/chromedriver.exe')
# ---> <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=15'>16</a> driver = webdriver.Chrome(options=options, service=service)
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=16'>17</a> soup = []
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=19'>20</a> stealth(driver,
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=20'>21</a>         languages=["en-US", "en"],
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=21'>22</a>         vendor="Google Inc.",
#    (...)
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=25'>26</a>         fix_hairline=True,
#      <a href='vscode-notebook-cell:/Users/javierdealcazar/TheBridgeDataScience/TheBridgeJavierAlcazar/MisProyectos/EDA/test_idealista2.ipynb#X16sZmlsZQ%3D%3D?line=26'>27</a>         )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/chrome/webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     DesiredCapabilities.CHROME["browserName"],
#      47     "goog",
#      48     options,
#      49     service,
#      50     keep_alive,
#      51 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/chromium/webdriver.py:53, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      49 self.service = service
#      51 self.service.path = DriverFinder.get_path(self.service, options)
# ---> 53 self.service.start()
#      55 try:
#      56     super().__init__(
#      57         command_executor=ChromiumRemoteConnection(
#      58             remote_server_addr=self.service.service_url,
#    (...)
#      64         options=options,
#      65     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/common/service.py:98, in Service.start(self)
#      91 def start(self) -> None:
#      92     """Starts the Service.
#      93
#      94     :Exceptions:
#      95      - WebDriverException : Raised either when it can't start the service
#      96        or when it can't connect to the service
#      97     """
# ---> 98     self._start_process(self._path)
#     100     count = 0
#     101     while True:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/common/service.py:204, in Service._start_process(self, path)
#     201         start_info.dwFlags = subprocess.CREATE_NEW_CONSOLE | subprocess.STARTF_USESHOWWINDOW
#     202         start_info.wShowWindow = subprocess.SW_HIDE
# --> 204     self.process = subprocess.Popen(
#     205         cmd,
#     206         env=self.env,
#     207         close_fds=close_file_descriptors,
#     208         stdout=self.log_output,
#     209         stderr=self.log_output,
#     210         stdin=PIPE,
#     211         creationflags=self.creation_flags,
#     212         startupinfo=start_info,
#     213         **self.popen_kw,
#     214     )
#     215     logger.debug("Started executable: `%s` in a child process with pid: %s", self._path, self.process.pid)
#     216 except TypeError:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:1950, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1948     if errno_num != 0:
#    1949         err_msg = os.strerror(errno_num)
# -> 1950     raise child_exception_type(errno_num, err_msg, err_filename)
#    1951 raise child_exception_type(err_msg)
#
# OSError: [Errno 8] Exec format error: './src/utils/chromedriver.exe'

# %%
def clean_csv(df_info):
    df_info["Direction"] = df_info["Direction"].str.replace("\n", " ")
    df_info["Description"] = df_info["Description"].str.replace("\n", " ")
    df_info["Room"] = df_info["Room"].str.replace("hab.", "")
    df_info["Price"] = df_info["Price"].str.replace("€/mes", "")
    df_info["m2"] = df_info["m2"].str.replace("m²", "")

    return df_info

# %%
df_1 = clean_csv(df_1)

# %%
df_1
# Out:
#                                             Direction  Price  \
# 0    Piso en calle de Hinojosa del Duque, 11, Hell...  1.200
# 1    Piso en calle de Alonso Cano, Nuevos Minister...  1.600
# 2     Piso en calle Alora, Palomeras sureste, Madrid     750
# 3     Piso en calle de Fúcar, Huertas-Cortes, Madrid   2.700
# 4    Piso en paseo de la Ermita del Santo, Puerta ...  1.200
# 5    Piso en calle Válgame Dios, Chueca-Justicia, ...  1.650
# 6    Piso en calle de los Estudios, Lavapiés-Embaj...  1.490
# 7    Piso en calle de Gravina, Chueca-Justicia, Ma...  1.290
# 8    Piso en paseo de la Ermita del Santo, 5, Puer...    850
# 9                  Chalet adosado en Palomas, Madrid   4.900
# 10   Piso en calle de Verdaguer y García, San Pasc...    950
# 11   Piso en calle de las Viñas del Rio, 16, Butar...    999
# 12   Piso en calle de Oña, Virgen del Cortijo - Ma...  1.100
# 13   Piso en calle Arroyo del Cañaveral, 66, El Ca...  1.750
# 14   Piso en calle Vargas, Nuevos Ministerios-Ríos...  1.450
# 15                           Piso en Aravaca, Madrid   1.650
# 16   Piso en calle Gran Via del sureste, Ensanche ...    850
# 17   Piso en avenida Cerro de Valdecahonde, 18, Ar...  1.370
# 18   Piso en avenida de Miguel Delibes, 19, El Cañ...    875
# 19    Piso en calle de José Abascal, Almagro, Madrid   8.800
# 20   Piso en plaza de Almuñecar, Casa de Campo, Ma...  1.200
# 21   Piso en calle Prieto Ureña, Nueva España, Mad...  5.500
# 22   Piso en C. Parador del Sol, 12, Comillas, Mad...  1.100
# 23   Chalet pareado en calle Olimpo, s/n, Conde Or...  8.500
# 24                           Piso en Almagro, Madrid   4.500
# 25     Piso en calle del Olvido, Almendrales, Madrid   1.100
# 26                 Piso en Juan Bravo, Lista, Madrid   1.650
# 27   Estudio en calle de San Romualdo, Simancas, M...  1.000
# 28   Estudio en calle de Ardemans, Guindalera, Mad...    750
# 29                           Piso en El Viso, Madrid   1.650
#
#                                  m2                              Floor  \
# 0                              117     Planta 6ª exterior con ascensor
# 1                               73     Planta 2ª interior con ascensor
# 2                               60     Planta 3ª exterior sin ascensor
# 3                              162               exterior con ascensor
# 4                               90     Planta 3ª exterior con ascensor
# 5                               70     Planta 3ª exterior con ascensor
# 6                               80     Planta 3ª exterior sin ascensor
# 7                               60          Bajo exterior con ascensor
# 8                               65   Entreplanta exterior con ascensor
# 9                              307
# 10                              45          Bajo exterior con ascensor
# 11                              61     Planta 1ª exterior con ascensor
# 12                             120     Planta 1ª exterior con ascensor
# 13                              90     Planta 5ª exterior con ascensor
# 14                              73     Planta 2ª exterior sin ascensor
# 15                             109     Planta 1ª exterior con ascensor
# 16                              57     Planta 3ª exterior con ascensor
# 17                              86     Planta 5ª exterior con ascensor
# 18                              55     Planta 6ª exterior con ascensor
# 19                             366     Planta 5ª exterior con ascensor
# 20                              75     Planta 2ª exterior con ascensor
# 21                             297     Planta 1ª exterior con ascensor
# 22                              49     Planta 4ª interior con ascensor
# 23                             650
# 24                             160     Planta 5ª exterior con ascensor
# 25                              52          Bajo exterior sin ascensor
# 26                              75     Planta 8ª exterior con ascensor
# 27  Planta 6ª exterior con ascensor
# 28  Planta 1ª interior con ascensor                           12 horas
# 29                              70     Planta 2ª exterior con ascensor
#
#       Room                                        Description
# 0       3    Piso de tres habitaciones amplias y cuarto de...
# 1       1    Se alquila en Chamberí, piso reformado para p...
# 2       2    Magnífico piso de 60m2. Consta de 2 dormitori...
# 3       3    Amplio y luminoso piso en Cortes en alquiler ...
# 4       3    Piso de 90m2 útiles, 104m2 construidos. Const...
# 5       3    Bonito piso exterior, con una suite, una habi...
# 6       1    Piso de 80m2 con una decoración unica de ladr...
# 7       1    Disponible para entrar en Septiembre. PATIO P...
# 8       2    Se alquila piso zona primcipe pio madrid rio ...
# 9       4    Colomba Boutique Inmobiliaria presenta en alq...
# 10      2    Por favor, NO CONTACTAR POR TELÉFONO, solo a ...
# 11      2    ¡Sin comisiones de agencia!   Y AHORA ALQUILA...
# 12      3    TECNOCASA ESTUDIO PINAR DE CHAMARTIN VENDE vi...
# 13      2    *** ALQUILER POR MESES*** Disponible a partir...
# 14      3    VIDEO DISPONIBLE! Piso exterior completamente...
# 15      3    ¡SERVICHECK ALQUILA HERMOSO PISO EN AVENIDA E...
# 16      1    VIDEO PUBLICIDAD! Piso exterior y parcialment...
# 17      2    ¡No te lo pienses! ¡Ven a visitarnos!   En el...
# 18      1    Vivienda nueva a estrena; Zonas comunes verde...
# 19      5    Piso de lujo reformado con magníficas calidad...
# 20      2    REDPISO PASEO DE LA FLORIDA alquila ésta fant...
# 21      5    INMOBILIARIA EMMANUEL PARA ENTRAR 1 de DICIEM...
# 22      1    Alquilar un piso con la reparación de diseño....
# 23      5    QUALITÉ Agence Immobilière Française présente...
# 24      2    Piso a estrenar en obra nueva en el barrio de...
# 25      1    Alquiler por temporadas "VIVIENDA A ESTRENAR"...
# 26      1    IMPRESIONANTE ÁTICO AMUEBLADO CON PISCINA EN ...
# 27  100 m²   SERVICHECK ALQUILA! PRECIOSO LOFT EN MADRID P...
# 28   35 m²   ¡FANTÁSTICO ESTUDIO AMUEBLADO EN BARRIO SALAM...
# 29      2    Piso reformado y luminoso vacío en alquiler E...
