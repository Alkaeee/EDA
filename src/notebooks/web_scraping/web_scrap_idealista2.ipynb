# %%
from seleniumwire import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.proxy import Proxy, ProxyType
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from selenium_stealth import stealth
from selenium.webdriver.firefox.options import Options as FirefoxOptions


from bs4 import BeautifulSoup as bs
import time
import pandas as pd
import random

# %%
df_1 = pd.DataFrame()
driver = webdriver.Firefox()

# %%
def get_rent_info(soup):
    rent_info = {
        "Direction": [],
        "Price": [],
        "m2": [],
        "Floor": [],
        "Room": [],
        "Description": []
    }
    item_info = soup.find_all('div', class_="item-info-container")
    rent_info["Direction"] = [x.find('a',class_="item-link").get_text() for x in item_info]
    rent_info["Price"] = [x.find('span',class_="item-price h2-simulated").get_text() for x in item_info]
    rent_info["Description"] = [x.find('div',class_="item-description description").get_text() for x in item_info]

    apart_detail = [x.find('div',class_="item-detail-char").get_text() for x in item_info]

    detail_list = [x.split('\n') for x in apart_detail]
    time.sleep(12)

    for elem in detail_list:
        print(elem)
        rent_info["Room"].append(elem[1])
        rent_info["m2"].append(elem[2])
        rent_info["Floor"].append(elem[3])

    df = pd.DataFrame(rent_info)
    return df

# %%
df = pd.DataFrame()

soup = []
df_info = pd.DataFrame()
URL = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/"
URL_2 ="https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-2.htm"
URL_3 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-3.htm"
URL_4 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-4.htm"
URL_5 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-5.htm"
URL_5 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-6.htm"
URL_6 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-7.htm"
URL_7 = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-8.htm"

urls = [URL]

# scraping logic...
for url in urls:
    time.sleep(5)
    driver.get(url)
    time.sleep(8)
    soup.append((driver.page_source, "html.parser"))


driver.quit()

# %%
s= bs(soup[0][0],"html.parser")

# %%
df_1 = pd.DataFrame()

# %%
df_1 = get_rent_info(s)
df_1
# Out:
# ['', '2 hab.', '91 m²', 'Planta 2ª exterior con ascensor', '0 minutos', '']
# ['', '2 hab.', '78 m²', 'Bajo exterior con ascensor', '']
# ['', '1 hab.', '68 m²', 'Planta 3ª exterior con ascensor', '25 minutos', '']
# ['', '1 hab.', '40 m²', 'Bajo exterior sin ascensor', '']
# ['', '1 hab.', '71 m²', 'Planta 2ª exterior con ascensor', '32 minutos', '']
# ['', '2 hab.', '55 m²', 'Planta 4ª interior con ascensor', '19\xa0oct ', '']
# ['', '1 hab.', '67 m²', 'Planta 2ª exterior con ascensor', '40 minutos', '']
# ['', '3 hab.', '146 m²', 'Planta 19ª exterior con ascensor', '']
# ['', '1 hab.', '74 m²', 'Planta 2ª exterior con ascensor', '40 minutos', '']
# ['', '3 hab.', '146 m²', 'Planta 21ª exterior con ascensor', '']
# ['', '1 hab.', '60 m²', 'Planta 3ª exterior con ascensor', '45 minutos', '']
# ['', '3 hab.', '146 m²', 'Planta 17ª exterior con ascensor', '']
# ['', '3 hab.', '132 m²', 'Planta 1ª exterior con ascensor', '55 minutos', '']
# ['', '3 hab.', '110 m²', 'Planta 6ª exterior con ascensor', '']
# ['', '1 hab.', '52 m²', 'Planta 3ª exterior con ascensor', '1 hora', '']
# ['', '4 hab.', '172 m²', 'Planta 4ª con ascensor', '']
# ['', '1 hab.', '65 m²', 'Planta 7ª exterior con ascensor', '1 hora', '']
# ['', '4 hab.', '187 m²', 'Bajo exterior con ascensor', '']
# ['', '3 hab.', '125 m²', ' exterior con ascensor', '1 hora', '']
# ['', '2 hab.', '178 m²', 'Planta 8ª exterior con ascensor', '']
# ['', '2 hab.', '50 m²', 'Planta 2ª exterior con ascensor', '1 hora', '']
# ['', '2 hab.', '110 m²', ' exterior con ascensor', '']
# ['', '2 hab.', '80 m²', 'Planta 7ª exterior con ascensor', '2 horas', '']
# ['', '4 hab.', '350 m²', 'Planta 5ª exterior con ascensor', '']
# ['', '1 hab.', '50 m²', 'Planta 2ª exterior sin ascensor', '2 horas', '']
# ['', '5 hab.', '342 m²', 'Planta 5ª exterior con ascensor', '']
# ['', '1 hab.', '73 m²', 'Planta 1ª exterior con ascensor', '2 horas', '']
# ['', '2 hab.', '85 m²', 'Planta 3ª exterior con ascensor', '']
# ['', '47 m²', 'Bajo exterior con ascensor', '3 horas', '']
# ['', '2 hab.', '90 m²', 'Planta 3ª exterior con ascensor', '']
#                                             Direction       Price  \
# 0                            \nPiso en Goya, Madrid\n  1.500€/mes
# 1       \nPiso en calle de Belice, Salvador, Madrid\n  1.150€/mes
# 2    \nPiso en calle Beasain, 31, Orcasitas, Madrid\n    790€/mes
# 3   \nPiso en calle de Oña, Virgen del Cortijo - M...  1.000€/mes
# 4   \nPiso en batalla del Salado, 44, Delicias, Ma...  1.400€/mes
# 5                    \nPiso en Vallehermoso, Madrid\n  1.500€/mes
# 6   \nPiso en calle de Juan Bravo, 3, Castellana, ...  2.100€/mes
# 7   \nPiso en paseo de la Dirección, 161, Valdeace...  2.820€/mes
# 8   \nPiso en calle de la Pintora Ángeles Santos, ...    980€/mes
# 9   \nPiso en paseo de la Dirección, 161, Valdeace...  2.940€/mes
# 10   \nPiso en calle de Elfo, 2, Concepción, Madrid\n  1.050€/mes
# 11  \nPiso en paseo de la Dirección, 161, Valdeace...  2.700€/mes
# 12                      \nPiso en Recoletos, Madrid\n  2.300€/mes
# 13                    \nPiso en Prosperidad, Madrid\n  2.400€/mes
# 14  \nPiso en calle domingo fernandez, 5, Nueva Es...  1.300€/mes
# 15  \nPiso en calle de Fernández de la Hoz, Almagr...  2.400€/mes
# 16  \nPiso en calle de Edgar Neville, 12, Cuatro C...  1.500€/mes
# 17                     \nPiso en Valdemarín, Madrid\n  2.800€/mes
# 18  \nPiso en calle de Martínez Izquierdo, Guindal...  2.300€/mes
# 19  \nPiso en paseo del General Martínez Campos, A...  3.100€/mes
# 20  \nPiso en calle de Galileo, 38, Arapiles, Madr...  1.600€/mes
# 21               \nPiso en Fuente del Berro, Madrid\n  2.300€/mes
# 22  \nPiso en Uruguay, 17, Bernabéu-Hispanoamérica...  1.550€/mes
# 23       \nPiso en calle de O'Donnell, Goya, Madrid\n  8.250€/mes
# 24  \nÁtico en calle de Martínez Izquierdo, 21, Gu...  1.130€/mes
# 25  \nPiso en calle San Martín de Porres, Ciudad U...  3.700€/mes
# 26  \nPiso en calle del hierro, 17, Delicias, Madr...  1.200€/mes
# 27  \nPiso en calle de San Bernardo, Malasaña-Univ...  3.600€/mes
# 28  \nEstudio en calle Sierra Bermeja, 30, Palomer...    700€/mes
# 29  \nPiso en calle de San Bernardo, Malasaña-Univ...  3.600€/mes
#
#                             m2                             Floor    Room  \
# 0                        91 m²   Planta 2ª exterior con ascensor  2 hab.
# 1                        78 m²        Bajo exterior con ascensor  2 hab.
# 2                        68 m²   Planta 3ª exterior con ascensor  1 hab.
# 3                        40 m²        Bajo exterior sin ascensor  1 hab.
# 4                        71 m²   Planta 2ª exterior con ascensor  1 hab.
# 5                        55 m²   Planta 4ª interior con ascensor  2 hab.
# 6                        67 m²   Planta 2ª exterior con ascensor  1 hab.
# 7                       146 m²  Planta 19ª exterior con ascensor  3 hab.
# 8                        74 m²   Planta 2ª exterior con ascensor  1 hab.
# 9                       146 m²  Planta 21ª exterior con ascensor  3 hab.
# 10                       60 m²   Planta 3ª exterior con ascensor  1 hab.
# 11                      146 m²  Planta 17ª exterior con ascensor  3 hab.
# 12                      132 m²   Planta 1ª exterior con ascensor  3 hab.
# 13                      110 m²   Planta 6ª exterior con ascensor  3 hab.
# 14                       52 m²   Planta 3ª exterior con ascensor  1 hab.
# 15                      172 m²            Planta 4ª con ascensor  4 hab.
# 16                       65 m²   Planta 7ª exterior con ascensor  1 hab.
# 17                      187 m²        Bajo exterior con ascensor  4 hab.
# 18                      125 m²             exterior con ascensor  3 hab.
# 19                      178 m²   Planta 8ª exterior con ascensor  2 hab.
# 20                       50 m²   Planta 2ª exterior con ascensor  2 hab.
# 21                      110 m²             exterior con ascensor  2 hab.
# 22                       80 m²   Planta 7ª exterior con ascensor  2 hab.
# 23                      350 m²   Planta 5ª exterior con ascensor  4 hab.
# 24                       50 m²   Planta 2ª exterior sin ascensor  1 hab.
# 25                      342 m²   Planta 5ª exterior con ascensor  5 hab.
# 26                       73 m²   Planta 1ª exterior con ascensor  1 hab.
# 27                       85 m²   Planta 3ª exterior con ascensor  2 hab.
# 28  Bajo exterior con ascensor                           3 horas   47 m²
# 29                       90 m²   Planta 3ª exterior con ascensor  2 hab.
#
#                                           Description
# 0   \nMARIO INMOBILIARIA OFRECE INMUEBLE\nPARA CON...
# 1   \n-ZONA SALVADOR- Piso reformado de 78m² const...
# 2   \nPiso de 1 dormitorio +TRASTERO + GARAJE con ...
# 3   \n- SANCHINARRO-Vivienda de 39 m² útiles, exte...
# 4   \nAlquilo apartamento grande de una habitación...
# 5   \nPiso acogedor en calle Bravo Murillo. Vivien...
# 6   \nApartamento de lujo completamente reformado ...
# 7   \nPara más viviendas como está, visita nuestra...
# 8   \nRogel Propiedades alquila piso ubicado en zo...
# 9   \n!! VISTAS UNICAS EN LO MAS ALTO DE MADRID !!...
# 10  \nApartamento totalmente amueblado para entrar...
# 11  \nPara más viviendas como está, visita nuestra...
# 12  \n"JCB ASESORES alquila piso DE LUJO SIN AMUEB...
# 13  \nLuminoso piso en Clara del Rey\nEngel & Völk...
# 14
# 15  \n¡Increíble piso en alquiler en la codiciada ...
# 16  \nPARA VISITAR ESCRIBEME POR WHATSAPP 6 8 7 3 ...
# 17  \nExtrena21 ofrece este magnifico bajo con jar...
# 18  \nDomus Aurea Capital presenta este Ático dúpl...
# 19  \nOportunidad de vivir en una de las mejores c...
# 20  \nEstupendo apartamento en la calle Galilio, c...
# 21  \nEXCELENTE PISO DE OBRA NUEVA CON PATIO\nEnge...
# 22  \nLuminoso piso en una séptima planta, recient...
# 23  \nPiso en alquiler en la calle O'Donnell.\nPIS...
# 24  \nÁtico con terraza orientada a sur a estrenar...
# 25  \nPiso en la calle San Martin de Porres.\nPISO...
# 26  \nPrecioso piso de un dormitorio, en perfecto ...
# 27  \nPiso en alquiler en calle San Bernardo.\nPIS...
# 28  \nDisponible a partir de mediados de diciembre...
# 29  \nPiso en alquiler en calle San Bernardo.\nPIS...

# %%
df_1
df_1.to_csv("../../data/rentaMadrid2023_12.csv")
