# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#                                               0.0/294.6 kB ? eta -:--:--
#      ------------------------------------- 294.6/294.6 kB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\javie\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.26.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\javie\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.1.1)
# Collecting matplotlib!=3.6.1,>=3.3 (from seaborn)
#   Downloading matplotlib-3.8.0-cp311-cp311-win_amd64.whl (7.6 MB)
#                                               0.0/7.6 MB ? eta -:--:--
#      --------                                 1.5/7.6 MB 32.7 MB/s eta 0:00:01
#      ---------------                          2.9/7.6 MB 30.9 MB/s eta 0:00:01
#      ---------------------                    4.2/7.6 MB 29.4 MB/s eta 0:00:01
#      ----------------------------             5.5/7.6 MB 29.4 MB/s eta 0:00:01
#      ------------------------------------     7.0/7.6 MB 29.6 MB/s eta 0:00:01
#      ---------------------------------------- 7.6/7.6 MB 27.1 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.3->seaborn)
#   Downloading contourpy-1.1.1-cp311-cp311-win_amd64.whl (480 kB)
#                                               0.0/480.5 kB ? eta -:--:--
#      ------------------------------------- 480.5/480.5 kB 29.4 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.3->seaborn)
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.3->seaborn)
#   Downloading fonttools-4.43.1-cp311-cp311-win_amd64.whl (2.1 MB)
#                                               0.0/2.1 MB ? eta -:--:--
#      -----------------------                  1.3/2.1 MB 39.7 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 33.8 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib!=3.6.1,>=3.3->seaborn)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#                                               0.0/56.1 kB ? eta -:--:--
#      ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\javie\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Collecting pillow>=6.2.0 (from matplotlib!=3.6.1,>=3.3->seaborn)
#   Downloading Pillow-10.1.0-cp311-cp311-win_amd64.whl (2.6 MB)
#                                               0.0/2.6 MB ? eta -:--:--
#      ----------------                         1.0/2.6 MB 32.3 MB/s eta 0:00:01
#      ------------------------------------     2.4/2.6 MB 29.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.6/2.6 MB 27.6 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\javie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\javie\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\javie\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\javie\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\javie\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.43.1 kiwisolver-1.4.5 matplotlib-3.8.0 pillow-10.1.0 seaborn-0.13.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\javie\appdata\local\programs\python\python311\lib\site-packages (3.8.0)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\javie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\javie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\javie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\javie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\javie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\javie\appdata\roaming\python\python311\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\javie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\javie\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\javie\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\javie\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')
import seaborn as sns

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# guarda en variables los datasets y su fuente
# Fuente sacada de https://www.idealista.com/alquiler-viviendas/madrid-madrid con web-scraping 2023
fuente_1 = "../data/rentaMadrid2023Idealista.csv"
df_idealista = pd.read_csv(fuente_1, sep=";")

# %%
df_idealista
# Out:
#                                              Direction   Price     m2  Floor  \
# 0                Piso en Lavapiés-Embajadores, Madrid   1400.0   71.0      5
# 1                      Piso en Pavia, Palacio, Madrid   2800.0  134.0      4
# 2     Piso en calle de Manuela Malasaña, 28, Malasa...   850.0   35.0      2
# 3     Piso en calle Corral de Almaguer, 12, Ensanch...   799.0   38.0      1
# 4     Dúplex en calle de Agustín Durán, 29, Guindal...  1800.0  135.0      0
# ..                                                 ...     ...    ...    ...
# 235                        Piso en Castellana, Madrid   4200.0  230.0      5
# 236   Piso en German Pérez Carrasco, Quintana, Madrid    900.0   50.0      2
# 237   Piso en calle de Hermosilla, 18, Recoletos, M...  3900.0  170.0      2
# 238   Estudio en calle del Manco de Lepanto, Numanc...   630.0    NaN      3
# 239   Piso en calle de Serrano, 28, Recoletos, Madrid   4600.0  165.0      3
#
#      Room                                        Description
# 0       2   Piso exterior muy luminoso y tranquilo en cal...
# 1       2   En alquiler y/o a la venta una propiedad espe...
# 2       1   Bonito apartamento amueblado en el corazón de...
# 3       1   ¡Sin comisiones de agencia!   Y AHORA ALQUILA...
# 4       2   Alquilamos, como particulares (no lo gestiona...
# ..    ...                                                ...
# 235     2   La Inmobiliaria Internacional CPM gestiona es...
# 236     2   ¿Estás buscando una vivienda luminosa, recién...
# 237     3   MAGNÍFICA VIVIENDA EN PLENO BARRIO DE SALAMAN...
# 238     0   POR FAVOR LEER TODA LA DESCRIPCIÓN DEL ANUNCI...
# 239     3   VIBA les ofrece una exclusiva vivienda en ple...
#
# [240 rows x 6 columns]

# %%
sns.catplot(df_idealista, y='Price', x='Room', kind="bar")

# %%
df_idealista.describe()
# Out:
#               Price          m2       Floor        Room
# count    240.000000  223.000000  240.000000  240.000000
# mean    2096.112500  115.434978    2.983333    2.225000
# std     1439.312251   83.334148    2.948607    1.237236
# min      630.000000   30.000000    0.000000    0.000000
# 25%     1100.000000   62.500000    1.000000    1.000000
# 50%     1510.000000   90.000000    2.000000    2.000000
# 75%     2750.000000  133.500000    4.000000    3.000000
# max    10000.000000  650.000000   22.000000    6.000000

# %%
df_idealista.dtypes
# Out:
# Direction       object
# Price          float64
# m2             float64
# Floor            int64
# Room             int64
# Description     object
# dtype: object

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(df_idealista["Price"]);
sns.displot(df_idealista["Price"],
             kde=True,
             stat="density",
             color='b',
             bins=30);
plt.xlim(-10,10000)
# Out:
# (-10.0, 10000.0)

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.boxplot(x=df_idealista["Price"], color="b");
plt.subplot(1,2,2)
sns.violinplot(x=df_idealista["Price"], color='deeppink',bw_method=.5, inner="stick");

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(x=df_idealista["Room"]);
plt.title("Numero de habitaciones")
plt.subplot(1,2,2)
sns.countplot(x=df_idealista["Floor"]);
plt.title("Numero de piso")
# Out:
# Text(0.5, 1.0, 'Numero de piso')

# %%
df_idealista['Room'].value_counts().sort_values(ascending=False)
# Out:
# Room
# 2    82
# 3    57
# 1    50
# 4    22
# 0    17
# 5    11
# 6     1
# Name: count, dtype: int64

# %%
plt.pie(df_idealista['Room'].value_counts(),labels=[2,3,1,4,0,5]);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\javie\OneDrive\Documentos\Hacker\EDA\src\notebooks\idealista_analytic.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/javie/OneDrive/Documentos/Hacker/EDA/src/notebooks/idealista_analytic.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> plt.pie(df_idealista['Room'].value_counts(),labels=[2,3,1,4,0,5]);
#
# File c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3546, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3523 @_copy_docstring_and_deprecators(Axes.pie)
#    3524 def pie(
#    3525     x: ArrayLike,
#    (...)
#    3544     data=None,
#    3545 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3546     return gca().pie(
#    3547         x,
#    3548         explode=explode,
#    3549         labels=labels,
#    3550         colors=colors,
#    3551         autopct=autopct,
#    3552         pctdistance=pctdistance,
#    3553         shadow=shadow,
#    3554         labeldistance=labeldistance,
#    3555         startangle=startangle,
#    3556         radius=radius,
#    3557         counterclock=counterclock,
#    3558         wedgeprops=wedgeprops,
#    3559         textprops=textprops,
#    3560         center=center,
#    3561         frame=frame,
#    3562         rotatelabels=rotatelabels,
#    3563         normalize=normalize,
#    3564         hatch=hatch,
#    3565         **({"data": data} if data is not None else {}),
#    3566     )
#
# File c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:3237, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3235     explode = [0] * len(x)
#    3236 if len(x) != len(labels):
# -> 3237     raise ValueError("'label' must be of length 'x'")
#    3238 if len(x) != len(explode):
#    3239     raise ValueError("'explode' must be of length 'x'")
#
# ValueError: 'label' must be of length 'x'

# %%
sns.catplot(df_idealista, y='Price', x='Room', kind="bar")

# %%
sns.catplot(df_idealista, y='Floor', x='Room', kind="bar")

# %%
sns.catplot(df_idealista, x='m2', y='Price', kind="strip");
plt.xlim([0, df_m2["75%"]])
plt.xticks([0,df_m2["min"],df_m2["25%"], df_m2["50%"],df_m2["75%"]]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\javie\OneDrive\Documentos\Hacker\EDA\src\notebooks\idealista_analytic.ipynb Cell 17 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/javie/OneDrive/Documentos/Hacker/EDA/src/notebooks/idealista_analytic.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> sns.catplot(df_idealista, x='m2', y='Price', kind="strip");
# ----> <a href='vscode-notebook-cell:/c%3A/Users/javie/OneDrive/Documentos/Hacker/EDA/src/notebooks/idealista_analytic.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> plt.xlim([0, df_m2["75%"]])
#       <a href='vscode-notebook-cell:/c%3A/Users/javie/OneDrive/Documentos/Hacker/EDA/src/notebooks/idealista_analytic.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> plt.xticks([0,df_m2["min"],df_m2["25%"], df_m2["50%"],df_m2["75%"]]);
#
# NameError: name 'df_m2' is not defined

# %%
df_idealista.columns
# Out:
# Index(['Direction', 'Price', 'm2', 'Floor', 'Room', 'Description'], dtype='object')

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(data=df_idealista[df_idealista.columns.values[3:5]], fill=True);
plt.xlim(-5,10)
plt.figure(figsize=(12,8))
sns.distplot(df_idealista["Room"] , color="skyblue",kde=True, label="Rooms")
sns.distplot(df_idealista["Floor"] , color="red", kde=True, label="Floors")
#sns.histplot(df_idealista["Room"] , color="skyblue",kde=True, label="Rooms")
#sns.histplot(df_idealista["Floor"] , color="red", kde=True, label="Floors")
plt.legend();
# Out:
# /var/folders/28/8cl0hx0s7wn3jhrkn9jsr1780000gp/T/ipykernel_78344/101829125.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_idealista["Room"] , color="skyblue",kde=True, label="Rooms")
# /var/folders/28/8cl0hx0s7wn3jhrkn9jsr1780000gp/T/ipykernel_78344/101829125.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_idealista["Floor"] , color="red", kde=True, label="Floors")

# %%
df_idealista[df_idealista["Price"] > 9000]
# Out:
#                                             Direction    Price     m2  Floor  \
# 61   Piso en calle de Claudio Coello, Castellana, ...  10000.0  400.0      7
#
#     Room                                        Description
# 61     4   Se alquila sin muebles! Ya esta disponible pa...

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df_idealista['m2'],
                y=df_idealista['Price'],
                hue = df_idealista['Room'],
               s=100);

# %%
sns.jointplot(x=df_idealista['m2'],
            y=df_idealista['Price'],
            color="#4CB391",
            kind="kde",
            height = 8);

# %%
df_nums = df_idealista.loc[:,"Price":"Room"]

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_nums.corr(),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);

# %%
sns.pairplot(df_idealista,
             kind="scatter",
             hue="Room",
             palette="mako",
             plot_kws=dict(s=80, linewidth=1.));

# %%
df_idealista['Room'].unique()[0]
# Out:
# 2

# %%
plt.scatter(data=df_idealista, x="Price", y="Floor", label=None,
            c="Room", cmap='viridis',
            s="m2", linewidth=1, alpha=0.5)
df_idealista['Room'].unique()[0]
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
