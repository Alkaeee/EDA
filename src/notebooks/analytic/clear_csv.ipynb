# %%
import pandas as pd
import numpy as np

# %%
def clean_csv(df_info):
    df_info["Direction"] = df_info["Direction"].str.replace("\n", " ")
    df_info["Description"] = df_info["Description"].str.replace("\n", " ")
    df_info["Room"] = df_info["Room"].str.replace("hab.", "")
    if df_info["Price"].dtype == object:
        df_info["Price"] = df_info["Price"].str.replace("€/mes", "")
    df_info["m2"] = df_info["m2"].str.replace("m²", "")
    df_info["m2"] = df_info["m2"].str.replace(".", "")
    df_info.drop(columns=["Unnamed: 0"], axis=1, inplace=True)


    return df_info

# %%
def changes_csv(df_info):
    # Ponemos 0 habitaciones para los estudios
    mask = df_info[df_info["Room"].str.contains("m")]["Room"].index 
    df_info.loc[mask,"Room"] = 0

    # Cambiamos a valores numericos
    df_info["m2"] = pd.to_numeric(df_info["m2"], errors="coerce")
    df_info["Room"] = pd.to_numeric(df_info["Room"], errors="coerce")
    df_info["Price"] = pd.to_numeric(df_info["Price"], errors="coerce")

    # Changed same indc
    mask_index_min = df_info[df_info["Price"]<12.000].index
    df_info.loc[mask_index_min, "Price"] = df_info.loc[mask_index_min, "Price"]*1000


    # clear rooms
    df_info["Floor"] = df_info["Floor"].str.extract(r"(\d+)")
    df_info["Floor"].fillna(0, inplace=True)


    return df_info

# %%
df = pd.read_csv("../../data/rentaMadrid2023_12.csv") 
df
# Out:
#     Unnamed: 0                                          Direction  \
# 0            0  \nPiso en avenida de Pablo Neruda, 81, Palomer...
# 1            1  \nPiso en calle del Duque de Sesto, Goya, Madr...
# 2            2      \nPiso en calle de La Bañeza, Pilar, Madrid\n
# 3            3  \nDúplex en calle de la Buganvilla, 4, Castill...
# 4            4  \nPiso en calle de Cartagena, 14, Guindalera, ...
# 5            5  \nÁtico en calle de Valverde, 35, Malasaña-Uni...
# 6            6       \nPiso en calle iglesia, 7, Opañel, Madrid\n
# 7            7                        \nPiso en Palomas, Madrid\n
# 8            8  \nPiso en calle del Mirador de la Reina, 50, A...
# 9            9  \nPiso en calle de Potosí, 8, Bernabéu-Hispano...
# 10          10  \nPiso en calle de Henri Dunant, Nueva España,...
# 11          11  \nPiso en calle del General Díaz Porlier, List...
# 12          12  \nPiso en calle del Condado de Treviño, 2, Cos...
# 13          13  \nÁtico en calle de Fuencarral, Trafalgar, Mad...
# 14          14  \nDúplex en calle de Martínez Izquierdo, Guind...
# 15          15         \nPiso en calle Lozoya, Arapiles, Madrid\n
# 16          16  \nPiso en calle de Sánchez Balderas, Prosperid...
# 17          17  \nPiso en calle de Don Ramón de la Cruz, Caste...
# 18          18       \nPiso en calle de Játiva, Adelfas, Madrid\n
# 19          19   \nÁtico en plaza de la Cebada, Palacio, Madrid\n
# 20          20  \nPiso en calle San Vicente Martir, Colina, Ma...
# 21          21  \nPiso en calle de Velázquez, Recoletos, Madrid\n
# 22          22                   \nPiso en Pueblo Nuevo, Madrid\n
# 23          23       \nPiso en calle de Goya, Recoletos, Madrid\n
# 24          24  \nEstudio en calle Vázquez de Mella, Pueblo Nu...
# 25          25  \nPiso en calle de Santa Teresa, Chueca-Justic...
# 26          26  \nPiso en calle de Marcos de Orueta, Tres Oliv...
# 27          27     \nPiso en calle de Moreto, Jerónimos, Madrid\n
# 28          28  \nPiso en calle de Ramírez Tomé, Portazgo, Mad...
# 29          29  \nPiso en calle de Castelló, Castellana, Madrid\n
#
#           Price                          m2                            Floor  \
# 0      960€/mes                       90 m²  Planta 1ª exterior con ascensor
# 1    3.500€/mes                      100 m²  Planta 2ª exterior con ascensor
# 2      930€/mes                       40 m²  Planta 8ª exterior con ascensor
# 3    3.100€/mes                      318 m²  Planta 4ª exterior con ascensor
# 4    1.500€/mes                       75 m²  Planta 2ª exterior con ascensor
# 5    1.700€/mes                       98 m²  Planta 5ª exterior con ascensor
# 6    1.095€/mes                       67 m²  Planta 2ª exterior sin ascensor
# 7    2.950€/mes                       80 m²  Planta 1ª exterior sin ascensor
# 8    1.700€/mes                      125 m²  Planta 3ª exterior con ascensor
# 9    1.500€/mes                       63 m²  Planta 2ª exterior con ascensor
# 10   6.000€/mes                      384 m²           Planta 7ª con ascensor
# 11   3.800€/mes                      158 m²  Planta 1ª exterior con ascensor
# 12   1.400€/mes                       55 m²       Bajo exterior con ascensor
# 13   4.000€/mes                      144 m²  Planta 6ª exterior con ascensor
# 14   2.300€/mes                      140 m²  Planta 3ª exterior con ascensor
# 15   1.300€/mes                       77 m²  Planta 4ª exterior con ascensor
# 16   1.000€/mes                       60 m²  Planta 2ª exterior con ascensor
# 17   4.800€/mes                      230 m²  Planta 1ª exterior con ascensor
# 18   1.400€/mes                       71 m²  Planta 1ª exterior con ascensor
# 19   2.500€/mes                       85 m²  Planta 7ª exterior con ascensor
# 20   1.500€/mes                       91 m²  Planta 1ª exterior con ascensor
# 21   2.900€/mes                       91 m²  Planta 3ª interior con ascensor
# 22   1.200€/mes                       87 m²  Planta 2ª exterior con ascensor
# 23   8.790€/mes                      150 m²  Planta 1ª exterior con ascensor
# 24     825€/mes  Bajo exterior sin ascensor                          2 horas
# 25   3.200€/mes                      177 m²  Planta 3ª exterior con ascensor
# 26   1.000€/mes                       65 m²  Planta 1ª exterior con ascensor
# 27  15.000€/mes                      281 m²  Planta 3ª exterior con ascensor
# 28     850€/mes                       66 m²  Planta 4ª exterior sin ascensor
# 29   2.200€/mes                      142 m²  Planta 5ª interior con ascensor
#
#       Room                                        Description
# 0   3 hab.  \nVivienda de 71 m2 útiles, para alquilar. Pla...
# 1   3 hab.  \nREFORMA INTEGRAL – ELEGANTES ACABADOS – DISE...
# 2   2 hab.  \nEstupendo piso de 55m2 completamente amuebla...
# 3   4 hab.  \nNik Inversión y Gestión, les ofrece este mar...
# 4   2 hab.  \nCasa RECIEN REFORMADA, cercana al metro Dieg...
# 5   1 hab.  \nNik Inversión y Gestión les ofrece en alquil...
# 6   2 hab.  \n►PARTICULAR► - sin comisión de agencia- REFO...
# 7   2 hab.  \nColomba Boutique Inmobiliaria Alquila piso d...
# 8   4 hab.  \nSe alquila piso en la zona de Arroyo del Fre...
# 9   1 hab.  \nZazume te trae este cómodo y acogedor aparta...
# 10  4 hab.  \nOasis House les presenta este impresionante ...
# 11  4 hab.  \n¡PISO CON MAGNIFICA TERRAZA INTERIOR EN CALL...
# 12  1 hab.  \nPrecioso apartamento, recientemente reformad...
# 13  3 hab.  \n****SERVICHECK ALQUILA FABULOSO ATICO EN EXC...
# 14  3 hab.  \n¡ESPECTACULAR DUPLEX DE 3 DORMITORIOS Y DOS ...
# 15  2 hab.  \nALQUILOFACIL MONCLOA alquila espectacular pi...
# 16  1 hab.  \n¡Síguenos en nuestras redes sociales y sé el...
# 17  4 hab.  \nHousingo se complace en presentar este magní...
# 18  2 hab.  \nArtem Group alquila piso exterior de dos dor...
# 19  2 hab.  \n*********SERVICHECK ALQUILA FABULOSO ATICO A...
# 20  2 hab.  \nEstupenda Vivienda, con salón muy amplio. La...
# 21  1 hab.  \n¡EXCLUSIVO PISO EN RECOLETOS, A ESCASOS METR...
# 22  3 hab.  \nSe alquila piso amueblado en Ciudad Lineal e...
# 23  3 hab.  \n¡EXCLUSIVO INMUEBLE EN RECOLETOS CON 3 BALCO...
# 24   67 m²  \nPOSIBILIDAD DE ALQUILAR CORTA ESTANCIA DESDE...
# 25  3 hab.  \n¡PISO CON 6 BALCONES EXTERIORES EN CALLE SAN...
# 26  3 hab.  \nESTUDIO HOME MADRID OFRECE piso de 65 m2 seg...
# 27  4 hab.  \nConsulting Inmobiliario Esquivel SLU. Les of...
# 28  2 hab.  \nSe alquila vivienda muy luminosa, ubicada en...
# 29  3 hab.  \n¡PISO CON TERRAZA INTERIOR EN CALLE CASTELLÓ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   30 non-null     int64
#  1   Direction    30 non-null     object
#  2   Price        30 non-null     object
#  3   m2           30 non-null     object
#  4   Floor        30 non-null     object
#  5   Room         30 non-null     object
#  6   Description  30 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ KB

# %%
df = clean_csv(df)
df = changes_csv(df)
df
# Out:
#                                             Direction   Price     m2 Floor  \
# 0    Piso en avenida de Pablo Neruda, 81, Palomera...   960.0   90.0     1
# 1     Piso en calle del Duque de Sesto, Goya, Madrid   3500.0  100.0     2
# 2          Piso en calle de La Bañeza, Pilar, Madrid    930.0   40.0     8
# 3    Dúplex en calle de la Buganvilla, 4, Castilla...  3100.0  318.0     4
# 4    Piso en calle de Cartagena, 14, Guindalera, M...  1500.0   75.0     2
# 5    Ático en calle de Valverde, 35, Malasaña-Univ...  1700.0   98.0     5
# 6           Piso en calle iglesia, 7, Opañel, Madrid   1095.0   67.0     2
# 7                            Piso en Palomas, Madrid   2950.0   80.0     1
# 8    Piso en calle del Mirador de la Reina, 50, Ar...  1700.0  125.0     3
# 9    Piso en calle de Potosí, 8, Bernabéu-Hispanoa...  1500.0   63.0     2
# 10   Piso en calle de Henri Dunant, Nueva España, ...  6000.0  384.0     7
# 11   Piso en calle del General Díaz Porlier, Lista...  3800.0  158.0     1
# 12   Piso en calle del Condado de Treviño, 2, Cost...  1400.0   55.0     0
# 13   Ático en calle de Fuencarral, Trafalgar, Madrid   4000.0  144.0     6
# 14   Dúplex en calle de Martínez Izquierdo, Guinda...  2300.0  140.0     3
# 15            Piso en calle Lozoya, Arapiles, Madrid   1300.0   77.0     4
# 16   Piso en calle de Sánchez Balderas, Prosperida...  1000.0   60.0     2
# 17   Piso en calle de Don Ramón de la Cruz, Castel...  4800.0  230.0     1
# 18          Piso en calle de Játiva, Adelfas, Madrid   1400.0   71.0     1
# 19      Ático en plaza de la Cebada, Palacio, Madrid   2500.0   85.0     7
# 20   Piso en calle San Vicente Martir, Colina, Mad...  1500.0   91.0     1
# 21     Piso en calle de Velázquez, Recoletos, Madrid   2900.0   91.0     3
# 22                      Piso en Pueblo Nuevo, Madrid   1200.0   87.0     2
# 23          Piso en calle de Goya, Recoletos, Madrid   8790.0  150.0     1
# 24   Estudio en calle Vázquez de Mella, Pueblo Nue...   825.0    NaN     2
# 25   Piso en calle de Santa Teresa, Chueca-Justici...  3200.0  177.0     3
# 26   Piso en calle de Marcos de Orueta, Tres Olivo...  1000.0   65.0     1
# 27        Piso en calle de Moreto, Jerónimos, Madrid     15.0  281.0     3
# 28   Piso en calle de Ramírez Tomé, Portazgo, Madrid    850.0   66.0     4
# 29     Piso en calle de Castelló, Castellana, Madrid   2200.0  142.0     5
#
#     Room                                        Description
# 0      3   Vivienda de 71 m2 útiles, para alquilar. Plan...
# 1      3   REFORMA INTEGRAL – ELEGANTES ACABADOS – DISEÑ...
# 2      2   Estupendo piso de 55m2 completamente amueblad...
# 3      4   Nik Inversión y Gestión, les ofrece este mara...
# 4      2   Casa RECIEN REFORMADA, cercana al metro Diego...
# 5      1   Nik Inversión y Gestión les ofrece en alquile...
# 6      2   ►PARTICULAR► - sin comisión de agencia- REFOR...
# 7      2   Colomba Boutique Inmobiliaria Alquila piso de...
# 8      4   Se alquila piso en la zona de Arroyo del Fres...
# 9      1   Zazume te trae este cómodo y acogedor apartam...
# 10     4   Oasis House les presenta este impresionante p...
# 11     4   ¡PISO CON MAGNIFICA TERRAZA INTERIOR EN CALLE...
# 12     1   Precioso apartamento, recientemente reformado...
# 13     3   ****SERVICHECK ALQUILA FABULOSO ATICO EN EXCL...
# 14     3   ¡ESPECTACULAR DUPLEX DE 3 DORMITORIOS Y DOS G...
# 15     2   ALQUILOFACIL MONCLOA alquila espectacular pis...
# 16     1   ¡Síguenos en nuestras redes sociales y sé el ...
# 17     4   Housingo se complace en presentar este magníf...
# 18     2   Artem Group alquila piso exterior de dos dorm...
# 19     2   *********SERVICHECK ALQUILA FABULOSO ATICO AM...
# 20     2   Estupenda Vivienda, con salón muy amplio. La ...
# 21     1   ¡EXCLUSIVO PISO EN RECOLETOS, A ESCASOS METRO...
# 22     3   Se alquila piso amueblado en Ciudad Lineal en...
# 23     3   ¡EXCLUSIVO INMUEBLE EN RECOLETOS CON 3 BALCON...
# 24     0   POSIBILIDAD DE ALQUILAR CORTA ESTANCIA DESDE ...
# 25     3   ¡PISO CON 6 BALCONES EXTERIORES EN CALLE SANT...
# 26     3   ESTUDIO HOME MADRID OFRECE piso de 65 m2 segú...
# 27     4   Consulting Inmobiliario Esquivel SLU. Les ofr...
# 28     2   Se alquila vivienda muy luminosa, ubicada en ...
# 29     3   ¡PISO CON TERRAZA INTERIOR EN CALLE CASTELLÓ!...

# %%
# Concat principal csv
df_idealista = pd.read_csv("../../data/rentaMadrid2023Idealista.csv", sep=";")
# Clear data
df_idealista
# Out:
#                                              Direction   Price     m2  Floor  \
# 0     Piso en avenida del Manzanares, Comillas, Mad...  1500.0   90.0      7
# 1           Piso en calle de Narváez, 9, Goya, Madrid   6365.0  154.0      2
# 2     Piso en Alonso Cano, 65, Nuevos Ministerios-R...   680.0   50.0      0
# 3     Piso en paseo del General Martínez Campos, Al...  2200.0  110.0      0
# 4     Piso en avenida de Monforte de Lemos, 147, Pi...   950.0   55.0     12
# ..                                                 ...     ...    ...    ...
# 382                        Piso en Castellana, Madrid   4200.0  230.0      5
# 383   Piso en German Pérez Carrasco, Quintana, Madrid    900.0   50.0      2
# 384   Piso en calle de Hermosilla, 18, Recoletos, M...  3900.0  170.0      2
# 385   Estudio en calle del Manco de Lepanto, Numanc...   630.0    NaN      3
# 386   Piso en calle de Serrano, 28, Recoletos, Madrid   4600.0  165.0      3
#
#      Room                                        Description
# 0       3   InmoRenta; Gestión y Garantía Real de tu alqu...
# 1       3   Piso de Home Club disponible para alquilarse ...
# 2       1   Piso Interior, situado en la zona de Ríos Ros...
# 3       1   MIA REAL ESTATE, presenta loft para aquellos ...
# 4       2   Bonito piso de 2 habitaciones en finca con po...
# ..    ...                                                ...
# 382     2   La Inmobiliaria Internacional CPM gestiona es...
# 383     2   ¿Estás buscando una vivienda luminosa, recién...
# 384     3   MAGNÍFICA VIVIENDA EN PLENO BARRIO DE SALAMAN...
# 385     0   POR FAVOR LEER TODA LA DESCRIPCIÓN DEL ANUNCI...
# 386     3   VIBA les ofrece una exclusiva vivienda en ple...
#
# [387 rows x 6 columns]

# %%
df_final = pd.concat([df,df_idealista], ignore_index=True)
df_final.drop_duplicates(inplace=True)

# %%
df_final.to_csv("../../data/rentaMadrid2023Idealista.csv", sep=";", index=False)

# %%
df_final
# Out:
#                                              Direction   Price     m2 Floor  \
# 0     Piso en avenida de Pablo Neruda, 81, Palomera...   960.0   90.0     1
# 1      Piso en calle del Duque de Sesto, Goya, Madrid   3500.0  100.0     2
# 2           Piso en calle de La Bañeza, Pilar, Madrid    930.0   40.0     8
# 3     Dúplex en calle de la Buganvilla, 4, Castilla...  3100.0  318.0     4
# 4     Piso en calle de Cartagena, 14, Guindalera, M...  1500.0   75.0     2
# ..                                                 ...     ...    ...   ...
# 412                        Piso en Castellana, Madrid   4200.0  230.0     5
# 413   Piso en German Pérez Carrasco, Quintana, Madrid    900.0   50.0     2
# 414   Piso en calle de Hermosilla, 18, Recoletos, M...  3900.0  170.0     2
# 415   Estudio en calle del Manco de Lepanto, Numanc...   630.0    NaN     3
# 416   Piso en calle de Serrano, 28, Recoletos, Madrid   4600.0  165.0     3
#
#      Room                                        Description
# 0       3   Vivienda de 71 m2 útiles, para alquilar. Plan...
# 1       3   REFORMA INTEGRAL – ELEGANTES ACABADOS – DISEÑ...
# 2       2   Estupendo piso de 55m2 completamente amueblad...
# 3       4   Nik Inversión y Gestión, les ofrece este mara...
# 4       2   Casa RECIEN REFORMADA, cercana al metro Diego...
# ..    ...                                                ...
# 412     2   La Inmobiliaria Internacional CPM gestiona es...
# 413     2   ¿Estás buscando una vivienda luminosa, recién...
# 414     3   MAGNÍFICA VIVIENDA EN PLENO BARRIO DE SALAMAN...
# 415     0   POR FAVOR LEER TODA LA DESCRIPCIÓN DEL ANUNCI...
# 416     3   VIBA les ofrece una exclusiva vivienda en ple...
#
# [417 rows x 6 columns]
