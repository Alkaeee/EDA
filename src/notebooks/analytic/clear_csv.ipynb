# %%
import pandas as pd
import numpy as np

# %%
def clean_csv(df_info):
    df_info["Direction"] = df_info["Direction"].str.replace("\n", " ")
    df_info["Description"] = df_info["Description"].str.replace("\n", " ")
    df_info["Room"] = df_info["Room"].str.replace("hab.", "")
    if df_info["Price"].dtype == object:
        df_info["Price"] = df_info["Price"].str.replace("€/mes", "")
    df_info["m2"] = df_info["m2"].str.replace("m²", "")
    df_info.drop(columns=["Unnamed: 0"], axis=1, inplace=True)


    return df_info

# %%
def changes_csv(df_info):
    # Ponemos 0 habitaciones para los estudios
    mask = df_info[df_info["Room"].str.contains("m")]["Room"].index 
    df_info.loc[mask,"Room"] = 0

    # Cambiamos a valores numericos
    df_info["m2"] = pd.to_numeric(df_info["m2"], errors="coerce")
    df_info["Room"] = pd.to_numeric(df_info["Room"], errors="coerce")
    df_info["Price"] = pd.to_numeric(df_info["Price"], errors="coerce")

    # Changed same indc
    mask_index_min = df_info[df_info["Price"]<20.000].index
    df_info.loc[mask_index_min, "Price"] = df_info.loc[mask_index_min, "Price"]*1000


    # clear rooms
    df_info["Floor"] = df_info["Floor"].str.extract(r"(\d+)")
    df_info["Floor"].fillna(0, inplace=True)


    return df_info

# %%
df = pd.read_csv("../../data/rentaMadrid2023_10.csv") 
df
# Out:
#     Unnamed: 0                                          Direction       Price  \
# 0            0  \nEstudio en calle de Tarragona, 36, Palos de ...    675€/mes
# 1            1  \nPiso en paseo de Santa María de la Cabeza, P...  2.700€/mes
# 2            2  \nPiso en calle Gran Via de Hortaleza, 5, Pina...  1.650€/mes
# 3            3  \nPiso en calle del Conde de Xiquena, Chueca-J...  5.495€/mes
# 4            4  \nPiso en calle de José Gutiérrez Maroto, 3, E...    900€/mes
# 5            5  \nÁtico en calle del Olvido, Almendrales, Madr...  1.650€/mes
# 6            6  \nPiso en calle Topete, 11, Bellas Vistas, Mad...  2.500€/mes
# 7            7           \nPiso en calle de Ayala, Goya, Madrid\n  3.800€/mes
# 8            8  \nPiso en calle de Embajadores, 91, Delicias, ...  1.050€/mes
# 9            9  \nPiso en calle de Bolivia, Bernabéu-Hispanoam...  1.550€/mes
# 10          10   \nPiso en calle de Écija, 7, Argüelles, Madrid\n  3.250€/mes
# 11          11  \nDúplex en calle San Martín de Porres, Ciudad...  1.250€/mes
# 12          12  \nEstudio en calle de Agustina de Aragón, List...    850€/mes
# 13          13  \nPiso en calle de Núñez de Balboa, Recoletos,...  3.868€/mes
# 14          14  \nEstudio en calle del Doctor Esquerdo, 47, Fu...  1.000€/mes
# 15          15  \nPiso en calle de Mauricio Legendre, Castilla...  2.948€/mes
# 16          16  \nPiso en José María de Castro, 1, Cuatro Cami...    950€/mes
# 17          17  \nPiso en calle del Cerro del Monte, 1, El Cañ...    947€/mes
# 18          18   \nPiso en calle cachero, 18, San Diego, Madrid\n    900€/mes
# 19          19  \nEstudio en calle de Irún, s/n, Casa de Campo...  1.750€/mes
# 20          20  \nPiso en calle de Géminis, 20, Casco Históric...  1.200€/mes
# 21          21                         \nPiso en La Paz, Madrid\n  1.150€/mes
# 22          22  \nPiso en avenida del Ensanche de Vallecas, En...    990€/mes
# 23          23   \nPiso en calle de Los Mesejo, Adelfas, Madrid\n  1.200€/mes
# 24          24    \nPiso en calle Paca Díaz, 8, Aravaca, Madrid\n    990€/mes
# 25          25  \nPiso en calle de Mauricio Legendre, Castilla...  1.450€/mes
# 26          26  \nPiso en calle de Géminis, 20, Casco Históric...    950€/mes
# 27          27  \nPiso en calle Colmenares, 5, Chueca-Justicia...  3.750€/mes
# 28          28  \nPiso en calle De Santa Engracia, Almagro, Ma...  2.600€/mes
# 29          29  \nPiso en Principe de Vergara, s/n, Goya, Madr...  5.600€/mes
#
#                                  m2                            Floor    Room  \
# 0   Planta 1ª interior con ascensor                         1 minuto   25 m²
# 1                            111 m²  Planta 1ª exterior con ascensor  3 hab.
# 2                            120 m²  Planta 2ª exterior con ascensor  3 hab.
# 3                            233 m²  Planta 4ª exterior con ascensor  2 hab.
# 4                             67 m²  Planta 6ª exterior con ascensor  2 hab.
# 5                             70 m²  Planta 2ª exterior sin ascensor  3 hab.
# 6                             58 m²  Planta 1ª exterior con ascensor  3 hab.
# 7                            111 m²  Planta 3ª exterior con ascensor  2 hab.
# 8                             45 m²  Planta 4ª interior con ascensor  2 hab.
# 9                            122 m²       Bajo interior con ascensor  2 hab.
# 10                           158 m²  Planta 2ª exterior con ascensor  3 hab.
# 11                            50 m²       Bajo exterior sin ascensor  1 hab.
# 12  Planta 4ª interior con ascensor                           1 hora   30 m²
# 13                           133 m²  Planta 5ª exterior con ascensor  3 hab.
# 14  Planta 4ª exterior con ascensor                           1 hora   37 m²
# 15                           117 m²  Planta 8ª exterior con ascensor  3 hab.
# 16                            35 m²  Planta 3ª interior sin ascensor  1 hab.
# 17                            95 m²       Bajo exterior con ascensor  2 hab.
# 18                            60 m²  Planta 2ª exterior sin ascensor  2 hab.
# 19  Planta 3ª exterior con ascensor                              NaN   40 m²
# 20                            73 m²  Planta 2ª exterior con ascensor  2 hab.
# 21                            82 m²  Planta 1ª exterior con ascensor  2 hab.
# 22                            80 m²  Planta 6ª exterior con ascensor  2 hab.
# 23                            85 m²  Planta 1ª exterior con ascensor  3 hab.
# 24                            68 m²  Planta 1ª exterior sin ascensor  2 hab.
# 25                           104 m²  Planta 6ª exterior con ascensor  4 hab.
# 26                            55 m²  Planta 2ª exterior con ascensor  1 hab.
# 27                           140 m²  Planta 1ª exterior con ascensor  2 hab.
# 28                           130 m²  Planta 4ª exterior con ascensor  3 hab.
# 29                           162 m²  Planta 5ª exterior con ascensor  4 hab.
#
#                                           Description
# 0   \nEstudio, cocina equipada con electrodoméstic...
# 1   \nPiso Reformado con Patio Privativo en el Cen...
# 2   \nPiscina de invierno y de verano, gimnasio, 2...
# 3   \nMARAVILLOSO Y LUMINOSO APARTAMENRO DE 2 HABI...
# 4   \nPiso en muy buen estado y muy soleado. Junto...
# 5   \nAlquiler por temporadas\n"VIVIENDA A ESTRENA...
# 6   \nALQUILER TEMPORAL! 1 A 11 MESES. Para entrar...
# 7   \nVivienda de lujo a estrenar para alquilar po...
# 8   \n¡NO INMOBILIARIAS! ALQUILA DIRECTAMENTE LA P...
# 9   \nServicheck alquila FABULOSO PISO EN LA MEJOR...
# 10  \nExclusiva vivienda con reforma integral reci...
# 11  \nSERVICHECK ALQUILA PRECIOSO PISO EN CIUDAD U...
# 12  \nFIAG Asesores pone a su disposición precioso...
# 13  \nServicheck Alquila Piso en Madrid!\nDisponib...
# 14  \nApartamento muy luminoso y tranquilo, con do...
# 15  \nServicheck Alquila Piso Temporal en Madrid!\...
# 16  \nSe Alquila Temporalmente por días, semanas, ...
# 17  \nDESTINADA A PERSONAS CON DISCAPACIDAD IGUAL ...
# 18  \nBonito piso totalmente reformado. Con dos do...
# 19  \nPrecioso estudio de 35 metros cuadrados a es...
# 20  \nEstupenda vivienda de OBRA NUEVA a estrenar!...
# 21  \nAlquiler de temporada\nSERVICHECK ALQUILA\nM...
# 22  \nMagnífico piso de 80m2. Consta de 2 dormitor...
# 23  \n¡SERVICHECK ALQUILA PISO EN MADRID!\nPara má...
# 24  \nEs orientación Este (cocina y salón) orienta...
# 25  \n¡SERVICHECK ALQUILA!\nAPARTAMENTO DE CUATROS...
# 26  \nEstupenda vivienda de OBRA NUEVA a estrenar!...
# 27  \nEl inmueble se encuentra enclavado en el bar...
# 28  \nForesyco alquila, extraordinario piso de tre...
# 29  \nSe alquila un apartamento exterior de 160 me...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   30 non-null     int64
#  1   Direction    30 non-null     object
#  2   Price        30 non-null     object
#  3   m2           30 non-null     object
#  4   Floor        29 non-null     object
#  5   Room         30 non-null     object
#  6   Description  30 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ KB

# %%
df = clean_csv(df)
df = changes_csv(df)
df
# Out:
#                                             Direction   Price     m2 Floor  \
# 0    Estudio en calle de Tarragona, 36, Palos de M...   675.0    NaN     1
# 1    Piso en paseo de Santa María de la Cabeza, Pa...  2700.0  111.0     1
# 2    Piso en calle Gran Via de Hortaleza, 5, Pinar...  1650.0  120.0     2
# 3    Piso en calle del Conde de Xiquena, Chueca-Ju...  5495.0  233.0     4
# 4    Piso en calle de José Gutiérrez Maroto, 3, En...   900.0   67.0     6
# 5     Ático en calle del Olvido, Almendrales, Madrid   1650.0   70.0     2
# 6    Piso en calle Topete, 11, Bellas Vistas, Madrid   2500.0   58.0     1
# 7               Piso en calle de Ayala, Goya, Madrid   3800.0  111.0     3
# 8    Piso en calle de Embajadores, 91, Delicias, M...  1050.0   45.0     4
# 9    Piso en calle de Bolivia, Bernabéu-Hispanoamé...  1550.0  122.0     0
# 10      Piso en calle de Écija, 7, Argüelles, Madrid   3250.0  158.0     2
# 11   Dúplex en calle San Martín de Porres, Ciudad ...  1250.0   50.0     0
# 12   Estudio en calle de Agustina de Aragón, Lista...   850.0    NaN     1
# 13   Piso en calle de Núñez de Balboa, Recoletos, ...  3868.0  133.0     5
# 14   Estudio en calle del Doctor Esquerdo, 47, Fue...  1000.0    NaN     1
# 15   Piso en calle de Mauricio Legendre, Castilla,...  2948.0  117.0     8
# 16   Piso en José María de Castro, 1, Cuatro Camin...   950.0   35.0     3
# 17   Piso en calle del Cerro del Monte, 1, El Caña...   947.0   95.0     0
# 18      Piso en calle cachero, 18, San Diego, Madrid    900.0   60.0     2
# 19   Estudio en calle de Irún, s/n, Casa de Campo,...  1750.0    NaN     0
# 20   Piso en calle de Géminis, 20, Casco Histórico...  1200.0   73.0     2
# 21                            Piso en La Paz, Madrid   1150.0   82.0     1
# 22   Piso en avenida del Ensanche de Vallecas, Ens...   990.0   80.0     6
# 23      Piso en calle de Los Mesejo, Adelfas, Madrid   1200.0   85.0     1
# 24       Piso en calle Paca Díaz, 8, Aravaca, Madrid    990.0   68.0     1
# 25   Piso en calle de Mauricio Legendre, Castilla,...  1450.0  104.0     6
# 26   Piso en calle de Géminis, 20, Casco Histórico...   950.0   55.0     2
# 27   Piso en calle Colmenares, 5, Chueca-Justicia,...  3750.0  140.0     1
# 28   Piso en calle De Santa Engracia, Almagro, Mad...  2600.0  130.0     4
# 29    Piso en Principe de Vergara, s/n, Goya, Madrid   5600.0  162.0     5
#
#     Room                                        Description
# 0      0   Estudio, cocina equipada con electrodoméstico...
# 1      3   Piso Reformado con Patio Privativo en el Cent...
# 2      3   Piscina de invierno y de verano, gimnasio, 2 ...
# 3      2   MARAVILLOSO Y LUMINOSO APARTAMENRO DE 2 HABIT...
# 4      2   Piso en muy buen estado y muy soleado. Junto ...
# 5      3   Alquiler por temporadas "VIVIENDA A ESTRENAR"...
# 6      3   ALQUILER TEMPORAL! 1 A 11 MESES. Para entrar ...
# 7      2   Vivienda de lujo a estrenar para alquilar por...
# 8      2   ¡NO INMOBILIARIAS! ALQUILA DIRECTAMENTE LA PR...
# 9      2   Servicheck alquila FABULOSO PISO EN LA MEJOR ...
# 10     3   Exclusiva vivienda con reforma integral recié...
# 11     1   SERVICHECK ALQUILA PRECIOSO PISO EN CIUDAD UN...
# 12     0   FIAG Asesores pone a su disposición precioso ...
# 13     3   Servicheck Alquila Piso en Madrid! Disponible...
# 14     0   Apartamento muy luminoso y tranquilo, con dos...
# 15     3   Servicheck Alquila Piso Temporal en Madrid! D...
# 16     1   Se Alquila Temporalmente por días, semanas, q...
# 17     2   DESTINADA A PERSONAS CON DISCAPACIDAD IGUAL O...
# 18     2   Bonito piso totalmente reformado. Con dos dor...
# 19     0   Precioso estudio de 35 metros cuadrados a est...
# 20     2   Estupenda vivienda de OBRA NUEVA a estrenar! ...
# 21     2   Alquiler de temporada SERVICHECK ALQUILA Magn...
# 22     2   Magnífico piso de 80m2. Consta de 2 dormitori...
# 23     3   ¡SERVICHECK ALQUILA PISO EN MADRID! Para más ...
# 24     2   Es orientación Este (cocina y salón) orientac...
# 25     4   ¡SERVICHECK ALQUILA! APARTAMENTO DE CUATROS D...
# 26     1   Estupenda vivienda de OBRA NUEVA a estrenar! ...
# 27     2   El inmueble se encuentra enclavado en el barr...
# 28     3   Foresyco alquila, extraordinario piso de tres...
# 29     4   Se alquila un apartamento exterior de 160 met...

# %%
# Concat principal csv
df_idealista = pd.read_csv("../../data/rentaMadrid2023Idealista.csv", sep =";")
# Clear data
df_idealista
# Out:
#                                              Direction   Price     m2  Floor  \
# 0     Estudio en calle de Tarragona, 36, Palos de M...   675.0    NaN      1
# 1     Piso en paseo de Santa María de la Cabeza, Pa...  2700.0  111.0      1
# 2     Piso en calle Gran Via de Hortaleza, 5, Pinar...  1650.0  120.0      2
# 3     Piso en calle del Conde de Xiquena, Chueca-Ju...  5495.0  233.0      4
# 4     Piso en calle de José Gutiérrez Maroto, 3, En...   900.0   67.0      6
# ..                                                 ...     ...    ...    ...
# 295                        Piso en Castellana, Madrid   4200.0  230.0      5
# 296   Piso en German Pérez Carrasco, Quintana, Madrid    900.0   50.0      2
# 297   Piso en calle de Hermosilla, 18, Recoletos, M...  3900.0  170.0      2
# 298   Estudio en calle del Manco de Lepanto, Numanc...   630.0    NaN      3
# 299   Piso en calle de Serrano, 28, Recoletos, Madrid   4600.0  165.0      3
#
#      Room                                        Description
# 0       0   Estudio, cocina equipada con electrodoméstico...
# 1       3   Piso Reformado con Patio Privativo en el Cent...
# 2       3   Piscina de invierno y de verano, gimnasio, 2 ...
# 3       2   MARAVILLOSO Y LUMINOSO APARTAMENRO DE 2 HABIT...
# 4       2   Piso en muy buen estado y muy soleado. Junto ...
# ..    ...                                                ...
# 295     2   La Inmobiliaria Internacional CPM gestiona es...
# 296     2   ¿Estás buscando una vivienda luminosa, recién...
# 297     3   MAGNÍFICA VIVIENDA EN PLENO BARRIO DE SALAMAN...
# 298     0   POR FAVOR LEER TODA LA DESCRIPCIÓN DEL ANUNCI...
# 299     3   VIBA les ofrece una exclusiva vivienda en ple...
#
# [300 rows x 6 columns]

# %%
df_final = pd.concat([df,df_idealista], ignore_index=True)

# %%
df_final.to_csv("../../data/rentaMadrid2023Idealista.csv", sep=";", index=False)

# %%
df_final
# Out:
#                                              Direction   Price     m2 Floor  \
# 0     Estudio en calle de Tarragona, 36, Palos de M...   675.0    NaN     1
# 1     Piso en paseo de Santa María de la Cabeza, Pa...  2700.0  111.0     1
# 2     Piso en calle Gran Via de Hortaleza, 5, Pinar...  1650.0  120.0     2
# 3     Piso en calle del Conde de Xiquena, Chueca-Ju...  5495.0  233.0     4
# 4     Piso en calle de José Gutiérrez Maroto, 3, En...   900.0   67.0     6
# ..                                                 ...     ...    ...   ...
# 325                        Piso en Castellana, Madrid   4200.0  230.0     5
# 326   Piso en German Pérez Carrasco, Quintana, Madrid    900.0   50.0     2
# 327   Piso en calle de Hermosilla, 18, Recoletos, M...  3900.0  170.0     2
# 328   Estudio en calle del Manco de Lepanto, Numanc...   630.0    NaN     3
# 329   Piso en calle de Serrano, 28, Recoletos, Madrid   4600.0  165.0     3
#
#      Room                                        Description
# 0       0   Estudio, cocina equipada con electrodoméstico...
# 1       3   Piso Reformado con Patio Privativo en el Cent...
# 2       3   Piscina de invierno y de verano, gimnasio, 2 ...
# 3       2   MARAVILLOSO Y LUMINOSO APARTAMENRO DE 2 HABIT...
# 4       2   Piso en muy buen estado y muy soleado. Junto ...
# ..    ...                                                ...
# 325     2   La Inmobiliaria Internacional CPM gestiona es...
# 326     2   ¿Estás buscando una vivienda luminosa, recién...
# 327     3   MAGNÍFICA VIVIENDA EN PLENO BARRIO DE SALAMAN...
# 328     0   POR FAVOR LEER TODA LA DESCRIPCIÓN DEL ANUNCI...
# 329     3   VIBA les ofrece una exclusiva vivienda en ple...
#
# [330 rows x 6 columns]
