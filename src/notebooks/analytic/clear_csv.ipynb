# %%
import pandas as pd
import numpy as np

# %%
def clean_csv(df_info):
    df_info["Direction"] = df_info["Direction"].str.replace("\n", " ")
    df_info["Description"] = df_info["Description"].str.replace("\n", " ")
    df_info["Room"] = df_info["Room"].str.replace("hab.", "")
    if df_info["Price"].dtype == object:
        df_info["Price"] = df_info["Price"].str.replace("€/mes", "")
    df_info["m2"] = df_info["m2"].str.replace("m²", "")
    df_info["m2"] = df_info["m2"].str.replace(".", "")
    df_info.drop(columns=["Unnamed: 0"], axis=1, inplace=True)


    return df_info

# %%
def changes_csv(df_info):
    # Ponemos 0 habitaciones para los estudios
    mask = df_info[df_info["Room"].str.contains("m")]["Room"].index 
    df_info.loc[mask,"Room"] = 0

    # Cambiamos a valores numericos
    df_info["m2"] = pd.to_numeric(df_info["m2"], errors="coerce")
    df_info["Room"] = pd.to_numeric(df_info["Room"], errors="coerce")
    df_info["Price"] = pd.to_numeric(df_info["Price"], errors="coerce")

    # Changed same indc
    mask_index_min = df_info[df_info["Price"]<12.000].index
    df_info.loc[mask_index_min, "Price"] = df_info.loc[mask_index_min, "Price"]*1000


    # clear rooms
    df_info["Floor"] = df_info["Floor"].str.extract(r"(\d+)")
    df_info["Floor"].fillna(0, inplace=True)


    return df_info

# %%
df = pd.read_csv("../../data/rentaMadrid2023_12.csv") 
df
# Out:
#     Unnamed: 0                                          Direction       Price  \
# 0            0                           \nPiso en Goya, Madrid\n  1.500€/mes
# 1            1      \nPiso en calle de Belice, Salvador, Madrid\n  1.150€/mes
# 2            2   \nPiso en calle Beasain, 31, Orcasitas, Madrid\n    790€/mes
# 3            3  \nPiso en calle de Oña, Virgen del Cortijo - M...  1.000€/mes
# 4            4  \nPiso en batalla del Salado, 44, Delicias, Ma...  1.400€/mes
# 5            5                   \nPiso en Vallehermoso, Madrid\n  1.500€/mes
# 6            6  \nPiso en calle de Juan Bravo, 3, Castellana, ...  2.100€/mes
# 7            7  \nPiso en paseo de la Dirección, 161, Valdeace...  2.820€/mes
# 8            8  \nPiso en calle de la Pintora Ángeles Santos, ...    980€/mes
# 9            9  \nPiso en paseo de la Dirección, 161, Valdeace...  2.940€/mes
# 10          10   \nPiso en calle de Elfo, 2, Concepción, Madrid\n  1.050€/mes
# 11          11  \nPiso en paseo de la Dirección, 161, Valdeace...  2.700€/mes
# 12          12                      \nPiso en Recoletos, Madrid\n  2.300€/mes
# 13          13                    \nPiso en Prosperidad, Madrid\n  2.400€/mes
# 14          14  \nPiso en calle domingo fernandez, 5, Nueva Es...  1.300€/mes
# 15          15  \nPiso en calle de Fernández de la Hoz, Almagr...  2.400€/mes
# 16          16  \nPiso en calle de Edgar Neville, 12, Cuatro C...  1.500€/mes
# 17          17                     \nPiso en Valdemarín, Madrid\n  2.800€/mes
# 18          18  \nPiso en calle de Martínez Izquierdo, Guindal...  2.300€/mes
# 19          19  \nPiso en paseo del General Martínez Campos, A...  3.100€/mes
# 20          20  \nPiso en calle de Galileo, 38, Arapiles, Madr...  1.600€/mes
# 21          21               \nPiso en Fuente del Berro, Madrid\n  2.300€/mes
# 22          22  \nPiso en Uruguay, 17, Bernabéu-Hispanoamérica...  1.550€/mes
# 23          23       \nPiso en calle de O'Donnell, Goya, Madrid\n  8.250€/mes
# 24          24  \nÁtico en calle de Martínez Izquierdo, 21, Gu...  1.130€/mes
# 25          25  \nPiso en calle San Martín de Porres, Ciudad U...  3.700€/mes
# 26          26  \nPiso en calle del hierro, 17, Delicias, Madr...  1.200€/mes
# 27          27  \nPiso en calle de San Bernardo, Malasaña-Univ...  3.600€/mes
# 28          28  \nEstudio en calle Sierra Bermeja, 30, Palomer...    700€/mes
# 29          29  \nPiso en calle de San Bernardo, Malasaña-Univ...  3.600€/mes
#
#                             m2                             Floor    Room  \
# 0                        91 m²   Planta 2ª exterior con ascensor  2 hab.
# 1                        78 m²        Bajo exterior con ascensor  2 hab.
# 2                        68 m²   Planta 3ª exterior con ascensor  1 hab.
# 3                        40 m²        Bajo exterior sin ascensor  1 hab.
# 4                        71 m²   Planta 2ª exterior con ascensor  1 hab.
# 5                        55 m²   Planta 4ª interior con ascensor  2 hab.
# 6                        67 m²   Planta 2ª exterior con ascensor  1 hab.
# 7                       146 m²  Planta 19ª exterior con ascensor  3 hab.
# 8                        74 m²   Planta 2ª exterior con ascensor  1 hab.
# 9                       146 m²  Planta 21ª exterior con ascensor  3 hab.
# 10                       60 m²   Planta 3ª exterior con ascensor  1 hab.
# 11                      146 m²  Planta 17ª exterior con ascensor  3 hab.
# 12                      132 m²   Planta 1ª exterior con ascensor  3 hab.
# 13                      110 m²   Planta 6ª exterior con ascensor  3 hab.
# 14                       52 m²   Planta 3ª exterior con ascensor  1 hab.
# 15                      172 m²            Planta 4ª con ascensor  4 hab.
# 16                       65 m²   Planta 7ª exterior con ascensor  1 hab.
# 17                      187 m²        Bajo exterior con ascensor  4 hab.
# 18                      125 m²             exterior con ascensor  3 hab.
# 19                      178 m²   Planta 8ª exterior con ascensor  2 hab.
# 20                       50 m²   Planta 2ª exterior con ascensor  2 hab.
# 21                      110 m²             exterior con ascensor  2 hab.
# 22                       80 m²   Planta 7ª exterior con ascensor  2 hab.
# 23                      350 m²   Planta 5ª exterior con ascensor  4 hab.
# 24                       50 m²   Planta 2ª exterior sin ascensor  1 hab.
# 25                      342 m²   Planta 5ª exterior con ascensor  5 hab.
# 26                       73 m²   Planta 1ª exterior con ascensor  1 hab.
# 27                       85 m²   Planta 3ª exterior con ascensor  2 hab.
# 28  Bajo exterior con ascensor                           3 horas   47 m²
# 29                       90 m²   Planta 3ª exterior con ascensor  2 hab.
#
#                                           Description
# 0   \nMARIO INMOBILIARIA OFRECE INMUEBLE\nPARA CON...
# 1   \n-ZONA SALVADOR- Piso reformado de 78m² const...
# 2   \nPiso de 1 dormitorio +TRASTERO + GARAJE con ...
# 3   \n- SANCHINARRO-Vivienda de 39 m² útiles, exte...
# 4   \nAlquilo apartamento grande de una habitación...
# 5   \nPiso acogedor en calle Bravo Murillo. Vivien...
# 6   \nApartamento de lujo completamente reformado ...
# 7   \nPara más viviendas como está, visita nuestra...
# 8   \nRogel Propiedades alquila piso ubicado en zo...
# 9   \n!! VISTAS UNICAS EN LO MAS ALTO DE MADRID !!...
# 10  \nApartamento totalmente amueblado para entrar...
# 11  \nPara más viviendas como está, visita nuestra...
# 12  \n"JCB ASESORES alquila piso DE LUJO SIN AMUEB...
# 13  \nLuminoso piso en Clara del Rey\nEngel & Völk...
# 14                                                NaN
# 15  \n¡Increíble piso en alquiler en la codiciada ...
# 16  \nPARA VISITAR ESCRIBEME POR WHATSAPP 6 8 7 3 ...
# 17  \nExtrena21 ofrece este magnifico bajo con jar...
# 18  \nDomus Aurea Capital presenta este Ático dúpl...
# 19  \nOportunidad de vivir en una de las mejores c...
# 20  \nEstupendo apartamento en la calle Galilio, c...
# 21  \nEXCELENTE PISO DE OBRA NUEVA CON PATIO\nEnge...
# 22  \nLuminoso piso en una séptima planta, recient...
# 23  \nPiso en alquiler en la calle O'Donnell.\nPIS...
# 24  \nÁtico con terraza orientada a sur a estrenar...
# 25  \nPiso en la calle San Martin de Porres.\nPISO...
# 26  \nPrecioso piso de un dormitorio, en perfecto ...
# 27  \nPiso en alquiler en calle San Bernardo.\nPIS...
# 28  \nDisponible a partir de mediados de diciembre...
# 29  \nPiso en alquiler en calle San Bernardo.\nPIS...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   30 non-null     int64
#  1   Direction    30 non-null     object
#  2   Price        30 non-null     object
#  3   m2           30 non-null     object
#  4   Floor        30 non-null     object
#  5   Room         30 non-null     object
#  6   Description  29 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ KB

# %%
df = clean_csv(df)
df = changes_csv(df)
df
# Out:
#                                             Direction   Price     m2 Floor  \
# 0                               Piso en Goya, Madrid   1500.0   91.0     2
# 1          Piso en calle de Belice, Salvador, Madrid   1150.0   78.0     0
# 2       Piso en calle Beasain, 31, Orcasitas, Madrid    790.0   68.0     3
# 3    Piso en calle de Oña, Virgen del Cortijo - Ma...  1000.0   40.0     0
# 4    Piso en batalla del Salado, 44, Delicias, Mad...  1400.0   71.0     2
# 5                       Piso en Vallehermoso, Madrid   1500.0   55.0     4
# 6    Piso en calle de Juan Bravo, 3, Castellana, M...  2100.0   67.0     2
# 7    Piso en paseo de la Dirección, 161, Valdeaced...  2820.0  146.0    19
# 8    Piso en calle de la Pintora Ángeles Santos, 1...   980.0   74.0     2
# 9    Piso en paseo de la Dirección, 161, Valdeaced...  2940.0  146.0    21
# 10      Piso en calle de Elfo, 2, Concepción, Madrid   1050.0   60.0     3
# 11   Piso en paseo de la Dirección, 161, Valdeaced...  2700.0  146.0    17
# 12                         Piso en Recoletos, Madrid   2300.0  132.0     1
# 13                       Piso en Prosperidad, Madrid   2400.0  110.0     6
# 14   Piso en calle domingo fernandez, 5, Nueva Esp...  1300.0   52.0     3
# 15   Piso en calle de Fernández de la Hoz, Almagro...  2400.0  172.0     4
# 16   Piso en calle de Edgar Neville, 12, Cuatro Ca...  1500.0   65.0     7
# 17                        Piso en Valdemarín, Madrid   2800.0  187.0     0
# 18   Piso en calle de Martínez Izquierdo, Guindale...  2300.0  125.0     0
# 19   Piso en paseo del General Martínez Campos, Al...  3100.0  178.0     8
# 20    Piso en calle de Galileo, 38, Arapiles, Madrid   1600.0   50.0     2
# 21                  Piso en Fuente del Berro, Madrid   2300.0  110.0     0
# 22   Piso en Uruguay, 17, Bernabéu-Hispanoamérica,...  1550.0   80.0     7
# 23          Piso en calle de O'Donnell, Goya, Madrid   8250.0  350.0     5
# 24   Ático en calle de Martínez Izquierdo, 21, Gui...  1130.0   50.0     2
# 25   Piso en calle San Martín de Porres, Ciudad Un...  3700.0  342.0     5
# 26    Piso en calle del hierro, 17, Delicias, Madrid   1200.0   73.0     1
# 27   Piso en calle de San Bernardo, Malasaña-Unive...  3600.0   85.0     3
# 28   Estudio en calle Sierra Bermeja, 30, Palomera...   700.0    NaN     3
# 29   Piso en calle de San Bernardo, Malasaña-Unive...  3600.0   90.0     3
#
#     Room                                        Description
# 0      2   MARIO INMOBILIARIA OFRECE INMUEBLE PARA CONCE...
# 1      2   -ZONA SALVADOR- Piso reformado de 78m² constr...
# 2      1   Piso de 1 dormitorio +TRASTERO + GARAJE con t...
# 3      1   - SANCHINARRO-Vivienda de 39 m² útiles, exter...
# 4      1   Alquilo apartamento grande de una habitación,...
# 5      2   Piso acogedor en calle Bravo Murillo. Viviend...
# 6      1   Apartamento de lujo completamente reformado y...
# 7      3   Para más viviendas como está, visita nuestra ...
# 8      1   Rogel Propiedades alquila piso ubicado en zon...
# 9      3   !! VISTAS UNICAS EN LO MAS ALTO DE MADRID !! ...
# 10     1   Apartamento totalmente amueblado para entrar ...
# 11     3   Para más viviendas como está, visita nuestra ...
# 12     3   "JCB ASESORES alquila piso DE LUJO SIN AMUEBL...
# 13     3   Luminoso piso en Clara del Rey Engel & Völker...
# 14     1                                                NaN
# 15     4   ¡Increíble piso en alquiler en la codiciada C...
# 16     1   PARA VISITAR ESCRIBEME POR WHATSAPP 6 8 7 3 8...
# 17     4   Extrena21 ofrece este magnifico bajo con jard...
# 18     3   Domus Aurea Capital presenta este Ático dúple...
# 19     2   Oportunidad de vivir en una de las mejores ca...
# 20     2   Estupendo apartamento en la calle Galilio, co...
# 21     2   EXCELENTE PISO DE OBRA NUEVA CON PATIO Engel ...
# 22     2   Luminoso piso en una séptima planta, reciente...
# 23     4   Piso en alquiler en la calle O'Donnell. PISO ...
# 24     1   Ático con terraza orientada a sur a estrenar ...
# 25     5   Piso en la calle San Martin de Porres. PISO C...
# 26     1   Precioso piso de un dormitorio, en perfecto e...
# 27     2   Piso en alquiler en calle San Bernardo. PISO ...
# 28     0   Disponible a partir de mediados de diciembre....
# 29     2   Piso en alquiler en calle San Bernardo. PISO ...

# %%
# Concat principal csv
df_idealista = pd.read_csv("../../data/rentaMadrid2023Idealista.csv", sep =";")
# Clear data
df_idealista
# Out:
#                                              Direction   Price     m2  Floor  \
# 0                                Piso en Goya, Madrid   1500.0   91.0      2
# 1           Piso en calle de Belice, Salvador, Madrid   1150.0   78.0      0
# 2        Piso en calle Beasain, 31, Orcasitas, Madrid    790.0   68.0      3
# 3     Piso en calle de Oña, Virgen del Cortijo - Ma...  1000.0   40.0      0
# 4     Piso en batalla del Salado, 44, Delicias, Mad...  1400.0   71.0      2
# ..                                                 ...     ...    ...    ...
# 377                        Piso en Castellana, Madrid   4200.0  230.0      5
# 378   Piso en German Pérez Carrasco, Quintana, Madrid    900.0   50.0      2
# 379   Piso en calle de Hermosilla, 18, Recoletos, M...  3900.0  170.0      2
# 380   Estudio en calle del Manco de Lepanto, Numanc...   630.0    NaN      3
# 381   Piso en calle de Serrano, 28, Recoletos, Madrid   4600.0  165.0      3
#
#      Room                                        Description
# 0       2   MARIO INMOBILIARIA OFRECE INMUEBLE PARA CONCE...
# 1       2   -ZONA SALVADOR- Piso reformado de 78m² constr...
# 2       1   Piso de 1 dormitorio +TRASTERO + GARAJE con t...
# 3       1   - SANCHINARRO-Vivienda de 39 m² útiles, exter...
# 4       1   Alquilo apartamento grande de una habitación,...
# ..    ...                                                ...
# 377     2   La Inmobiliaria Internacional CPM gestiona es...
# 378     2   ¿Estás buscando una vivienda luminosa, recién...
# 379     3   MAGNÍFICA VIVIENDA EN PLENO BARRIO DE SALAMAN...
# 380     0   POR FAVOR LEER TODA LA DESCRIPCIÓN DEL ANUNCI...
# 381     3   VIBA les ofrece una exclusiva vivienda en ple...
#
# [382 rows x 6 columns]

# %%
df_final = pd.concat([df,df_idealista], ignore_index=True)
df_final.drop_duplicates(inplace=True)

# %%
df_final.to_csv("../../data/rentaMadrid2023Idealista.csv", sep=";", index=False)
