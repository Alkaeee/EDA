# %%
import pandas as pd
import numpy as np

# %%
def clean_csv(df_info):
    df_info["Direction"] = df_info["Direction"].str.replace("\n", " ")
    df_info["Description"] = df_info["Description"].str.replace("\n", " ")
    df_info["Room"] = df_info["Room"].str.replace("hab.", "")
    if df_info["Price"].dtype == object:
        df_info["Price"] = df_info["Price"].str.replace("€/mes", "")
    df_info["m2"] = df_info["m2"].str.replace("m²", "")
    df_info["m2"] = df_info["m2"].str.replace(".", "")
    df_info.drop(columns=["Unnamed: 0"], axis=1, inplace=True)


    return df_info

# %%
def changes_csv(df_info):
    # Ponemos 0 habitaciones para los estudios
    mask = df_info[df_info["Room"].str.contains("m")]["Room"].index 
    df_info.loc[mask,"Room"] = 0

    # Cambiamos a valores numericos
    df_info["m2"] = pd.to_numeric(df_info["m2"], errors="coerce")
    df_info["Room"] = pd.to_numeric(df_info["Room"], errors="coerce")
    df_info["Price"] = pd.to_numeric(df_info["Price"], errors="coerce")

    # Changed same indc
    mask_index_min = df_info[df_info["Price"]<12.000].index
    df_info.loc[mask_index_min, "Price"] = df_info.loc[mask_index_min, "Price"]*1000


    # clear rooms
    df_info["Floor"] = df_info["Floor"].str.extract(r"(\d+)")
    df_info["Floor"].fillna(0, inplace=True)


    return df_info

# %%
df = pd.read_csv("../../data/rentaMadrid2023_12.csv") 
df
# Out:
#     Unnamed: 0                                          Direction       Price  \
# 0            0  \nPiso en avenida del Manzanares, Comillas, Ma...  1.500€/mes
# 1            1      \nPiso en calle de Narváez, 9, Goya, Madrid\n  6.365€/mes
# 2            2  \nPiso en Alonso Cano, 65, Nuevos Ministerios-...    680€/mes
# 3            3  \nPiso en paseo del General Martínez Campos, A...  2.200€/mes
# 4            4  \nPiso en avenida de Monforte de Lemos, 147, P...    950€/mes
# 5            5  \nPiso en calle Arte Conceptual, Ensanche de V...  1.100€/mes
# 6            6  \nPiso en calle del Monasterio de Caaveiro, 8,...    750€/mes
# 7            7    \nPiso en paseo Talleres, Los Ángeles, Madrid\n    850€/mes
# 8            8      \nPiso en calle de Alcántara, Lista, Madrid\n  2.700€/mes
# 9            9  \nPiso en avenida del Monte Igueldo, San Diego...  1.025€/mes
# 10          10  \nÁtico en calle de Fermín Caballero, 91, Peña...  1.600€/mes
# 11          11  \nPiso en calle de Hermosilla, 7, Recoletos, M...  1.950€/mes
# 12          12  \nPiso en calle de Rodrigo Uhagón, 21, Pradolo...    625€/mes
# 13          13  \nPiso en calle del Doctor Fleming, 39, Nueva ...  2.233€/mes
# 14          14  \nChalet pareado en Conde Orgaz-Piovera, Madrid\n  7.000€/mes
# 15          15  \nPiso en calle Félix Boix, 4, Nueva España, M...  2.340€/mes
# 16          16     \nPiso en plaza de arteijo, 7, Pilar, Madrid\n  1.050€/mes
# 17          17       \nPiso en calle de Esparteros, Sol, Madrid\n  1.462€/mes
# 18          18  \nPiso en calle Lonja de la Seda, 35, Pau de C...  1.100€/mes
# 19          19  \nPiso en calle del Doctor Fleming, 41, Nueva ...  2.202€/mes
# 20          20  \nEstudio en calle del Heliótropo, 2, Ventilla...  1.300€/mes
# 21          21  \nPiso en calle de Carlos Maurrás, 7, Nueva Es...  2.251€/mes
# 22          22  \nPiso en calle de Juan de la Hoz, Guindalera,...  1.000€/mes
# 23          23  \nPiso en calle del Doctor Fleming, 39, Nueva ...  2.294€/mes
# 24          24  \nPiso en avenida Donostiarra, Concepción, Mad...    890€/mes
# 25          25  \nPiso en calle Félix Boix, 6, Nueva España, M...  2.251€/mes
# 26          26  \nÁtico en calle Doña Urraca, Puerta del Ángel...    875€/mes
# 27          27  \nPiso en calle Félix Boix, 8, Nueva España, M...  2.998€/mes
# 28          28  \nEstudio en calle Malagón, 2, Canillas, Madrid\n    610€/mes
# 29          29  \nPiso en calle de Piamonte, Chueca-Justicia, ...  2.670€/mes
#
#                                  m2                              Floor  \
# 0                             90 m²    Planta 7ª exterior con ascensor
# 1                            154 m²    Planta 2ª exterior con ascensor
# 2                             50 m²         Bajo interior con ascensor
# 3                            110 m²  Entreplanta interior con ascensor
# 4                             55 m²   Planta 12ª exterior con ascensor
# 5                             79 m²    Planta 4ª exterior con ascensor
# 6                             72 m²    Planta 3ª exterior con ascensor
# 7                             48 m²         Bajo exterior sin ascensor
# 8                            160 m²    Planta 5ª exterior con ascensor
# 9                             76 m²    Planta 2ª exterior con ascensor
# 10                           118 m²    Planta 8ª exterior con ascensor
# 11                           112 m²    Planta 6ª exterior con ascensor
# 12                            42 m²         Bajo exterior sin ascensor
# 13                           122 m²    Planta 1ª exterior con ascensor
# 14                           650 m²                         24 minutos
# 15                           130 m²    Planta 7ª exterior con ascensor
# 16                            70 m²   Planta 10ª exterior con ascensor
# 17                            45 m²    Planta 2ª interior sin ascensor
# 18                           110 m²    Planta 2ª exterior con ascensor
# 19                           130 m²    Planta 2ª exterior con ascensor
# 20       Bajo exterior sin ascensor                         29 minutos
# 21                           131 m²    Planta 3ª exterior con ascensor
# 22                            47 m²    Planta 1ª interior sin ascensor
# 23                           135 m²    Planta 5ª exterior con ascensor
# 24                            56 m²    Planta 7ª exterior con ascensor
# 25                           117 m²    Planta 5ª exterior con ascensor
# 26                            50 m²    Planta 4ª exterior con ascensor
# 27                           203 m²    Planta 5ª exterior con ascensor
# 28  Planta 9ª exterior con ascensor                         40 minutos
# 29                           110 m²    Planta 3ª exterior con ascensor
#
#       Room                                        Description
# 0   3 hab.  \nInmoRenta; Gestión y Garantía Real de tu alq...
# 1   3 hab.  \nPiso de Home Club disponible para alquilarse...
# 2   1 hab.  \nPiso Interior, situado en la zona de Ríos Ro...
# 3   1 hab.  \nMIA REAL ESTATE, presenta loft para aquellos...
# 4   2 hab.  \nBonito piso de 2 habitaciones en finca con p...
# 5   2 hab.  \n¡SERVICHECK ALQUILA SIN COMISIÓN DE AGENCIA!...
# 6   1 hab.                     \nPequeña terraza/tendedero.\n
# 7   3 hab.  \nServicheck Alquila, información con Johana 6...
# 8   4 hab.  \nRef. 1808 Embassy Presenta un inmueble clási...
# 9   2 hab.  \nSIN COMISIÓN DE AGENCIA Y ALTA DE SUMINISTRO...
# 10  3 hab.  \nÁtico exterior de 3 habitaciones con magnífi...
# 11  3 hab.  \nEstrena vivienda en el Barrio de Salamanca\n...
# 12  1 hab.  \n" LEA EL ANUNCIO COMPLETO ANTES DE LLAMAR, G...
# 13  2 hab.  \nKM2 presenta esta ESPECTACULAR vivienda de 2...
# 14  6 hab.  \nQUARTIERS Expertos Inmobiliarios. Agents Imm...
# 15  2 hab.  \n¡ESPECTACULAR vivienda con 10% DE BONIFICACI...
# 16  2 hab.  \nPiso amueblado a 50 metros del centro comerc...
# 17  1 hab.  \nServicheck Alquila Piso en Madrid!\nDisponib...
# 18  3 hab.  \nDisponible a partir de Diciembre!\nSegunda p...
# 19  3 hab.  \nKM2 presenta esta ESPECTACULAR vivienda de 3...
# 20   46 m²  \nEstupendo apartamento, recién reformado, con...
# 21  3 hab.  \nKM2 presenta esta ESPECTACULAR vivienda de 3...
# 22  1 hab.  \nPiso en alquiler de 1 dormitorio, cocina ame...
# 23  2 hab.  \nKM2 presenta esta ESPECTACULAR vivienda de 2...
# 24  3 hab.  \nLuminoso piso de 3 habitaciones en Ciudad Li...
# 25  2 hab.  \n¡ESPECTACULAR vivienda con 10% DE BONIFICACI...
# 26  1 hab.  \n*OJO DISPONIBLE DESDE 4 NOVIEMBRE*\nAlquiler...
# 27  3 hab.  \nKM2 presenta esta ESPECTACULAR vivienda de 4...
# 28   37 m²  \nAlquilo estudio de diseño, totalmente reform...
# 29  1 hab.  \nServicheck Alquila Piso Temporal en Madrid!\...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   30 non-null     int64
#  1   Direction    30 non-null     object
#  2   Price        30 non-null     object
#  3   m2           30 non-null     object
#  4   Floor        30 non-null     object
#  5   Room         30 non-null     object
#  6   Description  30 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ KB

# %%
df = clean_csv(df)
df = changes_csv(df)
df
# Out:
#                                             Direction   Price     m2 Floor  \
# 0    Piso en avenida del Manzanares, Comillas, Mad...  1500.0   90.0     7
# 1          Piso en calle de Narváez, 9, Goya, Madrid   6365.0  154.0     2
# 2    Piso en Alonso Cano, 65, Nuevos Ministerios-R...   680.0   50.0     0
# 3    Piso en paseo del General Martínez Campos, Al...  2200.0  110.0     0
# 4    Piso en avenida de Monforte de Lemos, 147, Pi...   950.0   55.0    12
# 5    Piso en calle Arte Conceptual, Ensanche de Va...  1100.0   79.0     4
# 6    Piso en calle del Monasterio de Caaveiro, 8, ...   750.0   72.0     3
# 7        Piso en paseo Talleres, Los Ángeles, Madrid    850.0   48.0     0
# 8          Piso en calle de Alcántara, Lista, Madrid   2700.0  160.0     5
# 9    Piso en avenida del Monte Igueldo, San Diego,...  1025.0   76.0     2
# 10   Ático en calle de Fermín Caballero, 91, Peñag...  1600.0  118.0     8
# 11   Piso en calle de Hermosilla, 7, Recoletos, Ma...  1950.0  112.0     6
# 12   Piso en calle de Rodrigo Uhagón, 21, Pradolon...   625.0   42.0     0
# 13   Piso en calle del Doctor Fleming, 39, Nueva E...  2233.0  122.0     1
# 14     Chalet pareado en Conde Orgaz-Piovera, Madrid   7000.0  650.0    24
# 15   Piso en calle Félix Boix, 4, Nueva España, Ma...  2340.0  130.0     7
# 16        Piso en plaza de arteijo, 7, Pilar, Madrid   1050.0   70.0    10
# 17          Piso en calle de Esparteros, Sol, Madrid   1462.0   45.0     2
# 18   Piso en calle Lonja de la Seda, 35, Pau de Ca...  1100.0  110.0     2
# 19   Piso en calle del Doctor Fleming, 41, Nueva E...  2202.0  130.0     2
# 20   Estudio en calle del Heliótropo, 2, Ventilla-...  1300.0    NaN    29
# 21   Piso en calle de Carlos Maurrás, 7, Nueva Esp...  2251.0  131.0     3
# 22   Piso en calle de Juan de la Hoz, Guindalera, ...  1000.0   47.0     1
# 23   Piso en calle del Doctor Fleming, 39, Nueva E...  2294.0  135.0     5
# 24   Piso en avenida Donostiarra, Concepción, Madrid    890.0   56.0     7
# 25   Piso en calle Félix Boix, 6, Nueva España, Ma...  2251.0  117.0     5
# 26   Ático en calle Doña Urraca, Puerta del Ángel,...   875.0   50.0     4
# 27   Piso en calle Félix Boix, 8, Nueva España, Ma...  2998.0  203.0     5
# 28     Estudio en calle Malagón, 2, Canillas, Madrid    610.0    NaN    40
# 29   Piso en calle de Piamonte, Chueca-Justicia, M...  2670.0  110.0     3
#
#     Room                                        Description
# 0      3   InmoRenta; Gestión y Garantía Real de tu alqu...
# 1      3   Piso de Home Club disponible para alquilarse ...
# 2      1   Piso Interior, situado en la zona de Ríos Ros...
# 3      1   MIA REAL ESTATE, presenta loft para aquellos ...
# 4      2   Bonito piso de 2 habitaciones en finca con po...
# 5      2   ¡SERVICHECK ALQUILA SIN COMISIÓN DE AGENCIA! ...
# 6      1                        Pequeña terraza/tendedero.
# 7      3   Servicheck Alquila, información con Johana 67...
# 8      4   Ref. 1808 Embassy Presenta un inmueble clásic...
# 9      2   SIN COMISIÓN DE AGENCIA Y ALTA DE SUMINISTROS...
# 10     3   Ático exterior de 3 habitaciones con magnífic...
# 11     3   Estrena vivienda en el Barrio de Salamanca   ...
# 12     1   " LEA EL ANUNCIO COMPLETO ANTES DE LLAMAR, GR...
# 13     2   KM2 presenta esta ESPECTACULAR vivienda de 2 ...
# 14     6   QUARTIERS Expertos Inmobiliarios. Agents Immo...
# 15     2   ¡ESPECTACULAR vivienda con 10% DE BONIFICACIÓ...
# 16     2   Piso amueblado a 50 metros del centro comerci...
# 17     1   Servicheck Alquila Piso en Madrid! Disponible...
# 18     3   Disponible a partir de Diciembre! Segunda pla...
# 19     3   KM2 presenta esta ESPECTACULAR vivienda de 3 ...
# 20     0   Estupendo apartamento, recién reformado, con ...
# 21     3   KM2 presenta esta ESPECTACULAR vivienda de 3 ...
# 22     1   Piso en alquiler de 1 dormitorio, cocina amer...
# 23     2   KM2 presenta esta ESPECTACULAR vivienda de 2 ...
# 24     3   Luminoso piso de 3 habitaciones en Ciudad Lin...
# 25     2   ¡ESPECTACULAR vivienda con 10% DE BONIFICACIÓ...
# 26     1   *OJO DISPONIBLE DESDE 4 NOVIEMBRE* Alquiler d...
# 27     3   KM2 presenta esta ESPECTACULAR vivienda de 4 ...
# 28     0   Alquilo estudio de diseño, totalmente reforma...
# 29     1   Servicheck Alquila Piso Temporal en Madrid! D...

# %%
# Concat principal csv
df_idealista = pd.read_csv("../../data/rentaMadrid2023Idealista.csv", sep=";")
# Clear data
df_idealista
# Out:
#                                              Direction   Price     m2  Floor  \
# 0                                Piso en Goya, Madrid   1500.0   91.0      2
# 1           Piso en calle de Belice, Salvador, Madrid   1150.0   78.0      0
# 2        Piso en calle Beasain, 31, Orcasitas, Madrid    790.0   68.0      3
# 3     Piso en calle de Oña, Virgen del Cortijo - Ma...  1000.0   40.0      0
# 4     Piso en batalla del Salado, 44, Delicias, Mad...  1400.0   71.0      2
# ..                                                 ...     ...    ...    ...
# 407                        Piso en Castellana, Madrid   4200.0  230.0      5
# 408   Piso en German Pérez Carrasco, Quintana, Madrid    900.0   50.0      2
# 409   Piso en calle de Hermosilla, 18, Recoletos, M...  3900.0  170.0      2
# 410   Estudio en calle del Manco de Lepanto, Numanc...   630.0    NaN      3
# 411   Piso en calle de Serrano, 28, Recoletos, Madrid   4600.0  165.0      3
#
#      Room                                        Description
# 0       2   MARIO INMOBILIARIA OFRECE INMUEBLE PARA CONCE...
# 1       2   -ZONA SALVADOR- Piso reformado de 78m² constr...
# 2       1   Piso de 1 dormitorio +TRASTERO + GARAJE con t...
# 3       1   - SANCHINARRO-Vivienda de 39 m² útiles, exter...
# 4       1   Alquilo apartamento grande de una habitación,...
# ..    ...                                                ...
# 407     2   La Inmobiliaria Internacional CPM gestiona es...
# 408     2   ¿Estás buscando una vivienda luminosa, recién...
# 409     3   MAGNÍFICA VIVIENDA EN PLENO BARRIO DE SALAMAN...
# 410     0   POR FAVOR LEER TODA LA DESCRIPCIÓN DEL ANUNCI...
# 411     3   VIBA les ofrece una exclusiva vivienda en ple...
#
# [412 rows x 6 columns]

# %%
df_final = pd.concat([df,df_idealista], ignore_index=True)
df_final.drop_duplicates(inplace=True)

# %%
df_final.to_csv("../../data/rentaMadrid2023Idealista.csv", sep=";", index=False)

# %%
df_final
# Out:
#                                              Direction   Price     m2 Floor  \
# 0     Piso en avenida del Manzanares, Comillas, Mad...  1500.0   90.0     7
# 1           Piso en calle de Narváez, 9, Goya, Madrid   6365.0  154.0     2
# 2     Piso en Alonso Cano, 65, Nuevos Ministerios-R...   680.0   50.0     0
# 3     Piso en paseo del General Martínez Campos, Al...  2200.0  110.0     0
# 4     Piso en avenida de Monforte de Lemos, 147, Pi...   950.0   55.0    12
# ..                                                 ...     ...    ...   ...
# 437                        Piso en Castellana, Madrid   4200.0  230.0     5
# 438   Piso en German Pérez Carrasco, Quintana, Madrid    900.0   50.0     2
# 439   Piso en calle de Hermosilla, 18, Recoletos, M...  3900.0  170.0     2
# 440   Estudio en calle del Manco de Lepanto, Numanc...   630.0    NaN     3
# 441   Piso en calle de Serrano, 28, Recoletos, Madrid   4600.0  165.0     3
#
#      Room                                        Description
# 0       3   InmoRenta; Gestión y Garantía Real de tu alqu...
# 1       3   Piso de Home Club disponible para alquilarse ...
# 2       1   Piso Interior, situado en la zona de Ríos Ros...
# 3       1   MIA REAL ESTATE, presenta loft para aquellos ...
# 4       2   Bonito piso de 2 habitaciones en finca con po...
# ..    ...                                                ...
# 437     2   La Inmobiliaria Internacional CPM gestiona es...
# 438     2   ¿Estás buscando una vivienda luminosa, recién...
# 439     3   MAGNÍFICA VIVIENDA EN PLENO BARRIO DE SALAMAN...
# 440     0   POR FAVOR LEER TODA LA DESCRIPCIÓN DEL ANUNCI...
# 441     3   VIBA les ofrece una exclusiva vivienda en ple...
#
# [387 rows x 6 columns]
