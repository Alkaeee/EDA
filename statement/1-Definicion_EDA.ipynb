# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "EDA alquileres y viviendas vacacionales Madrid. Evolución."

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = "Un breve estudio sobre la evolución del alquiler en Madrid y contrastandolo con datos de la paginas idealista con datos actuales"
tema_2 = " Compararlo con viviendas vacaciones y como eso sube el "

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = "La subida de precio a lo largo del tiempo en Madrid por las viviendas vacacionales"

# %%
# Escribe más hipótesis si las hubiera en Markdown
hipotesis_2 = "Estudio de como ha ido evolucionando con el tiempo el alquiler con la renta media"
# hipotesis_3 = ""
# hipotesis_4 = ""
# hipotesis_5 = ""
# ...

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd

# %%
# guarda en variables los datasets y su fuente
df_1 = pd.DataFrame()
# Fuente sacada de https://www.idealista.com/alquiler-viviendas/madrid-madrid con web-scraping 2023
fuente_1 = "src/data/rentaMadridIdealista2023.csv"
df_1 = pd.read_csv(fuente_1, sep=";")
# Fuentes sacadas del INE
fuente_2 = "src/data/evolucion_del_precio_de_la_vivienda_en_madrid.csv"
df_2 = pd.read_csv(fuente_2, sep=";")
fuente_3 = "src/data/la_renta_bruta_media_de_madrid.csv"
df_3 = pd.read_csv(fuente_3, sep=";")
fuente_4 = "src/data/ipva_mad_tam.csv"
df_4 = pd.read_table(fuente_4, sep=";")
fuente_5 = "src/data/ipva_mad_vivienda.csv"
df_5 = pd.read_csv(fuente_5, sep=";")
fuente_6 = "src/data/ipva_mad_contrato.csv"
df_6 = pd.read_csv(fuente_6,  sep=";")
# Fuente recogida en dataset de apartamentos turisticos en Madrid
fuente_7 = "src/data/alojamientos-turisticos-sample.csv"
df_7 = pd.read_csv(fuente_7)
# Fuente media renta en madrid INE
fuente_8 = "src/data/salario_mad_medio.csv"
df_8 = pd.read_csv(fuente_8, sep=";")

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
df_1.head(20)
# Out:
#     Unnamed: 0                                          Direction    Price  \
# 0            0   Piso en calle del Balandro, Alameda de Osuna,...    1.195
# 1            1   Piso en calle de Claudio Coello, Castellana, ...   10.000
# 2            2   Ático en calle de Serrano Jover, Malasaña-Uni...    2.500
# 3            3                         Piso en Argüelles, Madrid     2.400
# 4            4    Estudio en calle de Preciados, 34, Sol, Madrid     1.100
# 5            5   Piso en avenida de Valdemarín, Valdemarín, Ma...    2.750
# 6            6                        Estudio en Almagro, Madrid     1.300
# 7            7               Dúplex en San Juan Bautista, Madrid     4.100
# 8            8       Piso en plaza de la Cebada, Palacio, Madrid   875.000
# 9            9               Piso en Conde Orgaz-Piovera, Madrid     2.500
# 10          10   Piso en calle de Puente la Reina, Las Tablas,...    1.195
# ...

# %%
# Siguiente dataset...
df_2.head()
# Out:
#     Año      Periodo  Madrid﻿  España
# 0  2007  Trimestre 2   3.497,8    NaN
# 1  2007  Trimestre 3  3.551,19    NaN
# 2  2007  Trimestre 4  3.364,98    NaN
# 3  2008  Trimestre 1  3.323,59    NaN
# 4  2008  Trimestre 2  3.268,73    NaN

# %%
df_3.head()
# Out:
#     Año Periodo  Renta bruta media per cápita
# 0  2013     Año                        34.485
# 1  2014     Año                        34.837
# 2  2015     Año                        36.442
# 3  2016     Año                        37.242
# 4  2017     Año                        38.224

# %%
df_4.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autonomas Tamano de la vivienda  \
# 0  Total Nacional          13 Madrid, Comunidad de                 Total
# 1  Total Nacional          13 Madrid, Comunidad de                 Total
# 2  Total Nacional          13 Madrid, Comunidad de                 Total
# 3  Total Nacional          13 Madrid, Comunidad de                 Total
# 4  Total Nacional          13 Madrid, Comunidad de                 Total
#
#   Tipo de dato  Periodo    Total
# 0       �ndice     2021  112,539
# 1       �ndice     2020  111,433
# 2       �ndice     2019  110,717
# 3       �ndice     2018  106,485
# 4       �ndice     2017  103,653

# %%
df_5.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autonomas Tipo de edificacion  \
# 0  Total Nacional          13 Madrid, Comunidad de               Total
# 1  Total Nacional          13 Madrid, Comunidad de               Total
# 2  Total Nacional          13 Madrid, Comunidad de               Total
# 3  Total Nacional          13 Madrid, Comunidad de               Total
# 4  Total Nacional          13 Madrid, Comunidad de               Total
#
#   Tipo de dato  Periodo    Total
# 0       �ndice     2021  112,539
# 1       �ndice     2020  111,433
# 2       �ndice     2019  110,717
# 3       �ndice     2018  106,485
# 4       �ndice     2017  103,653

# %%
df_6.head()
# Out:
#    Total Nacional Comunidades y Ciudades Autonomas  \
# 0  Total Nacional          13 Madrid, Comunidad de
# 1  Total Nacional          13 Madrid, Comunidad de
# 2  Total Nacional          13 Madrid, Comunidad de
# 3  Total Nacional          13 Madrid, Comunidad de
# 4  Total Nacional          13 Madrid, Comunidad de
#
#   Antiguedad del contrato de arrendamiento     Tipo de dato  Periodo    Total
# 0                                    Total           �ndice     2021  112,539
# 1                                    Total  Variaci�n anual     2021      1,0
# 2                           Nuevo contrato           �ndice     2021  113,661
# 3                           Nuevo contrato  Variaci�n anual     2021      2,0
# 4                       Contrato existente           �ndice     2021  112,298

# %%
df_7.head(20)
# Out:
#     apartment_id                               md5  \
# 0       36187629  66fff4225feb2ddf104ea38f76e4bff1
# 1        5388904  48790b4dd865e98cc1f5302a2bba1a50
# 2       39982406  d3a60e8898bd8ddce4325c8d3d6af7c8
# 3       19344018  e2f33bae8c814924e8ce7e6efa8e7245
# 4       17218380  11295740bea58c9ae080a459cc8094c5
# 5       30808704  8a04ff34abb53d484d162962a1b4b6f3
# 6       23409834  97a4b8d518a299aa5e6502f49cada7c4
# 7        1254955  911569ccd37ad14402df998bf3172228
# 8       39921958  08e8de7e04a236756df3d754d3e9000b
# 9        9485319  be0b3348a54c4dd9dca13df446621f98
# 10      31460984  f1f555f06f719f5111ea54ecfa4e3434
# 11      20087018  ece8097d66e1fe81b0d260efcfc6b228
# 12      18750489  9ffec0db9fdb8199bcf1363befa7800c
# 13      26274545  4d422a4e3a42159c8536930b9eb97938
# 14      38259169  1b85817bef241106dd24bf509198f489
# 15      24954938  99263f2954a6d6336613c6c536c34b07
# 16       9273891  23dacc968af9b9e139c35a08a6f5496c
# ...

# %%
df_8.head(10)
# Out:
#           Sexo    Comunidad autonoma Componentes del salario bruto mensual  \
# 0  Ambos sexos  Madrid, Comunidad de                          Salario base
# 1  Ambos sexos  Madrid, Comunidad de                         Salario bruto
# 2  Ambos sexos  Madrid, Comunidad de                          Salario neto
# 3      Mujeres  Madrid, Comunidad de                          Salario base
# 4      Mujeres  Madrid, Comunidad de                         Salario bruto
# 5      Mujeres  Madrid, Comunidad de                          Salario neto
# 6      Hombres  Madrid, Comunidad de                          Salario base
# 7      Hombres  Madrid, Comunidad de                         Salario bruto
# 8      Hombres  Madrid, Comunidad de                          Salario neto
#
#       Total
# 0  1.318,19
# 1  2.001,36
# 2  1.553,64
# 3  1.218,70
# 4  1.790,90
# 5  1.409,05
# 6  1.408,66
# 7  2.192,76
# 8  1.685,13
